# %% [markdown]
# # Calculates Cohen Kappa for sentence level annotations

# %% [markdown]
# This notebook calculates the Cohen Kappa scores for sentence level annotations from export of the InCepTion tool. These exports are stored in the IAA folder for five groups of two annotators: G1, G2, G3, G4, G5. Each group has two tsv files in their subfolder.
#
# InCepTion stores the annotations on rows for tokens. Rows have a document identifier, a sentence-token identifier and the annotation label. If there is no annotation, the "_" is given.
#
# We process the data group by group and calculte the Kappa scores for each label separately. Annotations are aggregated at the sentence level.
# If there are multiple labels per sentence, we select the label under investigation from either annotator and check if the other annotator has the same label or some other label.
#
# The results are aggregated in a Pandas frame and saved to a CSV file at the end after processing all the annotators.

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.cohen_kappa_score.html

# %%
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix

import numpy as np
import pandas as pd
import os, random, glob, json, re

import util

global1 = []
global2 = []
globalkey = []
globalgroup = []

results_df = pd.DataFrame(columns=['Label', 'G1', 'G2', 'G3', 'G4', 'G5'])
cnts_df = pd.DataFrame(columns=['Label', 'G1', 'G2', 'G3', 'G4', 'G5'])

# %%
### Given two annotators
group='G1'
base="./IAA/"+group+"/IAA_"
name1="avelli"
name2="vervaart"

print('annotator:',name1)
file1=base+name1+".tsv"
df1 = pd.read_csv(file1,sep="\t")
print(df1.info())
print(df1.head())
print()
df1['annotation'].fillna("_")

print('annotator:',name2)
file2=base+name2+".tsv"
df2 = pd.read_csv(file2,sep="\t")
print(df2.info())
print(df2.head())
df2['annotation'].fillna("_")
# Out:
# annotator: avelli
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4255 entries, 0 to 4254
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   note_id        4255 non-null   object
#  1   sen_id-tok_id  4255 non-null   object
#  2   annotation     3681 non-null   object
# dtypes: object(3)
# memory usage: 99.9+ KB
# None
#                                              note_id sen_id-tok_id annotation
# 0  VUmc--5113--1834251--414676213--2020-04-13--q1...           1-1          _
# 1  VUmc--5113--1834251--414676213--2020-04-13--q1...           1-2          _
# 2  VUmc--5113--1834251--414676213--2020-04-13--q1...           2-1          _
# 3  VUmc--5113--1834251--414676213--2020-04-13--q1...           2-2          _
# 4  VUmc--5113--1834251--414676213--2020-04-13--q1...           2-3          _
#
# annotator: vervaart
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4255 entries, 0 to 4254
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   note_id        4255 non-null   object
#  1   sen_id-tok_id  4255 non-null   object
#  2   annotation     3500 non-null   object
# dtypes: object(3)
# memory usage: 99.9+ KB
# None
#                                              note_id sen_id-tok_id annotation
# 0  VUmc--5113--1834251--414676213--2020-04-13--q1...           1-1          _
# 1  VUmc--5113--1834251--414676213--2020-04-13--q1...           1-2          _
# 2  VUmc--5113--1834251--414676213--2020-04-13--q1...           2-1          _
# 3  VUmc--5113--1834251--414676213--2020-04-13--q1...           2-2          _
# 4  VUmc--5113--1834251--414676213--2020-04-13--q1...           2-3          _
# 0       _
# 1       _
# 2       _
# 3       _
# 4       _
#        ..
# 4250    _
# 4251    _
# 4252    _
# 4253    _
# 4254    _
# Name: annotation, Length: 4255, dtype: object

# %% [markdown]
# ### Clean the annotations

# %%
print('DF1')
df1= util.clean_df(df1)
print('DF2')
df2= util.clean_df(df2)
# Out:
# DF1
# Length: 4255
# DF2
# Length: 4255

# %% [markdown]
# The number of token ids should be the same across the two annotators:

# %%
print('Number of token ids', len(util.get_token_ids(df1)))
print('Number of token ids', len(util.get_token_ids(df2)))
# Out:
# Number of token ids 4255
# Number of token ids 4255

# %% [markdown]
# ## Getting the  annotations at the sentence level

# %% [markdown]
# We get some statistics on the distribution of the annotations at the sentence level

# %%
sentence_label_dict1 = util.sentence_anno(df1)
print('Number of sentences:',len(sentence_label_dict1))

sentence_label_dict2 = util.sentence_anno(df2)
print('Number of sentences:',len(sentence_label_dict1))
# Out:
# Number of sentences: 731
# Number of sentences: 731

# %%
key1=list(sentence_label_dict1.keys())[7]
key2=list(sentence_label_dict2.keys())[7]
print(key1)
print(sentence_label_dict1[key1])
print(key2)
print(sentence_label_dict2[key2])
# Out:
# VUmc--5113--1834251--414676213--2020-04-13--q1q2--Search1_8
# ['_', '_', '_', '_']
# VUmc--5113--1834251--414676213--2020-04-13--q1q2--Search1_8
# ['_', '_', '_', '_']

# %% [markdown]
# Next, we need to make these annotations unique sets.

# %%
setdict1 = util.get_sentence_set_anno_dict(sentence_label_dict1)
setdict2 = util.get_sentence_set_anno_dict(sentence_label_dict2)

# %% [markdown]
# Check if this worked out and sentence ids are correctly aligned

# %%
keys1=setdict1.items()
keys2=list(setdict2.items())

cnt = 0
for key1, value1 in setdict1.items():
    value2=setdict2[key1]
    if not (value1=={'_'} and (value2=={'_'})):
        print(key1, value1, value2)
        cnt+=1
        if (cnt==50):
            break
# Out:
# VUmc--5113--1834251--414676213--2020-04-13--q1q2--Search1_19 {'target'} {'target'}
# VUmc--5113--1834251--414676213--2020-04-13--q1q2--Search1_20 {'target'} {'target'}
# VUmc--5113--1834251--414676213--2020-04-13--q1q2--Search1_21 {'target'} {'target'}
# VUmc--5113--1834251--414676213--2020-04-13--q1q2--Search1_22 {'target'} {'target', '_'}
# VUmc--5113--1834251--414676213--2020-04-13--q1q2--Search1_23 {'target'} {'_'}
# VUmc--5113--1834251--414676213--2020-04-13--q1q2--Search1_24 {'target'} {'_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_1 {'_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_2 {'_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_3 {'_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_4 {'_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_5 {'_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_6 {'_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_7 {'_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_8 {'_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_9 {'_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_10 {'.D450: Lopen en zich verplaatsen', '_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_11 {'.B455: Inspanningstolerantie', '_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_12 {'FAC 4', '.D450: Lopen en zich verplaatsen', '_'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_13 {'FAC 4', '.D450: Lopen en zich verplaatsen'} {'type\\_Background'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_15 {'.B152: Stemming', 'STM 4', '_'} {'STM 3', '_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_21 {'_'} {'.B455: Inspanningstolerantie', '_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_26 {'.D450: Lopen en zich verplaatsen'} {'_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_27 {'.D450: Lopen en zich verplaatsen'} {'FAC 4', '_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_28 {'.D450: Lopen en zich verplaatsen', '_'} {'_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_29 {'_', '.B455: Inspanningstolerantie'} {'_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_31 {'.B455: Inspanningstolerantie'} {'_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_46 {'STM 4', '_'} {'STM 3', '_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_47 {'.D450: Lopen en zich verplaatsen', '_'} {'lop\\_hulpmiddel', '_'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_48 {'target'} {'target'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_49 {'target'} {'target'}
# VUmc--5122--1834251--419112434--2020-05-01--q1q2--Search1_50 {'target'} {'target'}
# VUmc--5124--1834251--424950826--2020-05-25--q1q2--Search1_4 {'.B455: Inspanningstolerantie', '_'} {'.B455: Inspanningstolerantie', '_'}
# VUmc--5124--1834251--424950826--2020-05-25--q1q2--Search1_16 {'_'} {'target'}
# VUmc--5124--1834251--424950826--2020-05-25--q1q2--Search1_26 {'target'} {'_'}
# VUmc--5124--1834251--424950826--2020-05-25--q1q2--Search1_27 {'target'} {'_'}
# VUmc--5124--1834251--424950826--2020-05-25--q1q2--Search1_28 {'target'} {'_'}
# VUmc--5124--1834251--424950826--2020-05-25--q1q2--Search1_29 {'target'} {'_'}
# VUmc--5124--1834251--424950826--2020-05-25--q1q2--Search1_30 {'target'} {'_'}
# VUmc--5123--1834251--422391802--2020-05-14--q1q2--Search1_10 {'_'} {'type\\_Background'}
# VUmc--5123--1834251--422391802--2020-05-14--q1q2--Search1_11 {'_'} {'type\\_Background'}
# VUmc--5123--1834251--422391802--2020-05-14--q1q2--Search1_48 {'target'} {'_'}
# VUmc--5120--1834251--418664815--2020-04-29--q1q2--Search1_3 {'_'} {'STM 1', 'stm\\_reaction', '_'}
# VUmc--5120--1834251--418664815--2020-04-29--q1q2--Search1_5 {'FAC 4', '.D450: Lopen en zich verplaatsen', '_'} {'FAC 4', '_'}
# VUmc--5120--1834251--418664815--2020-04-29--q1q2--Search1_10 {'target'} {'target'}
# VUmc--5120--1834251--418664815--2020-04-29--q1q2--Search1_11 {'target', '_'} {'target'}
# VUmc--5062--1840760--422153501--2020-05-13--q1q2--Search1_6 {'type\\_Background', '_'} {'type\\_Background', '_'}
# VUmc--5062--1840760--422153501--2020-05-13--q1q2--Search1_7 {'type\\_Background'} {'type\\_Background'}
# VUmc--5062--1840760--422153501--2020-05-13--q1q2--Search1_8 {'type\\_Background'} {'type\\_Background'}
# VUmc--5062--1840760--422153501--2020-05-13--q1q2--Search1_9 {'type\\_Background', '_'} {'type\\_Background'}
# VUmc--5062--1840760--422153501--2020-05-13--q1q2--Search1_10 {'_'} {'type\\_Background'}

# %% [markdown]
# ## Getting the Cohen Kappa scores for multiple values per sentence

# %%
annotation_list=[]
for key1, value1 in setdict1.items():
    value2=setdict2[key1]
    for item in value1:
        annotation_list.append(item)
    for item in value2:
        annotation_list.append(item)
    
### Unique set of labels
annotation_labels = set(annotation_list)
print(annotation_labels)
# Out:
# {'lop\\_hulpmiddel', 'FAC 1', 'type\\_Background', 'info\\_Third party', 'STM 3', '.B455: Inspanningstolerantie', '.B152: Stemming', 'FAC 4', 'stm\\_reaction', 'target', 'STM 4', 'STM 1', '.D450: Lopen en zich verplaatsen', '_'}

# %%
print(len(setdict1))
print(len(setdict2))
# Out:
# 731
# 731

# %%
kappas={}
cnts = {}
for label in annotation_labels:
    kappa, cnt, l1, l2, k, g =util.get_kappa_for_label(setdict1, setdict2, label, group)
    kappas[label]=kappa
    cnts[label]=cnt
    global1.extend(l1)
    global2.extend(l2)
    globalkey.extend(k)
    globalgroup.extend(g)

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(kappas)
# Out:
# {   '.B152: Stemming': -0.12773714563492922,
#     '.B455: Inspanningstolerantie': -0.09532404942193673,
#     '.D450: Lopen en zich verplaatsen': -0.13194287827804896,
#     'FAC 0': -0.1317746717109476,
#     'FAC 2': -0.13256349157858316,
#     'FAC 3': -0.1317746717109476,
#     'INS 1': -0.1317746717109476,
#     'INS 3': -0.1317746717109476,
#     'STM 0': -0.13289420073339686,
#     'STM 1': -0.13195819557147304,
#     'STM 2': -0.13236170020756255,
#     'STM 4': -0.13177467171094737,
#     '_': -0.10504068558887836,
#     'disregard\\_file': -0.13289420073339664,
#     'info\\_Third party': -0.13456231761397186,
#     'lop\\_hulpmiddel': -0.13206542823374434,
#     'stm\\_reaction': -0.1317746717109476,
#     'target': -0.10632914035905983,
#     'type\\_Background': -0.14655489928954646,
#     'type\\_Implicit': -0.13289420073339664,
#     'view\\_Patient': -0.13289420073339686,
#     'view\\_Third party': -0.13075195270698026}

# %%
for key, value in kappas.items():
     results_df = util.add_new_row_with_value(results_df, key, value, group)
results_df
# Out:
#                                Label        G1        G2  G3  G4  G5
# 0                    lop\_hulpmiddel  0.143005 -0.132065  -1  -1  -1
# 1                              FAC 1  0.142431        -1  -1  -1  -1
# 2                   type\_Background  0.137186 -0.146555  -1  -1  -1
# 3                  info\_Third party  0.145252 -0.134562  -1  -1  -1
# 4                              STM 3  0.143085        -1  -1  -1  -1
# 5       .B455: Inspanningstolerantie  0.145241 -0.095324  -1  -1  -1
# 6                    .B152: Stemming  0.146836 -0.127737  -1  -1  -1
# 7                              FAC 4  0.144908        -1  -1  -1  -1
# 8                      stm\_reaction  0.145641 -0.131775  -1  -1  -1
# 9                             target  0.149687 -0.106329  -1  -1  -1
# 10                             STM 4  0.125939 -0.131775  -1  -1  -1
# 11                             STM 1  0.142431 -0.131958  -1  -1  -1
# 12  .D450: Lopen en zich verplaatsen  0.133845 -0.131943  -1  -1  -1
# 13                                 _  0.153347 -0.105041  -1  -1  -1
# 14                             STM 0 -1.000000 -0.132894  -1  -1  -1
# 15                             FAC 2 -1.000000 -0.132563  -1  -1  -1
# 16                   disregard\_file -1.000000 -0.132894  -1  -1  -1
# 17                             INS 3 -1.000000 -0.131775  -1  -1  -1
# 18                             INS 1 -1.000000 -0.131775  -1  -1  -1
# 19                             FAC 3 -1.000000 -0.131775  -1  -1  -1
# 20                             STM 2 -1.000000 -0.132362  -1  -1  -1
# 21                    type\_Implicit -1.000000 -0.132894  -1  -1  -1
# 22                 view\_Third party -1.000000 -0.130752  -1  -1  -1
# 23                     view\_Patient -1.000000 -0.132894  -1  -1  -1
# 24                             FAC 0 -1.000000 -0.131775  -1  -1  -1

# %%
for key, value in cnts.items():
     cnts_df = util.add_new_row_with_value(cnts_df, key, value, group)
cnts_df
# Out:
#                                Label  G1   G2  G3  G4  G5
# 0                    lop\_hulpmiddel   3    2  -1  -1  -1
# 1                              FAC 1   1   -1  -1  -1  -1
# 2                   type\_Background  61  229  -1  -1  -1
# 3                  info\_Third party   3   11  -1  -1  -1
# 4                              STM 3   2   -1  -1  -1  -1
# 5       .B455: Inspanningstolerantie  10    2  -1  -1  -1
# 6                    .B152: Stemming   3    9  -1  -1  -1
# 7                              FAC 4   4   -1  -1  -1  -1
# 8                      stm\_reaction   2    1  -1  -1  -1
# 9                             target  38   96  -1  -1  -1
# 10                             STM 4   4    1  -1  -1  -1
# 11                             STM 1   1    2  -1  -1  -1
# 12  .D450: Lopen en zich verplaatsen   9    2  -1  -1  -1
# 13                                 _  94  254  -1  -1  -1
# 14                             STM 0  -1    1  -1  -1  -1
# 15                             FAC 2  -1    1  -1  -1  -1
# 16                   disregard\_file  -1    1  -1  -1  -1
# 17                             INS 3  -1    1  -1  -1  -1
# 18                             INS 1  -1    1  -1  -1  -1
# 19                             FAC 3  -1    1  -1  -1  -1
# 20                             STM 2  -1    2  -1  -1  -1
# 21                    type\_Implicit  -1    1  -1  -1  -1
# 22                 view\_Third party  -1    2  -1  -1  -1
# 23                     view\_Patient  -1    1  -1  -1  -1
# 24                             FAC 0  -1    1  -1  -1  -1

# %% [markdown]
# ## G2

# %%
### Given two annotators
group='G2'
base="./IAA/"+group+"/IAA_"
name1="bos"
name2="meskers"

file1=base+name1+".tsv"
df1 = pd.read_csv(file1,sep="\t")
df1['annotation'].fillna("_")

file2=base+name2+".tsv"
df2 = pd.read_csv(file2,sep="\t")
df2['annotation'].fillna("_")

df1= util.clean_df(df1)
df2= util.clean_df(df2)

sentence_label_dict1 = util.sentence_anno(df1)
sentence_label_dict2 = util.sentence_anno(df2)

setdict1 = util.get_sentence_set_anno_dict(sentence_label_dict1)
setdict2 = util.get_sentence_set_anno_dict(sentence_label_dict2)

annotation_list=[]
for key1, value1 in setdict1.items():
    value2=setdict2[key1]
    for item in value1:
        annotation_list.append(item)
    for item in value2:
        annotation_list.append(item)
### Unique set of labels
annotation_labels = set(annotation_list)

kappas={}
cnts = {}
for label in annotation_labels:
    kappa, cnt, l1, l2, k, g =util.get_kappa_for_label(setdict1, setdict2, label, group)
    kappas[label]=kappa
    cnts[label]=cnt
    global1.extend(l1)
    global2.extend(l2)
    globalkey.extend(k)
    globalgroup.extend(g)
# Out:
# Length: 6464
# Length: 6464

# %%
for key, value in kappas.items():
     results_df = util.add_new_row_with_value(results_df, key, value, group)
        
results_df
# Out:
#                                Label        G1        G2  G3  G4  G5
# 0                    lop\_hulpmiddel  0.143005 -0.132065  -1  -1  -1
# 1                              FAC 1  0.142431        -1  -1  -1  -1
# 2                   type\_Background  0.137186 -0.146555  -1  -1  -1
# 3                  info\_Third party  0.145252 -0.134562  -1  -1  -1
# 4                              STM 3  0.143085        -1  -1  -1  -1
# 5       .B455: Inspanningstolerantie  0.145241 -0.095324  -1  -1  -1
# 6                    .B152: Stemming  0.146836 -0.127737  -1  -1  -1
# 7                              FAC 4  0.144908        -1  -1  -1  -1
# 8                      stm\_reaction  0.145641 -0.131775  -1  -1  -1
# 9                             target  0.149687 -0.106329  -1  -1  -1
# 10                             STM 4  0.125939 -0.131775  -1  -1  -1
# 11                             STM 1  0.142431 -0.131958  -1  -1  -1
# 12  .D450: Lopen en zich verplaatsen  0.133845 -0.131943  -1  -1  -1
# 13                                 _  0.153347 -0.105041  -1  -1  -1
# 14                             STM 0 -1.000000 -0.132894  -1  -1  -1
# 15                             FAC 2 -1.000000 -0.132563  -1  -1  -1
# 16                   disregard\_file -1.000000 -0.132894  -1  -1  -1
# 17                             INS 3 -1.000000 -0.131775  -1  -1  -1
# 18                             INS 1 -1.000000 -0.131775  -1  -1  -1
# 19                             FAC 3 -1.000000 -0.131775  -1  -1  -1
# 20                             STM 2 -1.000000 -0.132362  -1  -1  -1
# 21                    type\_Implicit -1.000000 -0.132894  -1  -1  -1
# 22                 view\_Third party -1.000000 -0.130752  -1  -1  -1
# 23                     view\_Patient -1.000000 -0.132894  -1  -1  -1
# 24                             FAC 0 -1.000000 -0.131775  -1  -1  -1

# %%
for key, value in cnts.items():
     cnts_df = util.add_new_row_with_value(cnts_df, key, value, group)
cnts_df
# Out:
#                                Label  G1   G2  G3  G4  G5
# 0                    lop\_hulpmiddel   3    2  -1  -1  -1
# 1                              FAC 1   1   -1  -1  -1  -1
# 2                   type\_Background  61  229  -1  -1  -1
# 3                  info\_Third party   3   11  -1  -1  -1
# 4                              STM 3   2   -1  -1  -1  -1
# 5       .B455: Inspanningstolerantie  10    2  -1  -1  -1
# 6                    .B152: Stemming   3    9  -1  -1  -1
# 7                              FAC 4   4   -1  -1  -1  -1
# 8                      stm\_reaction   2    1  -1  -1  -1
# 9                             target  38   96  -1  -1  -1
# 10                             STM 4   4    1  -1  -1  -1
# 11                             STM 1   1    2  -1  -1  -1
# 12  .D450: Lopen en zich verplaatsen   9    2  -1  -1  -1
# 13                                 _  94  254  -1  -1  -1
# 14                             STM 0  -1    1  -1  -1  -1
# 15                             FAC 2  -1    1  -1  -1  -1
# 16                   disregard\_file  -1    1  -1  -1  -1
# 17                             INS 3  -1    1  -1  -1  -1
# 18                             INS 1  -1    1  -1  -1  -1
# 19                             FAC 3  -1    1  -1  -1  -1
# 20                             STM 2  -1    2  -1  -1  -1
# 21                    type\_Implicit  -1    1  -1  -1  -1
# 22                 view\_Third party  -1    2  -1  -1  -1
# 23                     view\_Patient  -1    1  -1  -1  -1
# 24                             FAC 0  -1    1  -1  -1  -1

# %% [markdown]
# ## G3

# %%
### Given two annotators
group='G3'
base="./IAA/"+group+"/IAA_"
name1="katsburg"
name2="opsomer"

file1=base+name1+".tsv"
df1 = pd.read_csv(file1,sep="\t")
df1['annotation'].fillna("_")

file2=base+name2+".tsv"
df2 = pd.read_csv(file2,sep="\t")
df2['annotation'].fillna("_")

df1= util.clean_df(df1)
df2= util.clean_df(df2)

sentence_label_dict1 = util.sentence_anno(df1)
sentence_label_dict2 = util.sentence_anno(df2)

setdict1 = util.get_sentence_set_anno_dict(sentence_label_dict1)
setdict2 = util.get_sentence_set_anno_dict(sentence_label_dict2)

annotation_list=[]
for key1, value1 in setdict1.items():
    value2=setdict2[key1]
    for item in value1:
        annotation_list.append(item)
    for item in value2:
        annotation_list.append(item)
### Unique set of labels
annotation_labels = set(annotation_list)

kappas={}
cnts = {}
for label in annotation_labels:
    kappa, cnt, l1, l2, k, g =util.get_kappa_for_label(setdict1, setdict2, label, group)
    kappas[label]=kappa
    cnts[label]=cnt
    global1.extend(l1)
    global2.extend(l2)
    globalkey.extend(k)
    globalgroup.extend(g)
# Out:
# Length: 5968
# Length: 5968

# %%
for key, value in kappas.items():
     results_df = util.add_new_row_with_value(results_df, key, value, group)

results_df
# Out:
#                                Label        G1        G2         G3  G4  G5
# 0                    lop\_hulpmiddel  0.143005 -0.132065   0.325302  -1  -1
# 1                              FAC 1  0.142431        -1   0.312215  -1  -1
# 2                   type\_Background  0.137186 -0.146555   0.311319  -1  -1
# 3                  info\_Third party  0.145252 -0.134562     0.3262  -1  -1
# 4                              STM 3  0.143085        -1   0.325023  -1  -1
# 5       .B455: Inspanningstolerantie  0.145241 -0.095324   0.326995  -1  -1
# 6                    .B152: Stemming  0.146836 -0.127737    0.32547  -1  -1
# 7                              FAC 4  0.144908        -1         -1  -1  -1
# 8                      stm\_reaction  0.145641 -0.131775   0.349741  -1  -1
# 9                             target  0.149687 -0.106329   0.322066  -1  -1
# 10                             STM 4  0.125939 -0.131775   0.377946  -1  -1
# 11                             STM 1  0.142431 -0.131958   0.324976  -1  -1
# 12  .D450: Lopen en zich verplaatsen  0.133845 -0.131943   0.318445  -1  -1
# 13                                 _  0.153347 -0.105041  0.0980259  -1  -1
# 14                             STM 0 -1.000000 -0.132894         -1  -1  -1
# 15                             FAC 2 -1.000000 -0.132563   0.325027  -1  -1
# 16                   disregard\_file -1.000000 -0.132894   0.326659  -1  -1
# 17                             INS 3 -1.000000 -0.131775         -1  -1  -1
# 18                             INS 1 -1.000000 -0.131775   0.327409  -1  -1
# 19                             FAC 3 -1.000000 -0.131775         -1  -1  -1
# 20                             STM 2 -1.000000 -0.132362         -1  -1  -1
# 21                    type\_Implicit -1.000000 -0.132894   0.324021  -1  -1
# 22                 view\_Third party -1.000000 -0.130752   0.324889  -1  -1
# 23                     view\_Patient -1.000000 -0.132894   0.323974  -1  -1
# 24                             FAC 0 -1.000000 -0.131775   0.312215  -1  -1
# 25         .D840-859: Beroep en werk -1.000000        -1   0.324889  -1  -1

# %%
for key, value in cnts.items():
     cnts_df = util.add_new_row_with_value(cnts_df, key, value, group)
cnts_df
# Out:
#                                Label  G1   G2  G3  G4  G5
# 0                    lop\_hulpmiddel   3    2   2  -1  -1
# 1                              FAC 1   1   -1   1  -1  -1
# 2                   type\_Background  61  229  47  -1  -1
# 3                  info\_Third party   3   11   1  -1  -1
# 4                              STM 3   2   -1   1  -1  -1
# 5       .B455: Inspanningstolerantie  10    2   2  -1  -1
# 6                    .B152: Stemming   3    9   6  -1  -1
# 7                              FAC 4   4   -1  -1  -1  -1
# 8                      stm\_reaction   2    1   5  -1  -1
# 9                             target  38   96   6  -1  -1
# 10                             STM 4   4    1   2  -1  -1
# 11                             STM 1   1    2   1  -1  -1
# 12  .D450: Lopen en zich verplaatsen   9    2   6  -1  -1
# 13                                 _  94  254  67  -1  -1
# 14                             STM 0  -1    1  -1  -1  -1
# 15                             FAC 2  -1    1   1  -1  -1
# 16                   disregard\_file  -1    1   3  -1  -1
# 17                             INS 3  -1    1  -1  -1  -1
# 18                             INS 1  -1    1   1  -1  -1
# 19                             FAC 3  -1    1  -1  -1  -1
# 20                             STM 2  -1    2  -1  -1  -1
# 21                    type\_Implicit  -1    1   4  -1  -1
# 22                 view\_Third party  -1    2   1  -1  -1
# 23                     view\_Patient  -1    1   4  -1  -1
# 24                             FAC 0  -1    1   1  -1  -1
# 25         .D840-859: Beroep en werk  -1   -1   1  -1  -1

# %% [markdown]
# ## G4

# %%
### Given two annotators
group='G4'
base="./IAA/"+group+"/IAA_"
name1="swartjes"
name2="vanderpas"

file1=base+name1+".tsv"
df1 = pd.read_csv(file1,sep="\t")
df1['annotation'].fillna("_")

file2=base+name2+".tsv"
df2 = pd.read_csv(file2,sep="\t")
df2['annotation'].fillna("_")

df1= util.clean_df(df1)
df2= util.clean_df(df2)

sentence_label_dict1 = util.sentence_anno(df1)
sentence_label_dict2 = util.sentence_anno(df2)

setdict1 = util.get_sentence_set_anno_dict(sentence_label_dict1)
setdict2 = util.get_sentence_set_anno_dict(sentence_label_dict2)

annotation_list=[]
for key1, value1 in setdict1.items():
    value2=setdict2[key1]
    for item in value1:
        annotation_list.append(item)
    for item in value2:
        annotation_list.append(item)
### Unique set of labels
annotation_labels = set(annotation_list)

kappas={}
cnts = {}
for label in annotation_labels:
    kappa, cnt, l1, l2, k, g =util.get_kappa_for_label(setdict1, setdict2, label, group)
    kappas[label]=kappa
    cnts[label]=cnt
    global1.extend(l1)
    global2.extend(l2)
    globalkey.extend(k)
    globalgroup.extend(g)
# Out:
# Length: 3688
# Length: 3688

# %%
for key, value in kappas.items():
     results_df = util.add_new_row_with_value(results_df, key, value, group)
results_df
# Out:
#                                Label        G1        G2         G3  \
# 0                    lop\_hulpmiddel  0.143005 -0.132065   0.325302
# 1                              FAC 1  0.142431        -1   0.312215
# 2                   type\_Background  0.137186 -0.146555   0.311319
# 3                  info\_Third party  0.145252 -0.134562     0.3262
# 4                              STM 3  0.143085        -1   0.325023
# 5       .B455: Inspanningstolerantie  0.145241 -0.095324   0.326995
# 6                    .B152: Stemming  0.146836 -0.127737    0.32547
# 7                              FAC 4  0.144908        -1         -1
# 8                      stm\_reaction  0.145641 -0.131775   0.349741
# 9                             target  0.149687 -0.106329   0.322066
# 10                             STM 4  0.125939 -0.131775   0.377946
# 11                             STM 1  0.142431 -0.131958   0.324976
# 12  .D450: Lopen en zich verplaatsen  0.133845 -0.131943   0.318445
# 13                                 _  0.153347 -0.105041  0.0980259
# 14                             STM 0 -1.000000 -0.132894         -1
# 15                             FAC 2 -1.000000 -0.132563   0.325027
# 16                   disregard\_file -1.000000 -0.132894   0.326659
# 17                             INS 3 -1.000000 -0.131775         -1
# 18                             INS 1 -1.000000 -0.131775   0.327409
# 19                             FAC 3 -1.000000 -0.131775         -1
# 20                             STM 2 -1.000000 -0.132362         -1
# 21                    type\_Implicit -1.000000 -0.132894   0.324021
# 22                 view\_Third party -1.000000 -0.130752   0.324889
# 23                     view\_Patient -1.000000 -0.132894   0.323974
# 24                             FAC 0 -1.000000 -0.131775   0.312215
# 25         .D840-859: Beroep en werk -1.000000        -1   0.324889
#
#            G4  G5
# 0          -1  -1
# 1          -1  -1
# 2   -0.137402  -1
# 3  -0.0843616  -1
# 4          -1  -1
# 5          -1  -1
# 6  -0.0877339  -1
# 7          -1  -1
# 8  -0.0881164  -1
# 9  -0.0866779  -1
# 10         -1  -1
# 11         -1  -1
# 12 -0.0884038  -1
# 13   -0.10014  -1
# 14 -0.0879832  -1
# 15         -1  -1
# 16 -0.0884038  -1
# 17         -1  -1
# 18         -1  -1
# 19         -1  -1
# 20         -1  -1
# 21 -0.0884038  -1
# 22         -1  -1
# 23         -1  -1
# 24 -0.0882692  -1
# 25         -1  -1

# %%
for key, value in cnts.items():
     cnts_df = util.add_new_row_with_value(cnts_df, key, value, group)
cnts_df
# Out:
#                                Label  G1   G2  G3  G4  G5
# 0                    lop\_hulpmiddel   3    2   2  -1  -1
# 1                              FAC 1   1   -1   1  -1  -1
# 2                   type\_Background  61  229  47  71  -1
# 3                  info\_Third party   3   11   1   8  -1
# 4                              STM 3   2   -1   1  -1  -1
# 5       .B455: Inspanningstolerantie  10    2   2  -1  -1
# 6                    .B152: Stemming   3    9   6   6  -1
# 7                              FAC 4   4   -1  -1  -1  -1
# 8                      stm\_reaction   2    1   5   1  -1
# 9                             target  38   96   6  14  -1
# 10                             STM 4   4    1   2  -1  -1
# 11                             STM 1   1    2   1  -1  -1
# 12  .D450: Lopen en zich verplaatsen   9    2   6   1  -1
# 13                                 _  94  254  67  98  -1
# 14                             STM 0  -1    1  -1   2  -1
# 15                             FAC 2  -1    1   1  -1  -1
# 16                   disregard\_file  -1    1   3   1  -1
# 17                             INS 3  -1    1  -1  -1  -1
# 18                             INS 1  -1    1   1  -1  -1
# 19                             FAC 3  -1    1  -1  -1  -1
# 20                             STM 2  -1    2  -1  -1  -1
# 21                    type\_Implicit  -1    1   4   1  -1
# 22                 view\_Third party  -1    2   1  -1  -1
# 23                     view\_Patient  -1    1   4  -1  -1
# 24                             FAC 0  -1    1   1   2  -1
# 25         .D840-859: Beroep en werk  -1   -1   1  -1  -1

# %% [markdown]
# ## G5

# %%
### Given two annotators
group='G5'
base="./IAA/"+group+"/IAA_"
name1="edwin"
name2="sabina"

file1=base+name1+".tsv"
df1 = pd.read_csv(file1,sep="\t")
df1['annotation'].fillna("_")

file2=base+name2+".tsv"
df2 = pd.read_csv(file2,sep="\t")
df2['annotation'].fillna("_")

df1= util.clean_df(df1)
df2= util.clean_df(df2)

sentence_label_dict1 = util.sentence_anno(df1)
sentence_label_dict2 = util.sentence_anno(df2)

setdict1 = util.get_sentence_set_anno_dict(sentence_label_dict1)
setdict2 = util.get_sentence_set_anno_dict(sentence_label_dict2)

annotation_list=[]
for key1, value1 in setdict1.items():
    try:
        value2=setdict2[key1]
        for item in value1:
            annotation_list.append(item)
        for item in value2:
            annotation_list.append(item)
    except:
        print('Line mismatch', key1)
        
### Unique set of labels
annotation_labels = set(annotation_list)

kappas={}
cnts = {}
for label in annotation_labels:
    kappa, cnt, l1, l2, k, g =util.get_kappa_for_label(setdict1, setdict2, label, group)
    kappas[label]=kappa
    cnts[label]=cnt
    global1.extend(l1)
    global2.extend(l2)
    globalkey.extend(k)
    globalgroup.extend(g)
# Out:
# Length: 6353
# Length: 5676
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_1
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_2
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_3
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_4
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_5
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_6
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_7
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_8
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_9
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_10
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_11
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_12
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_13
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_14
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_15
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_16
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_17
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_18
# Line mismatch VUmc--4222--1801027--402487522--2020-02-28--q1q2--Search2_19
# Line mismatch VUmc--4220--1801027--402187360--2020-02-27--q1q2--Search2_1
# Line mismatch VUmc--4220--1801027--402187360--2020-02-27--q1q2--Search2_2
# Line mismatch VUmc--4220--1801027--402187360--2020-02-27--q1q2--Search2_3
# Line mismatch VUmc--4220--1801027--402187360--2020-02-27--q1q2--Search2_4
# Line mismatch VUmc--4220--1801027--402187360--2020-02-27--q1q2--Search2_5
# Line mismatch VUmc--4220--1801027--402187360--2020-02-27--q1q2--Search2_6
# Line mismatch VUmc--4220--1801027--402187360--2020-02-27--q1q2--Search2_7
# Line mismatch VUmc--4220--1801027--402187360--2020-02-27--q1q2--Search2_8
# Line mismatch VUmc--4220--1801027--402187360--2020-02-27--q1q2--Search2_9
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_1
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_2
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_3
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_4
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_5
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_6
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_7
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_8
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_9
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_10
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_11
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_12
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_13
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_14
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_15
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_16
# Line mismatch VUmc--4223--1801027--402890191--2020-03-01--q1q2--Search2_17
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_1
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_2
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_3
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_4
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_5
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_6
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_7
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_8
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_9
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_10
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_11
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_12
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_13
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_14
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_15
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_16
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_17
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_18
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_19
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_20
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_21
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_22
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_23
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_24
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_25
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_26
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_27
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_28
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_29
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_30
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_31
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_32
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_33
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_34
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_35
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_36
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_37
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_38
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_39
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_40
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_41
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_42
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_43
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_44
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_45
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_46
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_47
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_48
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_49
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_50
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_51
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_52
# Line mismatch VUmc--4221--1801027--402433215--2020-02-28--q1q2--Search2_53

# %%
for key, value in kappas.items():
     results_df = util.add_new_row_with_value(results_df, key, value, group)
results_df
# Out:
#                                Label        G1        G2         G3  \
# 0                    lop\_hulpmiddel  0.143005 -0.132065   0.325302
# 1                              FAC 1  0.142431        -1   0.312215
# 2                   type\_Background  0.137186 -0.146555   0.311319
# 3                  info\_Third party  0.145252 -0.134562     0.3262
# 4                              STM 3  0.143085        -1   0.325023
# 5       .B455: Inspanningstolerantie  0.145241 -0.095324   0.326995
# 6                    .B152: Stemming  0.146836 -0.127737    0.32547
# 7                              FAC 4  0.144908        -1         -1
# 8                      stm\_reaction  0.145641 -0.131775   0.349741
# 9                             target  0.149687 -0.106329   0.322066
# 10                             STM 4  0.125939 -0.131775   0.377946
# 11                             STM 1  0.142431 -0.131958   0.324976
# 12  .D450: Lopen en zich verplaatsen  0.133845 -0.131943   0.318445
# 13                                 _  0.153347 -0.105041  0.0980259
# 14                             STM 0 -1.000000 -0.132894         -1
# 15                             FAC 2 -1.000000 -0.132563   0.325027
# 16                   disregard\_file -1.000000 -0.132894   0.326659
# 17                             INS 3 -1.000000 -0.131775         -1
# 18                             INS 1 -1.000000 -0.131775   0.327409
# 19                             FAC 3 -1.000000 -0.131775         -1
# 20                             STM 2 -1.000000 -0.132362         -1
# 21                    type\_Implicit -1.000000 -0.132894   0.324021
# 22                 view\_Third party -1.000000 -0.130752   0.324889
# 23                     view\_Patient -1.000000 -0.132894   0.323974
# 24                             FAC 0 -1.000000 -0.131775   0.312215
# 25         .D840-859: Beroep en werk -1.000000        -1   0.324889
# 26                                 * -1.000000        -1         -1
#
#            G4        G5
# 0          -1        -1
# 1          -1        -1
# 2   -0.137402 -0.288104
# 3  -0.0843616 -0.294481
# 4          -1 -0.294666
# 5          -1 -0.295193
# 6  -0.0877339 -0.294296
# 7          -1        -1
# 8  -0.0881164 -0.294666
# 9  -0.0866779 -0.295869
# 10         -1        -1
# 11         -1 -0.294666
# 12 -0.0884038 -0.309097
# 13   -0.10014 -0.121111
# 14 -0.0879832        -1
# 15         -1        -1
# 16 -0.0884038        -1
# 17         -1        -1
# 18         -1        -1
# 19         -1        -1
# 20         -1        -1
# 21 -0.0884038        -1
# 22         -1        -1
# 23         -1        -1
# 24 -0.0882692        -1
# 25         -1        -1
# 26         -1  -0.31102

# %%
for key, value in cnts.items():
     cnts_df = util.add_new_row_with_value(cnts_df, key, value, group)
cnts_df
# Out:
#                                Label  G1   G2  G3  G4  G5
# 0                    lop\_hulpmiddel   3    2   2  -1  -1
# 1                              FAC 1   1   -1   1  -1  -1
# 2                   type\_Background  61  229  47  71  25
# 3                  info\_Third party   3   11   1   8   2
# 4                              STM 3   2   -1   1  -1   1
# 5       .B455: Inspanningstolerantie  10    2   2  -1   1
# 6                    .B152: Stemming   3    9   6   6   3
# 7                              FAC 4   4   -1  -1  -1  -1
# 8                      stm\_reaction   2    1   5   1   1
# 9                             target  38   96   6  14   3
# 10                             STM 4   4    1   2  -1  -1
# 11                             STM 1   1    2   1  -1   1
# 12  .D450: Lopen en zich verplaatsen   9    2   6   1   7
# 13                                 _  94  254  67  98  37
# 14                             STM 0  -1    1  -1   2  -1
# 15                             FAC 2  -1    1   1  -1  -1
# 16                   disregard\_file  -1    1   3   1  -1
# 17                             INS 3  -1    1  -1  -1  -1
# 18                             INS 1  -1    1   1  -1  -1
# 19                             FAC 3  -1    1  -1  -1  -1
# 20                             STM 2  -1    2  -1  -1  -1
# 21                    type\_Implicit  -1    1   4   1  -1
# 22                 view\_Third party  -1    2   1  -1  -1
# 23                     view\_Patient  -1    1   4  -1  -1
# 24                             FAC 0  -1    1   1   2  -1
# 25         .D840-859: Beroep en werk  -1   -1   1  -1  -1
# 26                                 *  -1   -1  -1  -1   4

# %% [markdown]
# ## Visualise globals

# %%
import matplotlib.pyplot as plt
plot_size = plt.rcParams["figure.figsize"]
print('This is the default size:')
print(plot_size[0]) 
print(plot_size[1])

plot_size[0] = 10
plot_size[1] = 8
print('We change it now to:')
print(plot_size[0]) 
print(plot_size[1])

plt.rcParams["figure.figsize"] = plot_size
# Out:
# This is the default size:
# 6.0
# 4.0
# We change it now to:
# 10
# 8

# %%
cnts_df.G1.value_counts().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Save the final results to a CSV file

# %%
result="iaa.csv"
results_df.to_csv(result)

result="cnts.csv"
cnts_df.to_csv(result)

# %% [markdown]
# ## Store all paired annotations at sentence level

# %%
all_df = pd.DataFrame(list(zip(globalgroup, globalkey, global1, global2)))
all_df.columns =['Key','Group',"label1", "label2"]
all_df.head()
# Out:
#   Key                                              Group           label1  \
# 0  G1  VUmc--5122--1834251--419112434--2020-05-01--q1...            FAC 4
# 1  G1  VUmc--5117--1834251--418077134--2020-04-27--q1...  .B152: Stemming
# 2  G1  VUmc--5117--1834251--418077134--2020-04-27--q1...  .B152: Stemming
# 3  G1  VUmc--5118--1834251--418315914--2020-04-28--q1...  .B152: Stemming
# 4  G1  VUmc--5122--1834251--419112434--2020-05-01--q1...  .B152: Stemming
#
#              label2
# 0  type\_Background
# 1             STM 3
# 2             STM 3
# 3             STM 3
# 4             STM 3

# %%
result="all_pairs.csv"
all_df.to_csv(result)

# %% [markdown]
# ## Document level

# %%
group="ALLDOC"
globals1=[]
globals2=[]
globalskey=[]
globalsgroup=[]

# %%
def get_doc_labels (df):
    doc_label_dict1={}
    doc_label_dict2={}
    for index, key in enumerate(df['Key']):
        doc = key[:key.find('_')]
        group = df['Group'].iloc[index]
        label1 = df['label1'].iloc[index]
        label2 = df['label2'].iloc[index]
        if doc in doc_label_dict1:
            doc_label_dict1[doc].append(label1)
        else:
            doc_label_dict1[doc]=[label1]
        
        if doc in doc_label_dict2:
            doc_label_dict2[doc].append(label2)
        else:
            doc_label_dict2[doc]=[label2]
    return doc_label_dict1, doc_label_dict2

# %%
doc_dict_label1, doc_dict_label2 = get_doc_labels(all_df)

setdict1 = util.get_sentence_set_anno_dict(doc_dict_label1)
setdict2 = util.get_sentence_set_anno_dict(doc_dict_label2)

annotation_list=[]
for key1, value1 in setdict1.items():
    try:
        value2=setdict2[key1]
        for item in value1:
            annotation_list.append(item)
        for item in value2:
            annotation_list.append(item)
    except:
        print('Line mismatch', key1)
        
### Unique set of labels
annotation_labels = set(annotation_list)

kappas={}
cnts = {}
for label in annotation_labels:
    kappa, cnt, l1, l2, k, g =util.get_kappa_for_label(setdict1, setdict2, label, group)
    kappas[label]=kappa
    cnts[label]=cnt
    global1.extend(l1)
    global2.extend(l2)
    globalkey.extend(k)
    globalgroup.extend(g)
# Out:
# /Users/piek/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:620: RuntimeWarning: invalid value encountered in true_divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)

# %%
print(len(setdict1))
print(len(setdict2))
# Out:
# 1
# 1

# %%
doc_results_df = pd.DataFrame(columns=['Label', 'ALLDOC'])

for key, value in kappas.items():
     results_df = util.add_new_row_with_value(results_df, key, value, "ALLDOC")
results_df
# Out:
#                                Label        G1        G2         G3  \
# 0                    lop\_hulpmiddel  0.143005 -0.132065   0.325302
# 1                              FAC 1  0.142431        -1   0.312215
# 2                   type\_Background  0.137186 -0.146555   0.311319
# 3                  info\_Third party  0.145252 -0.134562     0.3262
# 4                              STM 3  0.143085        -1   0.325023
# 5       .B455: Inspanningstolerantie  0.145241 -0.095324   0.326995
# 6                    .B152: Stemming  0.146836 -0.127737    0.32547
# 7                              FAC 4  0.144908        -1         -1
# 8                      stm\_reaction  0.145641 -0.131775   0.349741
# 9                             target  0.149687 -0.106329   0.322066
# 10                             STM 4  0.125939 -0.131775   0.377946
# 11                             STM 1  0.142431 -0.131958   0.324976
# 12  .D450: Lopen en zich verplaatsen  0.133845 -0.131943   0.318445
# 13                                 _  0.153347 -0.105041  0.0980259
# 14                             STM 0 -1.000000 -0.132894         -1
# 15                             FAC 2 -1.000000 -0.132563   0.325027
# 16                   disregard\_file -1.000000 -0.132894   0.326659
# 17                             INS 3 -1.000000 -0.131775         -1
# 18                             INS 1 -1.000000 -0.131775   0.327409
# 19                             FAC 3 -1.000000 -0.131775         -1
# 20                             STM 2 -1.000000 -0.132362         -1
# 21                    type\_Implicit -1.000000 -0.132894   0.324021
# 22                 view\_Third party -1.000000 -0.130752   0.324889
# 23                     view\_Patient -1.000000 -0.132894   0.323974
# 24                             FAC 0 -1.000000 -0.131775   0.312215
# 25         .D840-859: Beroep en werk -1.000000        -1   0.324889
# 26                                 * -1.000000        -1         -1
#
#            G4        G5  ALLDOC
# 0          -1        -1     NaN
# 1          -1        -1     0.0
# 2   -0.137402 -0.288104     NaN
# 3  -0.0843616 -0.294481     NaN
# 4          -1 -0.294666     0.0
# 5          -1 -0.295193     NaN
# 6  -0.0877339 -0.294296     NaN
# 7          -1        -1     NaN
# 8  -0.0881164 -0.294666     NaN
# 9  -0.0866779 -0.295869     NaN
# 10         -1        -1     0.0
# 11         -1 -0.294666     0.0
# 12 -0.0884038 -0.309097     0.0
# 13   -0.10014 -0.121111     NaN
# 14 -0.0879832        -1     NaN
# 15         -1        -1     NaN
# 16 -0.0884038        -1     NaN
# 17         -1        -1     NaN
# 18         -1        -1     NaN
# 19         -1        -1     NaN
# 20         -1        -1     NaN
# 21 -0.0884038        -1     NaN
# 22         -1        -1     NaN
# 23         -1        -1     NaN
# 24 -0.0882692        -1     NaN
# 25         -1        -1     NaN
# 26         -1  -0.31102     NaN

# %% [markdown]
# ## End of this notebook
