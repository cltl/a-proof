# %%
import pandas as pd
from pathlib import Path
import ast
from ast import literal_eval
#from updates_join_annotations import open_df_from_tsv
#import updates_get_average_scores_per_label as scores

# %%
def clean_data(filepath):
    # Read in file
    df = pd.read_excel(filepath, dtype={'tokens': list, 'annotators':set}, index_col=0)
    # Sort values and reset index to allow looping later
    df.sort_values(by=['file_id', 'start_index', 'end_index', 'Label'], inplace=True)
    df.reset_index(inplace=True, drop=True)
    # Drop repeated columns
    df.drop(['Unnamed: 0.1', 'Unnamed: 1', 'Unnamed: 2'], axis=1, inplace=True)
    
    # Read in file and set data type for two columns
    df['tokens'] = df['tokens'].apply(literal_eval)
    df['annotators'] = df['annotators'].apply(literal_eval)
    
    return df

# %%
# def main():
# filepath = '../sample_data/label_level_df.xlsx'
filepath = '../../Data/label_level_df_sorted_cleaned.xlsx'

df = clean_data(filepath)

# To do: Something strange happens in row 1289. Token length = 3, start token = 7, end token = 83, len annotator set = 4, annotator count = 1.
# Also row 1375

# %%
df.head()
# Out:
#             Label1   Label2            Label  file_id  start_index  end_index  \
# 0            view\  Patient     view\Patient     2503           48         54
# 1  .B152: Stemming      NaN  .B152: Stemming     2503           96         98
# 2            STM 1      NaN            STM 1     2503           96         98
# 3  .B152: Stemming      NaN  .B152: Stemming     2503           97         98
# 4  .B152: Stemming      NaN  .B152: Stemming     2503           98         98
#
#                                            tokens  \
# 0  [Verteld, zelf, dat, hij, erg, productief, is]
# 1                           [Mw, was, emotioneel]
# 2                           [Mw, was, emotioneel]
# 3                               [was, emotioneel]
# 4                                    [emotioneel]
#
#                                           annotators  annotator_count
# 0                                         {katsburg}                1
# 1                                        {vanderpas}                1
# 2                                        {vanderpas}                1
# 3                                          {opsomer}                1
# 4  {avelli, vervaart, meskers, katsburg, bos, swa...                6

# %%
#file_id = 2345
#label = 'STM0'
label_dict = dict()

# Loop through file_ids (change later)
for file_id in set(df['file_id']):
#for file_id in [2503]:
    # Create filtered df
    df_filtered = df[df['file_id'] == file_id]
    # Loop through labels and create further filtered df
    for label in set(df_filtered['Label']):
                
        #print(file_id, label)
        # df_label has the selection of the rows with the same label
        df_label = df_filtered[df_filtered['Label'] == label]
        df_label.reset_index(inplace=True, drop=True)
        
        try:
            # Set start and end index values
            start_index = df_label['start_index'][0]
            end_index = df_label['end_index'][0]
        except:
            continue
        
        #print('first annotation:', start_index, end_index)
        firstannotation = True
        counter = len(label_dict)+1
        try:
            annos = df_label['annotators'].iloc[1]
        except:
            continue
        
        label_dict[counter] = {'file_id': file_id,
                                           'start_index': start_index, 
                                           'end_index': end_index,
                                           'label': label,
                                           'tokens': df_label.head(1)['tokens'],
                                           'annotators': annos}
        current_range = range(start_index, end_index+1)

        if df_label.shape[0] == 1:
            #print('There is only one annotation for this label so we are done.')
            # If only one tag of label in this file, we are done
            continue
 

        # There are multiple annotations so we need to check their spans and merge
        # label through rest of df
        for index, row in df_label[1:].iterrows():
            # Note: df which it is looping over contains only data from one file from one label

            start_temp = row['start_index']
            end_temp = row['end_index']
            #print('temp', start_temp, end_temp)

            # Since the df_label is sorted on start & end index, only a few cases need to be checked
            # If the temporary start vallue is in the range of the saved start value
            if start_temp in current_range:
                #print('included')
                #print('counter', counter)
                if end_temp not in current_range: # And the temp end value is not, then update the end value
                    #print('updated')
                    end_index = end_temp
                    ### we need to adapt the range
                    current_range = range(start_index, end_index+1)
                # If the temp end value is also in the range then do nothing and move on.
                ### we update the info for this annotation
                if counter in label_dict:
                    #print('counter in label_dict and adding annotators', start_index, end_index)
                    label_dict[counter]['end_index'] = end_index
                    currentannos = label_dict[counter]['annotators']
                    currentannos.update(row['annotators'])
                    label_dict[counter]['annotators'] = currentannos
                    #print('Extended annotators:',label_dict[counter]['annotators'])
                else:
                    #print('counter not in label_dict', start_index, end_index)
                    label_dict[counter] = {'file_id': file_id,
                                           'start_index': start_index, 
                                           'end_index': end_index,
                                           'label': label,
                                           'tokens': row['tokens'],
                                           'annotators': row['annotators']}
                
            else:
                
                ### We have a new first annotation with start and range
                start_index = start_temp
                end_index = end_temp
                current_range = range(start_index, end_index+1)
                counter = len(label_dict)+1
                label_dict[counter] = {'file_id': file_id,
                                           'start_index': start_index, 
                                           'end_index': end_index,
                                           'label': label,
                                           'tokens': row['tokens'],
                                           'annotators': row['annotators']}
                
            # For last entry
            if index == len(df_label)-1:
                #print('last, stored')
                if counter in label_dict:
                    label_dict[counter]['end_index'] = end_index
                    currentannos = label_dict[counter]['annotators']
                    currentannos.update(row['annotators'])
                    label_dict[counter]['annotators'] = currentannos

                    #print('Extended annotators:',label_dict[counter]['annotators'])
                   
                else: 
                    label_dict[counter] = {'file_id': file_id,
                                           'start_index': start_index, 
                                           'end_index': end_index,
                                           'label': label,
                                           'tokens': row['tokens'],
                                           'annotators': row['annotators']}

# %%
label_dict
# Out:
# {1: {'file_id': 4100,
#   'start_index': 517,
#   'end_index': 520,
#   'label': 'FAC 2',
#   'tokens': 0    [niet, zonder, steun]
#   Name: tokens, dtype: object,
#   'annotators': {'bos'}},
#  2: {'file_id': 4100,
#   'start_index': 507,
#   'end_index': 507,
#   'label': 'type\\Implicit',
#   'tokens': 0    [mobiliseren]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  3: {'file_id': 4100,
#   'start_index': 556,
#   'end_index': 558,
#   'label': 'type\\Implicit',
#   'tokens': ['onvermogen', 'te', 'mobiliseren'],
#   'annotators': {'swartjes'}},
#  4: {'file_id': 4100,
#   'start_index': 263,
#   'end_index': 282,
#   'label': 'view\\Patient',
#   'tokens': 0    [Patient, geeft, aan, op, linkerzij, gevallen,...
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  5: {'file_id': 4100,
#   'start_index': 510,
#   'end_index': 513,
#   'label': 'view\\Patient',
#   'tokens': ['pijn', 'aan', 'in', 'linkerheup'],
#   'annotators': {'katsburg'}},
#  6: {'file_id': 4100,
#   'start_index': 515,
#   'end_index': 524,
#   'label': 'FAC 1',
#   'tokens': 0    [Kan, hierdoor, niet, zonder, steun]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'swartjes', 'vanderpas'}},
#  7: {'file_id': 4100,
#   'start_index': 157,
#   'end_index': 158,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': 0    [Patiente, fietste]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  8: {'file_id': 4100,
#   'start_index': 507,
#   'end_index': 507,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': 0    [mobiliseren]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vanderpas'}},
#  9: {'file_id': 4100,
#   'start_index': 515,
#   'end_index': 520,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['Kan', 'hierdoor', 'niet', 'zonder', 'steun', 'lopen'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vanderpas'}},
#  10: {'file_id': 4100,
#   'start_index': 557,
#   'end_index': 558,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['te', 'mobiliseren'],
#   'annotators': {'katsburg', 'swartjes'}},
#  11: {'file_id': 4103,
#   'start_index': 946,
#   'end_index': 946,
#   'label': '.D840-859: Beroep en werk',
#   'tokens': 0    [Beroep]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli'}},
#  12: {'file_id': 4103,
#   'start_index': 950,
#   'end_index': 953,
#   'label': '.D840-859: Beroep en werk',
#   'tokens': ['Opleiding', ':', 'hoger', 'onderwijs'],
#   'annotators': {'avelli'}},
#  13: {'file_id': 4103,
#   'start_index': 969,
#   'end_index': 973,
#   'label': 'INS 3',
#   'tokens': 0    [Rijdt, auto, en, fietst, normaliter]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  14: {'file_id': 4103,
#   'start_index': 533,
#   'end_index': 538,
#   'label': 'STM 0',
#   'tokens': 0    [Patient, is, al, anderhalf, jaar, somber]
#   Name: tokens, dtype: object,
#   'annotators': {'bos'}},
#  15: {'file_id': 4103,
#   'start_index': 541,
#   'end_index': 996,
#   'label': 'STM 0',
#   'tokens': ['veel', 'verdriet'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vanderpas'}},
#  16: {'file_id': 4103,
#   'start_index': 338,
#   'end_index': 996,
#   'label': '.B152: Stemming',
#   'tokens': 0    [hij, zit, vol, zorgen]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  17: {'file_id': 4103,
#   'start_index': 1006,
#   'end_index': 1006,
#   'label': '.B152: Stemming',
#   'tokens': ['boos'],
#   'annotators': {'avelli', 'bos', 'katsburg', 'swartjes'}},
#  18: {'file_id': 4103,
#   'start_index': 338,
#   'end_index': 341,
#   'label': 'type\\Implicit',
#   'tokens': 0    [hij, zit, vol, zorgen]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  19: {'file_id': 4103,
#   'start_index': 559,
#   'end_index': 567,
#   'label': 'type\\Implicit',
#   'tokens': ['vermogen',
#    'om',
#    'te',
#    'genieten',
#    'is',
#    'nu',
#    'ook',
#    'wel',
#    'minder'],
#   'annotators': {'meskers'}},
#  20: {'file_id': 4103,
#   'start_index': 570,
#   'end_index': 571,
#   'label': 'type\\Implicit',
#   'tokens': ['piekert', 'veel'],
#   'annotators': {'katsburg'}},
#  21: {'file_id': 4103,
#   'start_index': 578,
#   'end_index': 588,
#   'label': 'type\\Implicit',
#   'tokens': ['energie', 'is', 'verminderd'],
#   'annotators': {'katsburg', 'meskers'}},
#  22: {'file_id': 4103,
#   'start_index': 843,
#   'end_index': 844,
#   'label': 'type\\Implicit',
#   'tokens': ['overdag', 'vermoeid'],
#   'annotators': {'meskers'}},
#  23: {'file_id': 4103,
#   'start_index': 995,
#   'end_index': 996,
#   'label': 'type\\Implicit',
#   'tokens': ['ernstige', 'zorgen'],
#   'annotators': {'katsburg'}},
#  24: {'file_id': 4103,
#   'start_index': 1097,
#   'end_index': 1098,
#   'label': 'type\\Implicit',
#   'tokens': ['stijf', 'bij'],
#   'annotators': {'meskers'}},
#  25: {'file_id': 4103,
#   'start_index': 382,
#   'end_index': 396,
#   'label': 'stm\\reaction',
#   'tokens': 0    [Hij, heeft, gelezen, over, de, relatie, slaap...
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'meskers', 'opsomer', 'swartjes', 'vervaart'}},
#  26: {'file_id': 4103,
#   'start_index': 540,
#   'end_index': 545,
#   'label': 'stm\\reaction',
#   'tokens': ['heeft', 'veel', 'verdriet', 'om', 'zijn', 'vrouw'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vanderpas'}},
#  27: {'file_id': 4103,
#   'start_index': 608,
#   'end_index': 612,
#   'label': 'stm\\reaction',
#   'tokens': ['of', 'de', 'kanker', 'terug', 'komt'],
#   'annotators': {'meskers', 'swartjes', 'vanderpas'}},
#  28: {'file_id': 4103,
#   'start_index': 698,
#   'end_index': 704,
#   'label': 'stm\\reaction',
#   'tokens': ['op', 'hem', 'dat', 'ze', 'niet', 'mag', 'autorijden'],
#   'annotators': {'katsburg', 'swartjes'}},
#  29: {'file_id': 4103,
#   'start_index': 864,
#   'end_index': 869,
#   'label': 'stm\\reaction',
#   'tokens': ['dat', 'hij', 'niet', 'meer', 'mag', 'autorijden'],
#   'annotators': {'avelli', 'katsburg', 'meskers', 'swartjes', 'vervaart'}},
#  30: {'file_id': 4103,
#   'start_index': 997,
#   'end_index': 998,
#   'label': 'stm\\reaction',
#   'tokens': ['over', 'haar'],
#   'annotators': {'avelli', 'meskers', 'swartjes'}},
#  31: {'file_id': 4103,
#   'start_index': 357,
#   'end_index': 357,
#   'label': 'INS 1',
#   'tokens': 0    [vermoeid]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  32: {'file_id': 4103,
#   'start_index': 578,
#   'end_index': 580,
#   'label': 'INS 1',
#   'tokens': ['energie', 'is', 'verminderd'],
#   'annotators': {'katsburg'}},
#  33: {'file_id': 4103,
#   'start_index': 844,
#   'end_index': 844,
#   'label': 'INS 1',
#   'tokens': ['vermoeid'],
#   'annotators': {'katsburg'}},
#  34: {'file_id': 4103,
#   'start_index': 1097,
#   'end_index': 1099,
#   'label': 'FAC 4',
#   'tokens': 0    [stijf, bij]
#   Name: tokens, dtype: object,
#   'annotators': {'vervaart'}},
#  35: {'file_id': 4103,
#   'start_index': 1273,
#   'end_index': 1275,
#   'label': 'FAC 4',
#   'tokens': ['stijf', 'en', 'antalgisch'],
#   'annotators': {'meskers'}},
#  36: {'file_id': 4103,
#   'start_index': 357,
#   'end_index': 357,
#   'label': 'INS 2',
#   'tokens': 0    [vermoeid]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  37: {'file_id': 4103,
#   'start_index': 579,
#   'end_index': 587,
#   'label': 'INS 2',
#   'tokens': ['is',
#    'verminderd',
#    ',',
#    'hij',
#    'kan',
#    'minder',
#    'aan',
#    'dan',
#    'normaal'],
#   'annotators': {'meskers'}},
#  38: {'file_id': 4103,
#   'start_index': 843,
#   'end_index': 843,
#   'label': 'INS 2',
#   'tokens': ['overdag'],
#   'annotators': {'meskers'}},
#  39: {'file_id': 4103,
#   'start_index': 338,
#   'end_index': 341,
#   'label': 'view\\Patient',
#   'tokens': 0    [hij, zit, vol, zorgen]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  40: {'file_id': 4103,
#   'start_index': 355,
#   'end_index': 357,
#   'label': 'view\\Patient',
#   'tokens': ['voelt', 'zich', 'vermoeid'],
#   'annotators': {'meskers'}},
#  41: {'file_id': 4103,
#   'start_index': 547,
#   'end_index': 568,
#   'label': 'view\\Patient',
#   'tokens': ['Er',
#    'is',
#    'een',
#    'tijd',
#    'geweest',
#    'dat',
#    'hij',
#    'nergens',
#    'zin',
#    'in',
#    'had',
#    ',',
#    'vermogen',
#    'om',
#    'te',
#    'genieten',
#    'is',
#    'nu',
#    'ook',
#    'wel',
#    'minder',
#    '.'],
#   'annotators': {'meskers'}},
#  42: {'file_id': 4103,
#   'start_index': 569,
#   'end_index': 576,
#   'label': 'view\\Patient',
#   'tokens': ['Hij', 'piekert', 'veel', 'en', 'voelt', 'zich', 'schuldig', '.'],
#   'annotators': {'meskers'}},
#  43: {'file_id': 4103,
#   'start_index': 577,
#   'end_index': 587,
#   'label': 'view\\Patient',
#   'tokens': ['Zijn',
#    'energie',
#    'is',
#    'verminderd',
#    ',',
#    'hij',
#    'kan',
#    'minder',
#    'aan',
#    'dan',
#    'normaal'],
#   'annotators': {'meskers'}},
#  44: {'file_id': 4103,
#   'start_index': 594,
#   'end_index': 601,
#   'label': 'view\\Patient',
#   'tokens': ['Patient',
#    'ontkent',
#    'doodsgedachten',
#    ',',
#    'heeft',
#    'geen',
#    'rusteloos',
#    'gevoel'],
#   'annotators': {'katsburg'}},
#  45: {'file_id': 4103,
#   'start_index': 603,
#   'end_index': 613,
#   'label': 'view\\Patient',
#   'tokens': ['Hij',
#    'is',
#    'wel',
#    'enigzins',
#    'bezorgd',
#    'of',
#    'de',
#    'kanker',
#    'terug',
#    'komt',
#    '.'],
#   'annotators': {'meskers'}},
#  46: {'file_id': 4103,
#   'start_index': 666,
#   'end_index': 677,
#   'label': 'view\\Patient',
#   'tokens': ['patient',
#    'is',
#    'het',
#    'er',
#    'niet',
#    'mee',
#    'eens',
#    ',',
#    'verzet',
#    'zich',
#    'er',
#    'tegen'],
#   'annotators': {'katsburg'}},
#  47: {'file_id': 4103,
#   'start_index': 679,
#   'end_index': 692,
#   'label': 'view\\Patient',
#   'tokens': ['Hij',
#    'vindt',
#    'haar',
#    'te',
#    'goed',
#    'voor',
#    'een',
#    'verpleeghuis',
#    ',',
#    'kan',
#    'deze',
#    'beslissing',
#    'niet',
#    'accepteren'],
#   'annotators': {'katsburg'}},
#  48: {'file_id': 4103,
#   'start_index': 694,
#   'end_index': 704,
#   'label': 'view\\Patient',
#   'tokens': ['Zijn',
#    'vrouw',
#    'is',
#    'kwaad',
#    'op',
#    'hem',
#    'dat',
#    'ze',
#    'niet',
#    'mag',
#    'autorijden'],
#   'annotators': {'swartjes'}},
#  49: {'file_id': 4103,
#   'start_index': 735,
#   'end_index': 746,
#   'label': 'view\\Patient',
#   'tokens': ['Patient',
#    'zoekt',
#    'iemand',
#    'om',
#    'zijn',
#    'vrouw',
#    'te',
#    'overtuigen',
#    'dat',
#    'ze',
#    'ziek',
#    'is'],
#   'annotators': {'katsburg'}},
#  50: {'file_id': 4103,
#   'start_index': 1000,
#   'end_index': 1010,
#   'label': 'view\\Patient',
#   'tokens': ['Belt',
#    'dagelijks',
#    ',',
#    'zij',
#    'wordt',
#    'dan',
#    'boos',
#    'en',
#    'eist',
#    'de',
#    'autosleutels'],
#   'annotators': {'swartjes'}},
#  51: {'file_id': 4103,
#   'start_index': 338,
#   'end_index': 341,
#   'label': 'STM 1',
#   'tokens': 0    [hij, zit, vol, zorgen]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers', 'swartjes'}},
#  52: {'file_id': 4103,
#   'start_index': 395,
#   'end_index': 395,
#   'label': 'STM 1',
#   'tokens': ['bang'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  53: {'file_id': 4103,
#   'start_index': 538,
#   'end_index': 538,
#   'label': 'STM 1',
#   'tokens': ['somber'],
#   'annotators': {'avelli', 'katsburg', 'meskers', 'swartjes', 'vervaart'}},
#  54: {'file_id': 4103,
#   'start_index': 559,
#   'end_index': 607,
#   'label': 'STM 1',
#   'tokens': ['vermogen',
#    'om',
#    'te',
#    'genieten',
#    'is',
#    'nu',
#    'ook',
#    'wel',
#    'minder'],
#   'annotators': {'katsburg', 'meskers', 'swartjes', 'vanderpas'}},
#  55: {'file_id': 4103,
#   'start_index': 697,
#   'end_index': 697,
#   'label': 'STM 1',
#   'tokens': ['kwaad'],
#   'annotators': {'katsburg', 'swartjes'}},
#  56: {'file_id': 4103,
#   'start_index': 863,
#   'end_index': 863,
#   'label': 'STM 1',
#   'tokens': ['bang'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vervaart'}},
#  57: {'file_id': 4103,
#   'start_index': 995,
#   'end_index': 996,
#   'label': 'STM 1',
#   'tokens': ['ernstige', 'zorgen'],
#   'annotators': {'katsburg'}},
#  58: {'file_id': 4103,
#   'start_index': 1006,
#   'end_index': 1006,
#   'label': 'STM 1',
#   'tokens': ['boos'],
#   'annotators': {'avelli', 'bos', 'katsburg', 'swartjes'}},
#  59: {'file_id': 4103,
#   'start_index': 694,
#   'end_index': 704,
#   'label': 'view\\Third party',
#   'tokens': 0    [Zijn, vrouw, is, kwaad, op, hem, dat, ze, nie...
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  60: {'file_id': 4103,
#   'start_index': 786,
#   'end_index': 796,
#   'label': 'view\\Third party',
#   'tokens': ['Hij',
#    'is',
#    'volledig',
#    'overbelast',
#    'als',
#    'mantelzorger',
#    'en',
#    'heeft',
#    'weinig',
#    'ziekte',
#    'inzicht'],
#   'annotators': {'swartjes'}},
#  61: {'file_id': 4103,
#   'start_index': 833,
#   'end_index': 844,
#   'label': 'view\\Third party',
#   'tokens': ['Hij',
#    'slaapt',
#    'al',
#    'jaren',
#    'heel',
#    'slecht',
#    ',',
#    'hierdoor',
#    'is',
#    'hij',
#    'overdag',
#    'vermoeid'],
#   'annotators': {'swartjes'}},
#  62: {'file_id': 4103,
#   'start_index': 861,
#   'end_index': 869,
#   'label': 'view\\Third party',
#   'tokens': ['Hij',
#    'is',
#    'bang',
#    'dat',
#    'hij',
#    'niet',
#    'meer',
#    'mag',
#    'autorijden'],
#   'annotators': {'swartjes'}},
#  63: {'file_id': 4103,
#   'start_index': 355,
#   'end_index': 986,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': 0    [voelt, zich, vermoeid]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'katsburg', 'meskers', 'swartjes'}},
#  64: {'file_id': 4103,
#   'start_index': 1106,
#   'end_index': 1108,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': ['aan', 'en', 'uitkleden'],
#   'annotators': {'swartjes'}},
#  65: {'file_id': 4103,
#   'start_index': 1100,
#   'end_index': 1271,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': 0    [lopen]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'meskers'}},
#  66: {'file_id': 2570,
#   'start_index': 333,
#   'end_index': 337,
#   'label': 'FAC 2',
#   'tokens': 0    [met, rollator, binnen, en, buitenshuis]
#   Name: tokens, dtype: object,
#   'annotators': {'bos'}},
#  67: {'file_id': 2570,
#   'start_index': 592,
#   'end_index': 593,
#   'label': 'FAC 2',
#   'tokens': ['met', 'hulpmiddel'],
#   'annotators': {'bos'}},
#  68: {'file_id': 2570,
#   'start_index': 132,
#   'end_index': 132,
#   'label': 'type\\Implicit',
#   'tokens': 0    [dwarslaesie]
#   Name: tokens, dtype: object,
#   'annotators': {'vanderpas'}},
#  69: {'file_id': 2570,
#   'start_index': 166,
#   'end_index': 176,
#   'label': 'type\\Implicit',
#   'tokens': ['Overweging',
#    'botox',
#    'om',
#    'spieren',
#    'te',
#    'verslappen',
#    'om',
#    'lopen',
#    'te',
#    'verbeteren',
#    '.'],
#   'annotators': {'vanderpas'}},
#  70: {'file_id': 2570,
#   'start_index': 196,
#   'end_index': 202,
#   'label': 'type\\Implicit',
#   'tokens': ['Zij', 'kan', 'daardoor', 'de', 'benen', 'moeilijk', 'sturen'],
#   'annotators': {'avelli', 'katsburg', 'vanderpas'}},
#  71: {'file_id': 2570,
#   'start_index': 332,
#   'end_index': 337,
#   'label': 'FAC 4',
#   'tokens': 0    [lopen, met, rollator]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'meskers', 'opsomer', 'swartjes'}},
#  72: {'file_id': 2570,
#   'start_index': 503,
#   'end_index': 504,
#   'label': 'FAC 4',
#   'tokens': ['stuntelig', 'looppatroon'],
#   'annotators': {'meskers'}},
#  73: {'file_id': 2570,
#   'start_index': 592,
#   'end_index': 593,
#   'label': 'FAC 4',
#   'tokens': ['met', 'hulpmiddel'],
#   'annotators': {'meskers', 'swartjes'}},
#  74: {'file_id': 2570,
#   'start_index': 333,
#   'end_index': 334,
#   'label': 'FAC 1',
#   'tokens': 0    [met, rollator]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli'}},
#  75: {'file_id': 2570,
#   'start_index': 503,
#   'end_index': 504,
#   'label': 'FAC 1',
#   'tokens': ['stuntelig', 'looppatroon'],
#   'annotators': {'avelli'}},
#  76: {'file_id': 2570,
#   'start_index': 592,
#   'end_index': 593,
#   'label': 'FAC 1',
#   'tokens': ['met', 'hulpmiddel'],
#   'annotators': {'avelli'}},
#  77: {'file_id': 2570,
#   'start_index': 92,
#   'end_index': 92,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': 0    [looppatroon]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli'}},
#  78: {'file_id': 2570,
#   'start_index': 132,
#   'end_index': 132,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['dwarslaesie'],
#   'annotators': {'avelli'}},
#  79: {'file_id': 2570,
#   'start_index': 166,
#   'end_index': 593,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['Overweging',
#    'botox',
#    'om',
#    'spieren',
#    'te',
#    'verslappen',
#    'om',
#    'lopen',
#    'te',
#    'verbeteren'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  80: {'file_id': 4618,
#   'start_index': 315,
#   'end_index': 402,
#   'label': '.B152: Stemming',
#   'tokens': 0    [snel, emotioneel]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'katsburg', 'swartjes', 'vervaart'}},
#  81: {'file_id': 4618,
#   'start_index': 315,
#   'end_index': 316,
#   'label': 'STM 1',
#   'tokens': 0    [snel]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'katsburg', 'vanderpas', 'vervaart'}},
#  82: {'file_id': 3598,
#   'start_index': 83,
#   'end_index': 84,
#   'label': 'STM 1',
#   'tokens': 0    [is, emotioneel]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'swartjes'}},
#  83: {'file_id': 3598,
#   'start_index': 83,
#   'end_index': 84,
#   'label': '.B152: Stemming',
#   'tokens': 0    [is, emotioneel]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'swartjes', 'vervaart'}},
#  84: {'file_id': 3097,
#   'start_index': 2,
#   'end_index': 5,
#   'label': '.B152: Stemming',
#   'tokens': 0    [Dhr, voelt, zich, goed]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  85: {'file_id': 3097,
#   'start_index': 2,
#   'end_index': 5,
#   'label': 'STM 3',
#   'tokens': 0    [Dhr, voelt, zich, goed]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'opsomer', 'swartjes', 'vervaart'}},
#  86: {'file_id': 2607,
#   'start_index': 12,
#   'end_index': 26,
#   'label': 'type\\Implicit',
#   'tokens': 0    [Gaf, na, een, tijdje, gelopen, te, hebben, aa...
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  87: {'file_id': 2607,
#   'start_index': 12,
#   'end_index': 25,
#   'label': 'FAC 4',
#   'tokens': 0    [Gaf, na, een, tijdje, gelopen, te, hebben]
#   Name: tokens, dtype: object,
#   'annotators': {'bos', 'katsburg', 'meskers', 'swartjes', 'vervaart'}},
#  88: {'file_id': 2607,
#   'start_index': 12,
#   'end_index': 26,
#   'label': 'view\\Patient',
#   'tokens': 0    [Gaf, na, een, tijdje, gelopen, te, hebben, aa...
#   Name: tokens, dtype: object,
#   'annotators': {'avelli'}},
#  89: {'file_id': 2607,
#   'start_index': 144,
#   'end_index': 150,
#   'label': 'view\\Patient',
#   'tokens': ['vindt', 'dit', 'zelf', 'wel', 'een', 'beetje', 'snel'],
#   'annotators': {'katsburg'}},
#  90: {'file_id': 2607,
#   'start_index': 12,
#   'end_index': 25,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': 0    [Gaf, na, een, tijdje, gelopen, te, hebben, aa...
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  91: {'file_id': 2607,
#   'start_index': 93,
#   'end_index': 93,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['Transfer'],
#   'annotators': {'bos'}},
#  92: {'file_id': 4145,
#   'start_index': 132,
#   'end_index': 133,
#   'label': 'STM 2',
#   'tokens': 0    [Rustig]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  93: {'file_id': 4145,
#   'start_index': 132,
#   'end_index': 133,
#   'label': '.B152: Stemming',
#   'tokens': 0    [Rustig, aanwezig]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  94: {'file_id': 2610,
#   'start_index': 4,
#   'end_index': 7,
#   'label': 'STM 1',
#   'tokens': 0    [Mw, heeft, paniek, aanvallen]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli'}},
#  95: {'file_id': 2610,
#   'start_index': 22,
#   'end_index': 24,
#   'label': 'STM 1',
#   'tokens': ['vicieuze', 'cirkel', 'van'],
#   'annotators': {'opsomer'}},
#  96: {'file_id': 2610,
#   'start_index': 25,
#   'end_index': 25,
#   'label': 'STM 1',
#   'tokens': ['angst'],
#   'annotators': {'avelli', 'bos', 'vervaart'}},
#  97: {'file_id': 2610,
#   'start_index': 4,
#   'end_index': 7,
#   'label': 'STM 0',
#   'tokens': 0    [Mw, heeft, paniek, aanvallen]
#   Name: tokens, dtype: object,
#   'annotators': {'opsomer', 'swartjes'}},
#  98: {'file_id': 2610,
#   'start_index': 17,
#   'end_index': 27,
#   'label': 'STM 0',
#   'tokens': ['dan',
#    'zit',
#    'ze',
#    'in',
#    'een',
#    'vicieuze',
#    'cirkel',
#    'van',
#    'angst'],
#   'annotators': {'katsburg', 'meskers', 'swartjes'}},
#  99: {'file_id': 2610,
#   'start_index': 4,
#   'end_index': 7,
#   'label': '.B152: Stemming',
#   'tokens': 0    [Mw, heeft, paniek, aanvallen]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'opsomer', 'swartjes'}},
#  100: {'file_id': 2610,
#   'start_index': 17,
#   'end_index': 27,
#   'label': '.B152: Stemming',
#   'tokens': ['dan',
#    'zit',
#    'ze',
#    'in',
#    'een',
#    'vicieuze',
#    'cirkel',
#    'van',
#    'angst'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  101: {'file_id': 2610,
#   'start_index': 6,
#   'end_index': 7,
#   'label': 'stm\\reaction',
#   'tokens': 0    [paniek, aanvallen]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  102: {'file_id': 2610,
#   'start_index': 10,
#   'end_index': 14,
#   'label': 'stm\\reaction',
#   'tokens': ['ze', 'erg', 'benauwd', 'van', 'wordt'],
#   'annotators': {'katsburg'}},
#  103: {'file_id': 2616,
#   'start_index': 127,
#   'end_index': 129,
#   'label': '.B152: Stemming',
#   'tokens': 0    [Adequaat, en, coöperatief]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vervaart'}},
#  104: {'file_id': 2616,
#   'start_index': 172,
#   'end_index': 172,
#   'label': '.B152: Stemming',
#   'tokens': ['angstig'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vervaart'}},
#  105: {'file_id': 2616,
#   'start_index': 155,
#   'end_index': 160,
#   'label': 'FAC 3',
#   'tokens': 0    [+, looprek, ,, veilig, en, zelfstandig]
#   Name: tokens, dtype: object,
#   'annotators': {'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  106: {'file_id': 2616,
#   'start_index': 162,
#   'end_index': 170,
#   'label': 'FAC 3',
#   'tokens': ['+',
#    'looprek',
#    ',',
#    'FAC',
#    '3',
#    ',',
#    'veilig',
#    'en',
#    'zelfstandig'],
#   'annotators': {'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  107: {'file_id': 2616,
#   'start_index': 206,
#   'end_index': 213,
#   'label': 'FAC 3',
#   'tokens': ['onder', 'toezicht', 'van', '1', 'persoon'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  108: {'file_id': 2616,
#   'start_index': 154,
#   'end_index': 224,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': 0    [Transfers]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  109: {'file_id': 3133,
#   'start_index': 656,
#   'end_index': 666,
#   'label': '.D840-859: Beroep en werk',
#   'tokens': 0    [Patiënte, heeft, gewerkt, als, verzorgende, e...
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes', 'vervaart'}},
#  110: {'file_id': 3133,
#   'start_index': 212,
#   'end_index': 212,
#   'label': 'STM 0',
#   'tokens': 0    [toenemende]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'swartjes'}},
#  111: {'file_id': 3133,
#   'start_index': 1264,
#   'end_index': 1264,
#   'label': 'STM 0',
#   'tokens': ['angststoornis'],
#   'annotators': {'katsburg', 'swartjes'}},
#  112: {'file_id': 3133,
#   'start_index': 108,
#   'end_index': 108,
#   'label': '.B152: Stemming',
#   'tokens': 0    [twijfelachtig]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  113: {'file_id': 3133,
#   'start_index': 212,
#   'end_index': 986,
#   'label': '.B152: Stemming',
#   'tokens': ['toenemende', 'angstklachten'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  114: {'file_id': 3133,
#   'start_index': 1198,
#   'end_index': 1201,
#   'label': '.B152: Stemming',
#   'tokens': ['last', 'heeft', 'van', 'angst'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vervaart'}},
#  115: {'file_id': 3133,
#   'start_index': 1208,
#   'end_index': 1208,
#   'label': '.B152: Stemming',
#   'tokens': ['angstklachten'],
#   'annotators': {'swartjes', 'vervaart'}},
#  116: {'file_id': 3133,
#   'start_index': 1264,
#   'end_index': 1264,
#   'label': '.B152: Stemming',
#   'tokens': ['angststoornis'],
#   'annotators': {'katsburg', 'swartjes'}},
#  117: {'file_id': 3133,
#   'start_index': 214,
#   'end_index': 220,
#   'label': 'stm\\reaction',
#   'tokens': 0    [sinds, het, ontdekken, van, een, glioblastoma...
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'vanderpas'}},
#  118: {'file_id': 3133,
#   'start_index': 252,
#   'end_index': 260,
#   'label': 'stm\\reaction',
#   'tokens': ['Dit',
#    'is',
#    'ontstaan',
#    'na',
#    'de',
#    'behandeling',
#    'van',
#    'haar',
#    'hersentumor'],
#   'annotators': {'avelli', 'bos', 'vanderpas'}},
#  119: {'file_id': 3133,
#   'start_index': 309,
#   'end_index': 314,
#   'label': 'stm\\reaction',
#   'tokens': ['bang', 'is', 'geworden', 'in', 'het', 'verkeer'],
#   'annotators': {'opsomer', 'swartjes', 'vervaart'}},
#  120: {'file_id': 3133,
#   'start_index': 316,
#   'end_index': 328,
#   'label': 'stm\\reaction',
#   'tokens': ['omdat',
#    'ze',
#    'vreest',
#    'overal',
#    'tegenaan',
#    'te',
#    'botsen',
#    'of',
#    'een',
#    'ongeluk',
#    'te',
#    'veroorzaken'],
#   'annotators': {'bos', 'katsburg', 'meskers', 'swartjes'}},
#  121: {'file_id': 3133,
#   'start_index': 442,
#   'end_index': 454,
#   'label': 'stm\\reaction',
#   'tokens': ['dat',
#    'ze',
#    'nooit',
#    'meer',
#    'zo',
#    'actief',
#    'zal',
#    'zijn',
#    'als',
#    'voor',
#    'de',
#    'operatie'],
#   'annotators': {'avelli', 'meskers'}},
#  122: {'file_id': 3133,
#   'start_index': 465,
#   'end_index': 472,
#   'label': 'stm\\reaction',
#   'tokens': ['van', 'buiten', 'zijn', 'en', 'werken', 'in', 'de', 'tuin'],
#   'annotators': {'katsburg', 'meskers'}},
#  123: {'file_id': 3133,
#   'start_index': 528,
#   'end_index': 555,
#   'label': 'stm\\reaction',
#   'tokens': ['Voordat',
#    'de',
#    'hersentumor',
#    'bij',
#    'patiënt',
#    'gediagnosticeerd',
#    'werd',
#    ',',
#    'voelde',
#    'zij',
#    'zich',
#    'miskend',
#    'door',
#    'de',
#    'huisarts',
#    'en',
#    'andere',
#    'zorgverleners',
#    ',',
#    'wat',
#    'versterkt',
#    'is',
#    'na',
#    'het',
#    'stellen',
#    'van',
#    'de',
#    'diagnose'],
#   'annotators': {'katsburg', 'meskers', 'vervaart'}},
#  124: {'file_id': 3133,
#   'start_index': 575,
#   'end_index': 586,
#   'label': 'stm\\reaction',
#   'tokens': ['dat',
#    'het',
#    'praten',
#    'over',
#    'die',
#    'periode',
#    'veel',
#    'spanning',
#    'met',
#    'zich',
#    'meebrengt',
#    '.'],
#   'annotators': {'katsburg', 'meskers'}},
#  125: {'file_id': 3133,
#   'start_index': 615,
#   'end_index': 624,
#   'label': 'stm\\reaction',
#   'tokens': ['Hij',
#    'merkt',
#    'dat',
#    'de',
#    'cognitieve',
#    'problemen',
#    'haar',
#    'ook',
#    'angstig',
#    'maken'],
#   'annotators': {'avelli', 'meskers', 'opsomer', 'swartjes'}},
#  126: {'file_id': 3133,
#   'start_index': 1189,
#   'end_index': 1194,
#   'label': 'stm\\reaction',
#   'tokens': ['status', 'na', 'behandeling', 'van', 'een', 'glioblastoom'],
#   'annotators': {'bos'}},
#  127: {'file_id': 3133,
#   'start_index': 567,
#   'end_index': 586,
#   'label': 'type\\Implicit',
#   'tokens': 0    [maar, het, is, duidelijk, aan, haar, te, merk...
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  128: {'file_id': 3133,
#   'start_index': 849,
#   'end_index': 851,
#   'label': 'type\\Implicit',
#   'tokens': ['lachte', 'patiënte', 'veel'],
#   'annotators': {'katsburg'}},
#  129: {'file_id': 3133,
#   'start_index': 1264,
#   'end_index': 1264,
#   'label': 'type\\Implicit',
#   'tokens': ['angststoornis'],
#   'annotators': {'katsburg'}},
#  130: {'file_id': 3133,
#   'start_index': 98,
#   'end_index': 116,
#   'label': 'view\\Patient',
#   'tokens': 0    [Later, benoemt, patiënte, dat, zij, zich, afv...
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'meskers', 'opsomer', 'vanderpas', 'vervaart'}},
#  131: {'file_id': 3133,
#   'start_index': 239,
#   'end_index': 250,
#   'label': 'view\\Patient',
#   'tokens': ['Patiënte',
#    'geeft',
#    'aan',
#    'last',
#    'te',
#    'hebben',
#    'van',
#    'vergeetachtigheid',
#    ',',
#    'twijfel',
#    'en',
#    'angst'],
#   'annotators': {'katsburg', 'meskers', 'opsomer', 'vanderpas', 'vervaart'}},
#  132: {'file_id': 3133,
#   'start_index': 274,
#   'end_index': 280,
#   'label': 'view\\Patient',
#   'tokens': ['ze', 'toen', 'volgens', 'zichzelf', 'niet', 'veel', 'deed'],
#   'annotators': {'katsburg'}},
#  133: {'file_id': 3133,
#   'start_index': 309,
#   'end_index': 328,
#   'label': 'view\\Patient',
#   'tokens': ['bang',
#    'is',
#    'geworden',
#    'in',
#    'het',
#    'verkeer',
#    ',',
#    'omdat',
#    'ze',
#    'vreest',
#    'overal',
#    'tegenaan',
#    'te',
#    'botsen',
#    'of',
#    'een',
#    'ongeluk',
#    'te',
#    'veroorzaken',
#    '.'],
#   'annotators': {'meskers'}},
#  134: {'file_id': 3133,
#   'start_index': 398,
#   'end_index': 405,
#   'label': 'view\\Patient',
#   'tokens': ['Ze', 'zegt', 'ook', 'niet', 'tegen', 'drukte', 'te', 'kunnen'],
#   'annotators': {'katsburg'}},
#  135: {'file_id': 3133,
#   'start_index': 426,
#   'end_index': 437,
#   'label': 'view\\Patient',
#   'tokens': ['Als',
#    'belangrijkste',
#    'klacht',
#    'benoemt',
#    'ze',
#    'haar',
#    'twijfel',
#    'bij',
#    'het',
#    'nemen',
#    'van',
#    'beslissingen'],
#   'annotators': {'katsburg'}},
#  136: {'file_id': 3133,
#   'start_index': 439,
#   'end_index': 454,
#   'label': 'view\\Patient',
#   'tokens': ['Ze',
#    'is',
#    'bang',
#    'dat',
#    'ze',
#    'nooit',
#    'meer',
#    'zo',
#    'actief',
#    'zal',
#    'zijn',
#    'als',
#    'voor',
#    'de',
#    'operatie',
#    '.'],
#   'annotators': {'meskers'}},
#  137: {'file_id': 3133,
#   'start_index': 455,
#   'end_index': 460,
#   'label': 'view\\Patient',
#   'tokens': ['Momenteel', 'vindt', 'zij', 'zichzelf', 'niet', 'depressief'],
#   'annotators': {'katsburg', 'meskers', 'vervaart'}},
#  138: {'file_id': 3133,
#   'start_index': 462,
#   'end_index': 473,
#   'label': 'view\\Patient',
#   'tokens': ['Ze',
#    'kan',
#    'genieten',
#    'van',
#    'buiten',
#    'zijn',
#    'en',
#    'werken',
#    'in',
#    'de',
#    'tuin',
#    ','],
#   'annotators': {'meskers'}},
#  139: {'file_id': 3133,
#   'start_index': 483,
#   'end_index': 526,
#   'label': 'view\\Patient',
#   'tokens': ['Ze',
#    'heeft',
#    'het',
#    'idee',
#    'dat',
#    'het',
#    'anti-epilepticum',
#    'dat',
#    'ze',
#    'gebruikt',
#    '(',
#    'levetiracetam',
#    '(',
#    'KEPPRA',
#    ')',
#    '500',
#    'mg',
#    'tablet',
#    ',',
#    '2dd',
#    ')',
#    'mogelijk',
#    'een',
#    'rol',
#    'zou',
#    'kunnen',
#    'spelen',
#    'bij',
#    'haar',
#    'klachten',
#    ',',
#    'maar',
#    'het',
#    'zou',
#    'volgens',
#    'haar',
#    'neuroloog',
#    'niet',
#    'gestopt',
#    'kunnen',
#    'worden',
#    ',',
#    'aldus',
#    'patiënte'],
#   'annotators': {'katsburg'}},
#  140: {'file_id': 3133,
#   'start_index': 557,
#   'end_index': 565,
#   'label': 'view\\Patient',
#   'tokens': ['Ze',
#    'geeft',
#    'aan',
#    'dat',
#    'het',
#    'haar',
#    'niet',
#    'boos',
#    'maakt'],
#   'annotators': {'avelli', 'katsburg', 'meskers', 'swartjes', 'vervaart'}},
#  141: {'file_id': 3133,
#   'start_index': 212,
#   'end_index': 213,
#   'label': 'STM 1',
#   'tokens': 0    [toenemende, angstklachten]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  142: {'file_id': 3133,
#   'start_index': 239,
#   'end_index': 250,
#   'label': 'STM 1',
#   'tokens': ['Patiënte',
#    'geeft',
#    'aan',
#    'last',
#    'te',
#    'hebben',
#    'van',
#    'vergeetachtigheid',
#    ',',
#    'twijfel',
#    'en',
#    'angst'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  143: {'file_id': 3133,
#   'start_index': 309,
#   'end_index': 311,
#   'label': 'STM 1',
#   'tokens': ['bang'],
#   'annotators': {'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  144: {'file_id': 3133,
#   'start_index': 318,
#   'end_index': 318,
#   'label': 'STM 1',
#   'tokens': ['vreest'],
#   'annotators': {'swartjes'}},
#  145: {'file_id': 3133,
#   'start_index': 441,
#   'end_index': 441,
#   'label': 'STM 1',
#   'tokens': ['bang'],
#   'annotators': {'avelli', 'bos', 'katsburg', 'meskers', 'vervaart'}},
#  146: {'file_id': 3133,
#   'start_index': 536,
#   'end_index': 539,
#   'label': 'STM 1',
#   'tokens': ['voelde', 'zij', 'zich', 'miskend'],
#   'annotators': {'avelli', 'katsburg', 'vervaart'}},
#  147: {'file_id': 3133,
#   'start_index': 581,
#   'end_index': 585,
#   'label': 'STM 1',
#   'tokens': ['veel', 'spanning'],
#   'annotators': {'katsburg', 'meskers', 'swartjes'}},
#  148: {'file_id': 3133,
#   'start_index': 623,
#   'end_index': 623,
#   'label': 'STM 1',
#   'tokens': ['angstig'],
#   'annotators': {'avelli',
#    'bos',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  149: {'file_id': 3133,
#   'start_index': 879,
#   'end_index': 897,
#   'label': 'STM 1',
#   'tokens': ['In',
#    'het',
#    'tweede',
#    'gesprek',
#    'was',
#    'ze',
#    'echter',
#    'overwegend',
#    'angstig',
#    'en',
#    'somber',
#    'en',
#    'leek',
#    'haar',
#    'klachtenpresentatie',
#    'wat',
#    'meer',
#    'stemmingscongruent',
#    '.'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  150: {'file_id': 3133,
#   'start_index': 1201,
#   'end_index': 1201,
#   'label': 'STM 1',
#   'tokens': ['angst'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vervaart'}},
#  151: {'file_id': 3133,
#   'start_index': 1208,
#   'end_index': 1208,
#   'label': 'STM 1',
#   'tokens': ['angstklachten'],
#   'annotators': {'swartjes', 'vervaart'}},
#  152: {'file_id': 3133,
#   'start_index': 588,
#   'end_index': 625,
#   'label': 'view\\Third party',
#   'tokens': 0    [Partner, van, patiënte, merkt, dat, zij, dras...
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'meskers', 'opsomer', 'vervaart'}},
#  153: {'file_id': 3133,
#   'start_index': 459,
#   'end_index': 460,
#   'label': 'STM 2',
#   'tokens': 0    [niet, depressief]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'meskers', 'swartjes', 'vervaart'}},
#  154: {'file_id': 3133,
#   'start_index': 563,
#   'end_index': 564,
#   'label': 'STM 2',
#   'tokens': ['niet'],
#   'annotators': {'avelli', 'bos', 'meskers', 'swartjes', 'vervaart'}},
#  155: {'file_id': 3133,
#   'start_index': 975,
#   'end_index': 975,
#   'label': 'STM 2',
#   'tokens': ['normofoor'],
#   'annotators': {'avelli', 'bos', 'meskers', 'swartjes', 'vervaart'}},
#  156: {'file_id': 3133,
#   'start_index': 462,
#   'end_index': 464,
#   'label': 'STM 3',
#   'tokens': 0    [Ze, kan, genieten]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  157: {'file_id': 3133,
#   'start_index': 849,
#   'end_index': 851,
#   'label': 'STM 3',
#   'tokens': ['lachte', 'patiënte', 'veel'],
#   'annotators': {'katsburg', 'swartjes'}},
#  158: {'file_id': 3133,
#   'start_index': 972,
#   'end_index': 985,
#   'label': 'STM 3',
#   'tokens': ['De',
#    'stemming',
#    'is',
#    'normofoor',
#    'met',
#    'tijdens',
#    'het',
#    'eerste',
#    'gesprek',
#    'een',
#    'vrolijk'],
#   'annotators': {'meskers', 'swartjes', 'vanderpas'}},
#  159: {'file_id': 3645,
#   'start_index': 15,
#   'end_index': 15,
#   'label': '.B152: Stemming',
#   'tokens': 0    [onrust/stress]
#   Name: tokens, dtype: object,
#   'annotators': {'opsomer', 'swartjes'}},
#  160: {'file_id': 3645,
#   'start_index': 22,
#   'end_index': 24,
#   'label': '.B152: Stemming',
#   'tokens': ['trekt', 'sonde', 'eruit'],
#   'annotators': {'opsomer', 'swartjes'}},
#  161: {'file_id': 3645,
#   'start_index': 22,
#   'end_index': 25,
#   'label': 'type\\Implicit',
#   'tokens': 0    [trekt, sonde, eruit]
#   Name: tokens, dtype: object,
#   'annotators': {'opsomer'}},
#  162: {'file_id': 3645,
#   'start_index': 15,
#   'end_index': 15,
#   'label': 'STM 1',
#   'tokens': 0    [onrust/stress]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  163: {'file_id': 3645,
#   'start_index': 22,
#   'end_index': 24,
#   'label': 'STM 1',
#   'tokens': ['trekt', 'sonde', 'eruit'],
#   'annotators': {'swartjes'}},
#  164: {'file_id': 4673,
#   'start_index': 45,
#   'end_index': 46,
#   'label': '.B152: Stemming',
#   'tokens': 0    [blijft, gespannen]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes', 'vervaart'}},
#  165: {'file_id': 4673,
#   'start_index': 45,
#   'end_index': 51,
#   'label': 'STM 1',
#   'tokens': 0    [blijft, gespannen]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes', 'vervaart'}},
#  166: {'file_id': 4673,
#   'start_index': 16,
#   'end_index': 17,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': 0    [Voelt, zich]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers', 'swartjes'}},
#  167: {'file_id': 4673,
#   'start_index': 19,
#   'end_index': 19,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': ['moe'],
#   'annotators': {'meskers', 'swartjes'}},
#  168: {'file_id': 2637,
#   'start_index': 5,
#   'end_index': 5,
#   'label': '.B152: Stemming',
#   'tokens': 0    [moe]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  169: {'file_id': 2637,
#   'start_index': 33,
#   'end_index': 36,
#   'label': '.B152: Stemming',
#   'tokens': ['ziet', 'er', 'rustig', 'uit'],
#   'annotators': {'katsburg'}},
#  170: {'file_id': 4175,
#   'start_index': 57,
#   'end_index': 57,
#   'label': '.B152: Stemming',
#   'tokens': 0    [angst]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'meskers', 'swartjes'}},
#  171: {'file_id': 4175,
#   'start_index': 65,
#   'end_index': 65,
#   'label': '.B152: Stemming',
#   'tokens': ['Rust/opluchting'],
#   'annotators': {'katsburg', 'meskers', 'swartjes'}},
#  172: {'file_id': 4688,
#   'start_index': 377,
#   'end_index': 380,
#   'label': '.D840-859: Beroep en werk',
#   'tokens': 0    [Beroep]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli'}},
#  173: {'file_id': 4688,
#   'start_index': 1086,
#   'end_index': 1100,
#   'label': '.B152: Stemming',
#   'tokens': 0    [emoties, geïrriteerd]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  174: {'file_id': 4688,
#   'start_index': 142,
#   'end_index': 144,
#   'label': 'type\\Implicit',
#   'tokens': 0    [Last, van, vermoeidheid]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  175: {'file_id': 4688,
#   'start_index': 393,
#   'end_index': 395,
#   'label': 'type\\Implicit',
#   'tokens': ['komt', 'in', 'rolstoel'],
#   'annotators': {'swartjes'}},
#  176: {'file_id': 4688,
#   'start_index': 1099,
#   'end_index': 1100,
#   'label': 'type\\Implicit',
#   'tokens': ['snel', 'geïrriteerd'],
#   'annotators': {'katsburg'}},
#  177: {'file_id': 4688,
#   'start_index': 140,
#   'end_index': 144,
#   'label': 'INS 2',
#   'tokens': 0    [mn, ., Last, van]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  178: {'file_id': 4688,
#   'start_index': 445,
#   'end_index': 563,
#   'label': 'INS 2',
#   'tokens': ['een', 'beperkte', 'conditie'],
#   'annotators': {'bos', 'katsburg', 'meskers'}},
#  179: {'file_id': 4688,
#   'start_index': 146,
#   'end_index': 151,
#   'label': 'view\\Patient',
#   'tokens': 0    [Wil, liever, niet, meer, behandeld, worden]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  180: {'file_id': 4688,
#   'start_index': 361,
#   'end_index': 365,
#   'label': 'view\\Patient',
#   'tokens': ['dat', 'hij', 'geen', 'alcohol', 'drinkt'],
#   'annotators': {'katsburg'}},
#  181: {'file_id': 4688,
#   'start_index': 450,
#   'end_index': 461,
#   'label': 'view\\Patient',
#   'tokens': ['wil',
#    'hij',
#    'liever',
#    'geen',
#    'verdere',
#    'behandeling',
#    'meer',
#    'ondergaan',
#    ',',
#    'maar',
#    'enkel',
#    'symptoombestrijding'],
#   'annotators': {'katsburg'}},
#  182: {'file_id': 4688,
#   'start_index': 569,
#   'end_index': 575,
#   'label': 'view\\Patient',
#   'tokens': ['wil',
#    'geen',
#    'verdere',
#    'behandeling',
#    'te',
#    'willen',
#    'ondergaan'],
#   'annotators': {'katsburg'}},
#  183: {'file_id': 4688,
#   'start_index': 377,
#   'end_index': 380,
#   'label': 'BER 4',
#   'tokens': 0    [Beroep, :, voormalig, timmerman]
#   Name: tokens, dtype: object,
#   'annotators': {'vervaart'}},
#  184: {'file_id': 4688,
#   'start_index': 131,
#   'end_index': 132,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': 0    [Wast, zichzelf]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vervaart'}},
#  185: {'file_id': 4688,
#   'start_index': 142,
#   'end_index': 563,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': ['Last', 'van', 'vermoeidheid'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'swartjes',
#    'vervaart'}},
#  186: {'file_id': 4688,
#   'start_index': 393,
#   'end_index': 395,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': 0    [komt, in, rolstoel]
#   Name: tokens, dtype: object,
#   'annotators': {'vanderpas', 'vervaart'}},
#  187: {'file_id': 4688,
#   'start_index': 1054,
#   'end_index': 1054,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['loopstoornissen'],
#   'annotators': {'vanderpas', 'vervaart'}},
#  188: {'file_id': 3069,
#   'start_index': 20,
#   'end_index': 21,
#   'label': 'STM 0',
#   'tokens': 0    [Erg]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers', 'vanderpas'}},
#  189: {'file_id': 3069,
#   'start_index': 20,
#   'end_index': 21,
#   'label': '.B152: Stemming',
#   'tokens': 0    [Erg, geschrokken]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli'}},
#  190: {'file_id': 4696,
#   'start_index': 9,
#   'end_index': 19,
#   'label': 'FAC 4',
#   'tokens': 0    [met, rollator, lopen, gaat, moeizaam, maar, g...
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  191: {'file_id': 4696,
#   'start_index': 9,
#   'end_index': 15,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': 0    [met, rollator, lopen, gaat, moeizaam, maar, g...
#   Name: tokens, dtype: object,
#   'annotators': {'bos', 'katsburg', 'meskers', 'swartjes', 'vervaart'}},
#  192: {'file_id': 2651,
#   'start_index': 2,
#   'end_index': 4,
#   'label': '.B152: Stemming',
#   'tokens': 0    [Adequaat, en, coöperatief]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  193: {'file_id': 2651,
#   'start_index': 6,
#   'end_index': 10,
#   'label': '.B152: Stemming',
#   'tokens': ['loopt', 'zelfstandig', 'rond', 'op', 'kamer'],
#   'annotators': {'katsburg'}},
#  194: {'file_id': 2651,
#   'start_index': 153,
#   'end_index': 155,
#   'label': '.B152: Stemming',
#   'tokens': ['suf', ',', 'slaperig'],
#   'annotators': {'avelli'}},
#  195: {'file_id': 2651,
#   'start_index': 178,
#   'end_index': 180,
#   'label': '.B152: Stemming',
#   'tokens': ['in', 'de', 'war'],
#   'annotators': {'avelli'}},
#  196: {'file_id': 2651,
#   'start_index': 275,
#   'end_index': 279,
#   'label': 'FAC 2',
#   'tokens': 0    [Lopen, FAC, 2, met, rollator]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'katsburg', 'swartjes', 'vervaart'}},
#  197: {'file_id': 2651,
#   'start_index': 153,
#   'end_index': 158,
#   'label': 'type\\Implicit',
#   'tokens': 0    [suf, ,, slaperig, ,, geen, kracht]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  198: {'file_id': 2651,
#   'start_index': 268,
#   'end_index': 273,
#   'label': 'type\\Implicit',
#   'tokens': ['Bed-stoel',
#    'onder',
#    'supervisie',
#    'zelfstandig',
#    'met',
#    'rollator'],
#   'annotators': {'swartjes'}},
#  199: {'file_id': 2651,
#   'start_index': 6,
#   'end_index': 22,
#   'label': 'FAC 4',
#   'tokens': 0    [loopt, zelfstandig, rond, op, kamer]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  200: {'file_id': 2651,
#   'start_index': 24,
#   'end_index': 28,
#   'label': 'FAC 4',
#   'tokens': ['Loopt', 'FAC', '4', 'zonder', 'loophulpmiddel'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  201: {'file_id': 2651,
#   'start_index': 252,
#   'end_index': 256,
#   'label': 'FAC 4',
#   'tokens': ['FAC', '4'],
#   'annotators': {'avelli', 'swartjes', 'vanderpas', 'vervaart'}},
#  202: {'file_id': 2651,
#   'start_index': 271,
#   'end_index': 273,
#   'label': 'FAC 4',
#   'tokens': ['zelfstandig', 'met', 'rollator'],
#   'annotators': {'vanderpas'}},
#  203: {'file_id': 2651,
#   'start_index': 291,
#   'end_index': 293,
#   'label': 'FAC 4',
#   'tokens': ['Lopen', 'FAC', '4'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  204: {'file_id': 2651,
#   'start_index': 153,
#   'end_index': 155,
#   'label': 'STM 1',
#   'tokens': 0    [suf, ,, slaperig]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli'}},
#  205: {'file_id': 2651,
#   'start_index': 178,
#   'end_index': 180,
#   'label': 'STM 1',
#   'tokens': ['in', 'de', 'war'],
#   'annotators': {'avelli'}},
#  206: {'file_id': 2651,
#   'start_index': 269,
#   'end_index': 273,
#   'label': 'FAC 3',
#   'tokens': 0    [onder, supervisie, zelfstandig, met, rollator]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  207: {'file_id': 2651,
#   'start_index': 284,
#   'end_index': 286,
#   'label': 'FAC 3',
#   'tokens': ['Lopen', 'FAC', '3'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  208: {'file_id': 2651,
#   'start_index': 153,
#   'end_index': 158,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': 0    [suf, slaperig]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  209: {'file_id': 2651,
#   'start_index': 6,
#   'end_index': 293,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': 0    [loopt, zelfstandig, rond, op, kamer]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  210: {'file_id': 3688,
#   'start_index': 83,
#   'end_index': 97,
#   'label': 'INS 4',
#   'tokens': 0    [is, nu, meer, aan, het, sporten, maar, moet, ...
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  211: {'file_id': 3688,
#   'start_index': 100,
#   'end_index': 107,
#   'label': 'INS 4',
#   'tokens': ['gaat', 'veel'],
#   'annotators': {'avelli', 'meskers', 'swartjes'}},
#  212: {'file_id': 3688,
#   'start_index': 154,
#   'end_index': 159,
#   'label': '.D840-859: Beroep en werk',
#   'tokens': 0    [heeft, hij, bij, de, zorgboerderij, gewerkt]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  213: {'file_id': 3688,
#   'start_index': 287,
#   'end_index': 291,
#   'label': '.B152: Stemming',
#   'tokens': 0    [meer, onrustig]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'opsomer'}},
#  214: {'file_id': 3688,
#   'start_index': 293,
#   'end_index': 294,
#   'label': '.B152: Stemming',
#   'tokens': ['nu', 'rustiger'],
#   'annotators': {'avelli', 'meskers', 'opsomer'}},
#  215: {'file_id': 3688,
#   'start_index': 299,
#   'end_index': 302,
#   'label': '.B152: Stemming',
#   'tokens': ['meer', 'last', 'van', 'paniek'],
#   'annotators': {'avelli', 'bos', 'meskers', 'opsomer', 'swartjes'}},
#  216: {'file_id': 3688,
#   'start_index': 367,
#   'end_index': 374,
#   'label': '.B152: Stemming',
#   'tokens': ['Pt', 'heeft', 'het', 'er', 'soms', 'nog', 'moeilijk', 'mee'],
#   'annotators': {'bos', 'meskers', 'opsomer'}},
#  217: {'file_id': 3688,
#   'start_index': 99,
#   'end_index': 107,
#   'label': 'FAC 4',
#   'tokens': 0    [Pt, gaat, veel, fietsen, en, lopen, door, de,...
#   Name: tokens, dtype: object,
#   'annotators': {'bos'}},
#  218: {'file_id': 3688,
#   'start_index': 171,
#   'end_index': 171,
#   'label': 'FAC 4',
#   'tokens': ['loopt'],
#   'annotators': {'bos'}},
#  219: {'file_id': 3688,
#   'start_index': 367,
#   'end_index': 380,
#   'label': 'stm\\reaction',
#   'tokens': 0    [Pt, heeft, het, er, soms, nog, moeilijk, mee,...
#   Name: tokens, dtype: object,
# ...
#    'zijn',
#    'emoties',
#    'nog',
#    'niet',
#    'in',
#    'zicht',
#    'zijn'],
#   'annotators': {'katsburg'}},
#  795: {'file_id': 4584,
#   'start_index': 83,
#   'end_index': 83,
#   'label': 'STM 1',
#   'tokens': 0    [piekeren]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'swartjes', 'vanderpas', 'vervaart'}},
#  796: {'file_id': 4584,
#   'start_index': 189,
#   'end_index': 189,
#   'label': 'STM 1',
#   'tokens': ['geëmotioneerd'],
#   'annotators': {'avelli', 'bos', 'swartjes', 'vanderpas', 'vervaart'}},
#  797: {'file_id': 4584,
#   'start_index': 53,
#   'end_index': 74,
#   'label': 'view\\Third party',
#   'tokens': 0    [J, weet, dit, niet, meer, ,, maar, noemt, wel...
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  798: {'file_id': 4584,
#   'start_index': 80,
#   'end_index': 88,
#   'label': 'view\\Third party',
#   'tokens': ['J.',
#    'Begint',
#    'met',
#    'piekeren',
#    "'s",
#    'nachts',
#    'over',
#    'zijn',
#    'zoons'],
#   'annotators': {'swartjes'}},
#  799: {'file_id': 4584,
#   'start_index': 137,
#   'end_index': 163,
#   'label': 'view\\Third party',
#   'tokens': ['Weer',
#    'emotioneel',
#    'beschikbaar',
#    '(',
#    'uitleg',
#    ',',
#    'want',
#    'hij',
#    'begrijpt',
#    'het',
#    'verkeerd',
#    'en',
#    'zegt',
#    'dat',
#    'zijn',
#    'emoties',
#    'nog',
#    'niet',
#    'in',
#    'zicht',
#    'zijn',
#    '(',
#    'op',
#    'terugkomen',
#    '!',
#    ')',
#    '.'],
#   'annotators': {'swartjes'}},
#  800: {'file_id': 4584,
#   'start_index': 66,
#   'end_index': 69,
#   'label': 'STM 3',
#   'tokens': 0    [blij]
#   Name: tokens, dtype: object,
#   'annotators': {'bos'}},
#  801: {'file_id': 3051,
#   'start_index': 4,
#   'end_index': 6,
#   'label': 'STM 1',
#   'tokens': 0    [een, sombere, indruk]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'opsomer', 'swartjes', 'vervaart'}},
#  802: {'file_id': 3051,
#   'start_index': 4,
#   'end_index': 6,
#   'label': '.B152: Stemming',
#   'tokens': 0    [een, sombere, indruk]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'opsomer', 'swartjes', 'vervaart'}},
#  803: {'file_id': 3054,
#   'start_index': 230,
#   'end_index': 232,
#   'label': 'STM 1',
#   'tokens': 0    [boosheid]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers', 'vervaart'}},
#  804: {'file_id': 3054,
#   'start_index': 699,
#   'end_index': 700,
#   'label': 'STM 1',
#   'tokens': ['niet', 'zichzelf'],
#   'annotators': {'avelli'}},
#  805: {'file_id': 3054,
#   'start_index': 222,
#   'end_index': 237,
#   'label': 'view\\Third party',
#   'tokens': 0    [via, echtgenote, :, al, langer, veranderd, ge...
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  806: {'file_id': 3054,
#   'start_index': 230,
#   'end_index': 232,
#   'label': '.B152: Stemming',
#   'tokens': 0    [boosheid]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers', 'vervaart'}},
#  807: {'file_id': 3054,
#   'start_index': 699,
#   'end_index': 700,
#   'label': '.B152: Stemming',
#   'tokens': ['niet', 'zichzelf'],
#   'annotators': {'avelli'}},
#  808: {'file_id': 2546,
#   'start_index': 282,
#   'end_index': 289,
#   'label': 'FAC 2',
#   'tokens': 0    [moeizamer]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  809: {'file_id': 2546,
#   'start_index': 551,
#   'end_index': 557,
#   'label': 'FAC 2',
#   'tokens': ['denkt', 'ook', 'niet', 'dat', 'transfers', 'kunnen', 'lukken'],
#   'annotators': {'meskers', 'swartjes'}},
#  810: {'file_id': 2546,
#   'start_index': 560,
#   'end_index': 567,
#   'label': 'FAC 2',
#   'tokens': ['thuis', 'ook', 'niet', 'van', 'bed', 'naar', 'toilet', 'kunnen'],
#   'annotators': {'meskers', 'swartjes'}},
#  811: {'file_id': 2546,
#   'start_index': 608,
#   'end_index': 610,
#   'label': 'FAC 2',
#   'tokens': ['lopen', 'onder', 'begeleiding'],
#   'annotators': {'meskers', 'swartjes', 'vanderpas'}},
#  812: {'file_id': 2546,
#   'start_index': 282,
#   'end_index': 282,
#   'label': 'type\\Implicit',
#   'tokens': 0    [moeizamer]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'vanderpas'}},
#  813: {'file_id': 2546,
#   'start_index': 287,
#   'end_index': 289,
#   'label': 'type\\Implicit',
#   'tokens': ['meerdere', 'malen', 'gevallen'],
#   'annotators': {'katsburg', 'vanderpas'}},
#  814: {'file_id': 2546,
#   'start_index': 388,
#   'end_index': 392,
#   'label': 'type\\Implicit',
#   'tokens': ['Afgelopen', 'maanden', 'aantal', 'keer', 'gevallen'],
#   'annotators': {'vanderpas'}},
#  815: {'file_id': 2546,
#   'start_index': 435,
#   'end_index': 437,
#   'label': 'type\\Implicit',
#   'tokens': ['niet', 'meer', 'redden'],
#   'annotators': {'vervaart'}},
#  816: {'file_id': 2546,
#   'start_index': 460,
#   'end_index': 463,
#   'label': 'type\\Implicit',
#   'tokens': ['niet', 'meer', 'ADL', 'zelfstandig'],
#   'annotators': {'katsburg'}},
#  817: {'file_id': 2546,
#   'start_index': 523,
#   'end_index': 526,
#   'label': 'type\\Implicit',
#   'tokens': ['zelf', 'transfers', 'kan', 'maken'],
#   'annotators': {'meskers'}},
#  818: {'file_id': 2546,
#   'start_index': 523,
#   'end_index': 526,
#   'label': 'FAC 4',
#   'tokens': 0    [zelf]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  819: {'file_id': 2546,
#   'start_index': 570,
#   'end_index': 572,
#   'label': 'FAC 4',
#   'tokens': ['kan', 'ook', 'niet'],
#   'annotators': {'meskers'}},
#  820: {'file_id': 2546,
#   'start_index': 562,
#   'end_index': 575,
#   'label': 'FAC 0',
#   'tokens': 0    [niet, van, bed, naar, toilet, kunnen]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'opsomer'}},
#  821: {'file_id': 2546,
#   'start_index': 517,
#   'end_index': 526,
#   'label': 'view\\Patient',
#   'tokens': 0    [denkt, zelf, dat, hij]
#   Name: tokens, dtype: object,
#   'annotators': {'bos', 'katsburg', 'meskers'}},
#  822: {'file_id': 2546,
#   'start_index': 550,
#   'end_index': 557,
#   'label': 'view\\Patient',
#   'tokens': ['En',
#    'denkt',
#    'ook',
#    'niet',
#    'dat',
#    'transfers',
#    'kunnen',
#    'lukken'],
#   'annotators': {'bos'}},
#  823: {'file_id': 2546,
#   'start_index': 576,
#   'end_index': 583,
#   'label': 'view\\Patient',
#   'tokens': ['Denkt', 'ook', 'zelf', 'niet', 'naar', 'huis', 'te', 'kunnen'],
#   'annotators': {'katsburg'}},
#  824: {'file_id': 2546,
#   'start_index': 460,
#   'end_index': 463,
#   'label': 'FAC 1',
#   'tokens': 0    [niet, meer, ADL, zelfstandig]
#   Name: tokens, dtype: object,
#   'annotators': {'vervaart'}},
#  825: {'file_id': 2546,
#   'start_index': 553,
#   'end_index': 554,
#   'label': 'FAC 1',
#   'tokens': ['niet', 'dat'],
#   'annotators': {'vervaart'}},
#  826: {'file_id': 2546,
#   'start_index': 562,
#   'end_index': 566,
#   'label': 'FAC 1',
#   'tokens': ['niet', 'van', 'bed', 'naar', 'toilet'],
#   'annotators': {'bos'}},
#  827: {'file_id': 2546,
#   'start_index': 572,
#   'end_index': 572,
#   'label': 'FAC 1',
#   'tokens': ['niet'],
#   'annotators': {'bos'}},
#  828: {'file_id': 2546,
#   'start_index': 608,
#   'end_index': 610,
#   'label': 'FAC 1',
#   'tokens': ['lopen', 'onder', 'begeleiding'],
#   'annotators': {'avelli', 'bos', 'katsburg'}},
#  829: {'file_id': 2546,
#   'start_index': 535,
#   'end_index': 542,
#   'label': 'view\\Third party',
#   'tokens': 0    [partner, denkt, dat, hij, thuis, het, niet, r...
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'meskers', 'swartjes', 'vervaart'}},
#  830: {'file_id': 2546,
#   'start_index': 550,
#   'end_index': 557,
#   'label': 'view\\Third party',
#   'tokens': ['En', 'denkt'],
#   'annotators': {'katsburg', 'meskers', 'swartjes', 'vervaart'}},
#  831: {'file_id': 2546,
#   'start_index': 559,
#   'end_index': 575,
#   'label': 'view\\Third party',
#   'tokens': ['Zou',
#    'thuis',
#    'ook',
#    'niet',
#    'van',
#    'bed',
#    'naar',
#    'toilet',
#    'kunnen',
#    'lopen',
#    ',',
#    'kan',
#    'ook',
#    'niet',
#    'trap',
#    'lopen'],
#   'annotators': {'avelli', 'meskers', 'swartjes'}},
#  832: {'file_id': 2546,
#   'start_index': 282,
#   'end_index': 282,
#   'label': 'FAC 3',
#   'tokens': 0    [moeizamer]
#   Name: tokens, dtype: object,
#   'annotators': {'swartjes'}},
#  833: {'file_id': 2546,
#   'start_index': 508,
#   'end_index': 526,
#   'label': 'FAC 3',
#   'tokens': ['Linker',
#    'been',
#    'de',
#    'afgelopen',
#    'dagen',
#    'weer',
#    'meer',
#    'kracht',
#    ',',
#    'denkt',
#    'zelf',
#    'dat',
#    'hij',
#    'wel',
#    'weer',
#    'zelf',
#    'transfers',
#    'kan',
#    'maken'],
#   'annotators': {'swartjes'}},
#  834: {'file_id': 2546,
#   'start_index': 570,
#   'end_index': 572,
#   'label': 'FAC 3',
#   'tokens': ['kan', 'ook', 'niet'],
#   'annotators': {'swartjes'}},
#  835: {'file_id': 2546,
#   'start_index': 609,
#   'end_index': 611,
#   'label': 'FAC 3',
#   'tokens': ['onder', 'begeleiding'],
#   'annotators': {'opsomer', 'vervaart'}},
#  836: {'file_id': 2546,
#   'start_index': 348,
#   'end_index': 1044,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': 0    [conditie, conditie, conditie, Conditie, condi...
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'opsomer', 'vanderpas', 'vervaart'}},
#  837: {'file_id': 2546,
#   'start_index': 281,
#   'end_index': 282,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': 0    [lopen]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'vanderpas'}},
#  838: {'file_id': 2546,
#   'start_index': 287,
#   'end_index': 289,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['meerdere', 'malen', 'gevallen'],
#   'annotators': {'vanderpas'}},
#  839: {'file_id': 2546,
#   'start_index': 388,
#   'end_index': 392,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['Afgelopen', 'maanden', 'aantal', 'keer', 'gevallen'],
#   'annotators': {'vanderpas'}},
#  840: {'file_id': 2546,
#   'start_index': 460,
#   'end_index': 463,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['niet', 'meer', 'ADL', 'zelfstandig'],
#   'annotators': {'katsburg'}},
#  841: {'file_id': 2546,
#   'start_index': 524,
#   'end_index': 568,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['transfers'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  842: {'file_id': 2546,
#   'start_index': 570,
#   'end_index': 574,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['kan', 'ook', 'niet', 'trap', 'lopen'],
#   'annotators': {'bos', 'katsburg', 'meskers', 'swartjes', 'vervaart'}},
#  843: {'file_id': 2546,
#   'start_index': 606,
#   'end_index': 610,
#   'label': '.D450: Lopen en zich verplaatsen',
#   'tokens': ['transfers', 'en', 'lopen'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  844: {'file_id': 3059,
#   'start_index': 2,
#   'end_index': 8,
#   'label': 'STM 0',
#   'tokens': 0    [mw, was, heel, emotioneel, in, de, ochtend]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'meskers', 'opsomer', 'swartjes'}},
#  845: {'file_id': 3059,
#   'start_index': 2,
#   'end_index': 8,
#   'label': '.B152: Stemming',
#   'tokens': 0    [mw, was, heel, emotioneel, in, de, ochtend]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  846: {'file_id': 3059,
#   'start_index': 2,
#   'end_index': 14,
#   'label': 'stm\\reaction',
#   'tokens': 0    [mw, was, heel, emotioneel, in, de, ochtend, i...
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'meskers', 'swartjes', 'vanderpas', 'vervaart'}},
#  847: {'file_id': 3581,
#   'start_index': 5,
#   'end_index': 7,
#   'label': '.B152: Stemming',
#   'tokens': 0    [Het, gaat]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg'}},
#  848: {'file_id': 3581,
#   'start_index': 142,
#   'end_index': 172,
#   'label': '.B152: Stemming',
#   'tokens': ['heel', 'vrolijk'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  849: {'file_id': 3581,
#   'start_index': 391,
#   'end_index': 391,
#   'label': '.B152: Stemming',
#   'tokens': ['gedemotiveerd'],
#   'annotators': {'avelli', 'vervaart'}},
#  850: {'file_id': 3581,
#   'start_index': 432,
#   'end_index': 435,
#   'label': '.B152: Stemming',
#   'tokens': ['Ziet', 'er', 'tegen', 'op'],
#   'annotators': {'avelli'}},
#  851: {'file_id': 3581,
#   'start_index': 135,
#   'end_index': 143,
#   'label': 'stm\\reaction',
#   'tokens': 0    [Bij, geen, stress]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'opsomer', 'vervaart'}},
#  852: {'file_id': 3581,
#   'start_index': 145,
#   'end_index': 150,
#   'label': 'stm\\reaction',
#   'tokens': ['Bij', 'stress'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vervaart'}},
#  853: {'file_id': 3581,
#   'start_index': 152,
#   'end_index': 160,
#   'label': 'stm\\reaction',
#   'tokens': ['Wel', 'wat', 'angst', 'en', 'zorg', 'om', 'de', 'toekomst'],
#   'annotators': {'avelli',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  854: {'file_id': 3581,
#   'start_index': 167,
#   'end_index': 168,
#   'label': 'stm\\reaction',
#   'tokens': ['als', 'man'],
#   'annotators': {'meskers'}},
#  855: {'file_id': 3581,
#   'start_index': 391,
#   'end_index': 393,
#   'label': 'stm\\reaction',
#   'tokens': ['gedemotiveerd', 'zonder', 'wachtlijsten'],
#   'annotators': {'avelli', 'vervaart'}},
#  856: {'file_id': 3581,
#   'start_index': 142,
#   'end_index': 143,
#   'label': 'STM 4',
#   'tokens': 0    [heel]
#   Name: tokens, dtype: object,
#   'annotators': {'katsburg', 'meskers', 'opsomer', 'vervaart'}},
#  857: {'file_id': 3581,
#   'start_index': 115,
#   'end_index': 124,
#   'label': 'INS 5',
#   'tokens': 0    [Was, veel, aan, het, sporten, ,, boksen, en, ...
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'katsburg', 'meskers', 'swartjes'}},
#  858: {'file_id': 3581,
#   'start_index': 16,
#   'end_index': 23,
#   'label': 'view\\Patient',
#   'tokens': 0    [Pt, weet, niet, meer, wat, hij, leuk, vindt]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  859: {'file_id': 3581,
#   'start_index': 161,
#   'end_index': 166,
#   'label': 'view\\Patient',
#   'tokens': ['Voelt', 'zich', 'over', 'het', 'algemeen', 'gemakkelijk'],
#   'annotators': {'meskers'}},
#  860: {'file_id': 3581,
#   'start_index': 202,
#   'end_index': 208,
#   'label': 'view\\Patient',
#   'tokens': ['Dat', 'is', 'nergens', 'voor', 'nodig', 'aldus', 'pt'],
#   'annotators': {'katsburg'}},
#  861: {'file_id': 3581,
#   'start_index': 149,
#   'end_index': 150,
#   'label': 'STM 1',
#   'tokens': 0    [sneller]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'katsburg', 'meskers', 'opsomer', 'vervaart'}},
#  862: {'file_id': 3581,
#   'start_index': 152,
#   'end_index': 156,
#   'label': 'STM 1',
#   'tokens': ['Wel', 'wat'],
#   'annotators': {'avelli',
#    'bos',
#    'katsburg',
#    'meskers',
#    'opsomer',
#    'swartjes',
#    'vanderpas',
#    'vervaart'}},
#  863: {'file_id': 3581,
#   'start_index': 170,
#   'end_index': 171,
#   'label': 'STM 1',
#   'tokens': ['Niet', 'veel'],
#   'annotators': {'bos'}},
#  864: {'file_id': 3581,
#   'start_index': 391,
#   'end_index': 391,
#   'label': 'STM 1',
#   'tokens': ['gedemotiveerd'],
#   'annotators': {'avelli', 'vervaart'}},
#  865: {'file_id': 3581,
#   'start_index': 432,
#   'end_index': 435,
#   'label': 'STM 1',
#   'tokens': ['Ziet', 'er', 'tegen', 'op'],
#   'annotators': {'avelli'}},
#  866: {'file_id': 3581,
#   'start_index': 170,
#   'end_index': 172,
#   'label': 'STM 2',
#   'tokens': 0    [Niet, veel]
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'katsburg', 'meskers', 'vervaart'}},
#  867: {'file_id': 3581,
#   'start_index': 115,
#   'end_index': 124,
#   'label': '.B455: Inspanningstolerantie',
#   'tokens': 0    [Was, veel, aan, het, sporten, ,, boksen, en, ...
#   Name: tokens, dtype: object,
#   'annotators': {'avelli', 'bos', 'katsburg', 'meskers', 'swartjes'}},
#  868: {'file_id': 3581,
#   'start_index': 5,
#   'end_index': 7,
#   'label': 'STM 3',
#   'tokens': 0    [Het, gaat, goed]
#   Name: tokens, dtype: object,
#   'annotators': {'meskers'}},
#  869: {'file_id': 3581,
#   'start_index': 163,
#   'end_index': 166,
#   'label': 'STM 3',
#   'tokens': ['over', 'het', 'algemeen', 'gemakkelijk'],
#   'annotators': {'meskers', 'opsomer'}},
#  870: {'file_id': 3581,
#   'start_index': 170,
#   'end_index': 172,
#   'label': 'STM 3',
#   'tokens': ['Niet', 'veel', 'angst'],
#   'annotators': {'vanderpas'}}}

# %%
#### The next function could be differentiated per label
#- gemiddelde aantal gedeelde annotaties per label
#- hoeveel annotaties per student
#- hoe vaak is student outlier
#- confusion matrix
from collections import Counter

label_agreement = {}
labels = []
annotators = []
annotation_total = 0
for key, value in label_dict.items():
    label = label_dict[key]['label']
    labels.append(label)
    key_annotators= label_dict[key]['annotators']
    for anno in key_annotators:
        annotators.append(anno)
    if label in label_agreement:
        label_agreement[label]+=len(key_annotators)
    else:
        label_agreement[label]=len(key_annotators)
    annotation_total += len(key_annotators)


print('Annotations per label', Counter(labels))
print('Annotations per annotator',Counter(annotators))
print('Total annotations:', len(label_dict.items()))
print('Total student annotations:', annotation_total)
print('Average agreement of annotations', annotation_total/(len(label_dict.items())))

# for key, value in label_agreement.items():
#     print(key, value)
# Out:
# Annotations per label Counter({'.B152: Stemming': 119, 'view\\Patient': 100, 'STM 1': 95, 'type\\Implicit': 91, '.D450: Lopen en zich verplaatsen': 62, 'stm\\reaction': 61, 'FAC 4': 53, '.B455: Inspanningstolerantie': 41, 'view\\Third party': 40, 'STM 3': 30, 'STM 0': 27, 'STM 2': 22, 'INS 2': 17, 'FAC 2': 16, 'FAC 1': 15, 'INS 1': 15, '.D840-859: Beroep en werk': 14, 'FAC 3': 14, 'FAC 0': 11, 'FAC 5': 10, 'INS 3': 5, 'INS 5': 3, 'BER 0': 3, 'INS 4': 2, 'STM 4': 2, 'BER 4': 1, 'BER 1': 1})
# Annotations per annotator Counter({'katsburg': 420, 'swartjes': 374, 'meskers': 369, 'avelli': 281, 'vervaart': 252, 'bos': 247, 'vanderpas': 162, 'opsomer': 153})
# Total annotations: 870
# Total student annotations: 2258
# Average agreement of annotations 2.5954022988505745

# %%
# Function differentiated per label

labels = []
annotators = []
annotation_total = 0
for key, value in label_dict.items():
    #label naar keus invullen
    if label_dict[key]['label'] == 'STM 4':
        label = label_dict[key]['label']
        labels.append(label)
        key_annotators=label_dict[key]['annotators']
        for anno in key_annotators:
            annotators.append(anno)
        annotation_total += len(key_annotators)
        
        
print('Annotations per label', Counter(labels))
print()
print('Annotations per annotator',Counter(annotators))
print()
print('Total annotations:', len(labels))
print()
print('Total student annotations:', annotation_total)
print()
print('Average agreement of annotations', annotation_total/len(labels))
# Out:
# Annotations per label Counter({'STM 4': 3})
#
# Annotations per annotator Counter({'meskers': 2, 'bos': 1, 'vervaart': 1, 'katsburg': 1, 'opsomer': 1})
#
# Total annotations: 3
#
# Total student annotations: 6
#
# Average agreement of annotations 2.0

# %%
df_soft = pd.DataFrame.from_dict(label_dict, orient='index')

# %%
df_soft.head()
# Out:
#    file_id  start_index  end_index                             label  \
# 1     4100          517        520                             FAC 2
# 2     4100          157        158      .B455: Inspanningstolerantie
# 3     4100          507        507  .D450: Lopen en zich verplaatsen
# 4     4100          515        520  .D450: Lopen en zich verplaatsen
# 5     4100          557        558  .D450: Lopen en zich verplaatsen
#
#                                               tokens  \
# 1  0    [niet, zonder, steun]
# Name: tokens, dtype...
# 2  0    [Patiente, fietste]
# Name: tokens, dtype: ...
# 3     0    [mobiliseren]
# Name: tokens, dtype: object
# 4        [Kan, hierdoor, niet, zonder, steun, lopen]
# 5                                  [te, mobiliseren]
#
#                                           annotators
# 1                                              {bos}
# 2                                         {swartjes}
# 3  {bos, avelli, katsburg, swartjes, meskers, van...
# 4  {bos, avelli, katsburg, swartjes, meskers, van...
# 5                               {katsburg, swartjes}

# %%
# add row to df with a number for the amount of annotators per annotation

list_lens = []
for index, item in enumerate(df_soft['annotators']):
    if type(item) == str:
        item2 = item.split(' ')
        list_lens.append(len(item2))
    else: 
        list_lens.append(len(item))
        
#print(list_lens)    
    
df_soft['number_of_annotators'] = list_lens

# %%
df_soft.head()
# Out:
#    file_id  start_index  end_index                             label  \
# 1     4100          517        520                             FAC 2
# 2     4100          157        158      .B455: Inspanningstolerantie
# 3     4100          507        507  .D450: Lopen en zich verplaatsen
# 4     4100          515        520  .D450: Lopen en zich verplaatsen
# 5     4100          557        558  .D450: Lopen en zich verplaatsen
#
#                                               tokens  \
# 1  0    [niet, zonder, steun]
# Name: tokens, dtype...
# 2  0    [Patiente, fietste]
# Name: tokens, dtype: ...
# 3     0    [mobiliseren]
# Name: tokens, dtype: object
# 4        [Kan, hierdoor, niet, zonder, steun, lopen]
# 5                                  [te, mobiliseren]
#
#                                           annotators  number_of_annotators
# 1                                              {bos}                     1
# 2                                         {swartjes}                     1
# 3  {bos, avelli, katsburg, swartjes, meskers, van...                     6
# 4  {bos, avelli, katsburg, swartjes, meskers, van...                     6
# 5                               {katsburg, swartjes}                     2

# %%
df_soft.to_excel('softboundary_output_file_newest3.xlsx')

# %%
df_soft
# Out:
#      file_id  start_index  end_index                             label  \
# 1       4100          517        520                             FAC 2
# 2       4100          157        158      .B455: Inspanningstolerantie
# 3       4100          507        507  .D450: Lopen en zich verplaatsen
# 4       4100          515        520  .D450: Lopen en zich verplaatsen
# 5       4100          557        558  .D450: Lopen en zich verplaatsen
# ..       ...          ...        ...                               ...
# 872     3581          432        435                             STM 1
# 873     3581          170        172                             STM 2
# 874     3581           16         23                      view\Patient
# 875     3581          161        166                      view\Patient
# 876     3581          202        208                      view\Patient
#
#                                                 tokens  \
# 1    0    [niet, zonder, steun]
# Name: tokens, dtype...
# 2    0    [Patiente, fietste]
# Name: tokens, dtype: ...
# 3       0    [mobiliseren]
# Name: tokens, dtype: object
# 4          [Kan, hierdoor, niet, zonder, steun, lopen]
# 5                                    [te, mobiliseren]
# ..                                                 ...
# 872                              [Ziet, er, tegen, op]
# 873      0    [Niet, veel]
# Name: tokens, dtype: object
# 874  0    [Pt, weet, niet, meer, wat, hij, leuk, vi...
# 875    [Voelt, zich, over, het, algemeen, gemakkelijk]
# 876         [Dat, is, nergens, voor, nodig, aldus, pt]
#
#                                             annotators  number_of_annotators
# 1                                                {bos}                     1
# 2                                           {swartjes}                     1
# 3    {bos, avelli, katsburg, swartjes, meskers, van...                     6
# 4    {bos, avelli, katsburg, swartjes, meskers, van...                     6
# 5                                 {katsburg, swartjes}                     2
# ..                                                 ...                   ...
# 872                                           {avelli}                     1
# 873              {meskers, avelli, vervaart, katsburg}                     4
# 874                                          {meskers}                     1
# 875                                          {meskers}                     1
# 876                                         {katsburg}                     1
#
# [876 rows x 7 columns]

# %%
# extract information about the annotations made by only one annotator
# label count

list_labels = []

for index, item in enumerate(df_soft['number_of_annotators']):
    if item == 1:
        list_labels.append(df_soft.iloc[index]['label'])
        
Counter(list_labels)

list_annotators = []

# %%
# extract information about the annotations made by only one annotator
# annotator count

list_annotators = []

for index, item in enumerate(df_soft['number_of_annotators']):
    if item == 1:
        list_annotators.append(str(df_soft.iloc[index]['annotators']))
        
Counter(list_annotators)

# print()
# print(list_annotators)
# Out:
# Counter({"{'bos'}": 33,
#          "{'swartjes'}": 76,
#          "{'katsburg'}": 142,
#          "{'meskers'}": 82,
#          "{'avelli'}": 44,
#          "{'vervaart'}": 20,
#          "{'vanderpas'}": 19,
#          "{'opsomer'}": 14})

# %%
# extract labels and spans of annotations made by only one annotator for a certain annotator

list_tuples = []
for index, item in enumerate(df_soft['number_of_annotators']):
    # fille in name of annotator at end of the next line
    if item == 1 and df_soft.iloc[index]['annotators'] == {'swartjes'}:
        list_tuples.append((df_soft.iloc[index]['label'], df_soft.iloc[index]['tokens']))

# %%
print(len(list_tuples))

for item in list_tuples:
    print(item)
# Out:
# 76
# ('.B455: Inspanningstolerantie', 0    [Patiente, fietste]
# Name: tokens, dtype: object)
# ('type\\Implicit', 0    [mobiliseren]
# Name: tokens, dtype: object)
# ('type\\Implicit', ['onvermogen', 'te', 'mobiliseren'])
# ('view\\Third party', 0    [Zijn, vrouw, is, kwaad, op, hem, dat, ze, nie...
# Name: tokens, dtype: object)
# ('view\\Third party', ['Hij', 'is', 'volledig', 'overbelast', 'als', 'mantelzorger', 'en', 'heeft', 'weinig', 'ziekte', 'inzicht'])
# ('view\\Third party', ['Hij', 'slaapt', 'al', 'jaren', 'heel', 'slecht', ',', 'hierdoor', 'is', 'hij', 'overdag', 'vermoeid'])
# ('view\\Third party', ['Hij', 'is', 'bang', 'dat', 'hij', 'niet', 'meer', 'mag', 'autorijden'])
# ('.B455: Inspanningstolerantie', ['aan', 'en', 'uitkleden'])
# ('view\\Patient', ['Zijn', 'vrouw', 'is', 'kwaad', 'op', 'hem', 'dat', 'ze', 'niet', 'mag', 'autorijden'])
# ('view\\Patient', ['Belt', 'dagelijks', ',', 'zij', 'wordt', 'dan', 'boos', 'en', 'eist', 'de', 'autosleutels'])
# ('STM 1', ['vreest'])
# ('STM 1', 0    [onrust/stress]
# Name: tokens, dtype: object)
# ('STM 1', ['trekt', 'sonde', 'eruit'])
# ('type\\Implicit', 0    [Last, van, vermoeidheid]
# Name: tokens, dtype: object)
# ('type\\Implicit', ['komt', 'in', 'rolstoel'])
# ('type\\Implicit', 0    [suf, ,, slaperig, ,, geen, kracht]
# Name: tokens, dtype: object)
# ('type\\Implicit', ['Bed-stoel', 'onder', 'supervisie', 'zelfstandig', 'met', 'rollator'])
# ('INS 5', 0    [meer, aan, het, sporten]
# Name: tokens, dtype: object)
# ('.D840-859: Beroep en werk', 0    [heeft, hij, bij, de, zorgboerderij, gewerkt]
# Name: tokens, dtype: object)
# ('.B152: Stemming', ['Patiënte', 'wilde', 'geen', 'sonde', 'meer', ',', 'trok', 'deze', 'meermalen', 'uit'])
# ('type\\Implicit', 0    [met, rollator, met, de, Bijbel, er, op]
# Name: tokens, dtype: object)
# ('type\\Implicit', ['Patiënte', 'wilde', 'geen', 'sonde', 'meer', ',', 'trok', 'deze', 'meermalen', 'uit'])
# ('FAC 2', 0    [gaat, moeilijk, met, rollator]
# Name: tokens, dtype: object)
# ('FAC 2', ['gaat', 'traag', 'met', 'kleine', 'pasjes'])
# ('FAC 4', ['patiënt', 'gebruikt', 'een', 'wandelstok'])
# ('stm\\reaction', 0    [maar, dit, ging, beter, met]
# Name: tokens, dtype: object)
# ('INS 2', 0    [Zou, zelfstandig, wonen, en, wandelen]
# Name: tokens, dtype: object)
# ('INS 2', ['Deed', 'eigen', 'boodschappen'])
# ('FAC 4', 0    [voor, het, toilet, ,, net, zoals, thuis]
# Name: tokens, dtype: object)
# ('FAC 4', ['toiletgang'])
# ('FAC 4', ['heeft', 'met', 'de', 'fysio', 'een', 'flink', 'stuk'])
# ('.B455: Inspanningstolerantie', ['wassen'])
# ('.B455: Inspanningstolerantie', ['aankleden'])
# ('.B455: Inspanningstolerantie', ['huishouden'])
# ('.B455: Inspanningstolerantie', ['boodschappen'])
# ('.B455: Inspanningstolerantie', ['loopt'])
# ('INS 2', 0    [slechte]
# Name: tokens, dtype: object)
# ('INS 2', ['hulp', 'met'])
# ('INS 2', ['kleine', 'stukjes', 'in', 'huis'])
# ('view\\Patient', ['Lijkt', 'het', 'wel', 'prettig', 'te', 'vinden', 'om', 'te', 'praten'])
# ('INS 2', ['Boodschappen', 'doen'])
# ('FAC 4', ['Boodschappen', 'doen', 'met', 'een', 'boodschappenkarretje'])
# ('type\\Implicit', ['Boodschappen', 'doen', 'met', 'een', 'boodschappenkarretje'])
# ('BER 0', ['geen', 'geschikte', 'taken', 'bij', 'huidige', 'werkgever'])
# ('BER 0', ['niet', 'mogelijk'])
# ('.D450: Lopen en zich verplaatsen', ['Boodschappen', 'doen', 'met', 'een', 'boodschappenkarretje'])
# ('.D450: Lopen en zich verplaatsen', ['activiteiten', 'uitvoeren'])
# ('INS 3', 0    [30, min]
# Name: tokens, dtype: object)
# ('INS 3', ['Huishoudelijke', 'taken'])
# ('.D840-859: Beroep en werk', ['Fysiek', 'zwaar', 'werk'])
# ('.D840-859: Beroep en werk', ['administratieve', 'taken'])
# ('type\\Implicit', 0    [depressieve, stoornis]
# Name: tokens, dtype: object)
# ('type\\Implicit', ['tot', 'weinig', 'activiteiten', 'komen'])
# ('type\\Implicit', ['Het', 'risico', 'op', 'suïcide'])
# ('STM 1', 0    [prikkelbare]
# Name: tokens, dtype: object)
# ('STM 1', ['tot', 'weinig', 'activiteiten', 'komen'])
# ('STM 3', 0    [Hij, heeft, plezier]
# Name: tokens, dtype: object)
# ('STM 2', ['wordt', 'niet', 'verhoogd', 'ingeschat'])
# ('view\\Third party', ['Patiente', 'loopt', 'minder', 'goed', ',', 'ze', 'heeft', 'weer', 'meer', 'last', 'van', 'haar', 'linker', 'heup', 'gekregen'])
# ('type\\Implicit', 0    [Patiente, heeft, last, van, nervositeit]
# Name: tokens, dtype: object)
# ('type\\Implicit', ['gaat', 'regelmatig', 'naar', 'buiten'])
# ('FAC 0', ['Actieve', 'stalift'])
# ('.B455: Inspanningstolerantie', 0    [Verplaatsen, in, bed]
# Name: tokens, dtype: object)
# ('.B455: Inspanningstolerantie', ['Staan'])
# ('view\\Patient', 0    [Mw, zegt, hier, geen, last, van, te, hebben]
# Name: tokens, dtype: object)
# ('view\\Patient', ['Vroeg', 'niet', 'om', 'meer', 'maar', 'vond', 'het', 'heel', 'prettig', 'dat', 'het', 'kon.'])
# ('.B455: Inspanningstolerantie', 0    [lichamelijk, activiteiten]
# Name: tokens, dtype: object)
# ('.B455: Inspanningstolerantie', ['vermoeidheid'])
# ('view\\Third party', 0    [J, weet, dit, niet, meer, ,, maar, noemt, wel...
# Name: tokens, dtype: object)
# ('view\\Third party', ['J.', 'Begint', 'met', 'piekeren', "'s", 'nachts', 'over', 'zijn', 'zoons'])
# ('view\\Third party', ['Weer', 'emotioneel', 'beschikbaar', '(', 'uitleg', ',', 'want', 'hij', 'begrijpt', 'het', 'verkeerd', 'en', 'zegt', 'dat', 'zijn', 'emoties', 'nog', 'niet', 'in', 'zicht', 'zijn', '(', 'op', 'terugkomen', '!', ')', '.'])
# ('.B152: Stemming', ['emoties'])
# ('FAC 2', 0    [moeizamer]
# Name: tokens, dtype: object)
# ('FAC 3', 0    [moeizamer]
# Name: tokens, dtype: object)
# ('FAC 3', ['Linker', 'been', 'de', 'afgelopen', 'dagen', 'weer', 'meer', 'kracht', ',', 'denkt', 'zelf', 'dat', 'hij', 'wel', 'weer', 'zelf', 'transfers', 'kan', 'maken'])
# ('FAC 3', ['kan', 'ook', 'niet'])

# %%
# extract vocabulary per label
token_dict = {}
for index, item in enumerate(df_soft['label']):
    # fille in name of annotator at end of the next line
    for tokens in df_soft.iloc[index]['tokens']:
        if type(tokens)==str:
            tokens = [tokens]
        for token in tokens:
            if token:
                if token in token_dict:
                    token_dict[token].append(item)
                else:
                    token_dict[token] = [item]

for key, value in token_dict.items():
    print(key, Counter(value))
# Out:
# niet Counter({'view\\Patient': 38, 'view\\Third party': 15, 'STM 1': 8, 'type\\Implicit': 8, '.D450: Lopen en zich verplaatsen': 6, 'STM 2': 6, 'FAC 1': 5, 'stm\\reaction': 5, '.B152: Stemming': 5, 'FAC 2': 3, 'INS 2': 3, 'FAC 0': 3, 'STM 0': 2, 'INS 1': 2, 'BER 0': 2, '.B455: Inspanningstolerantie': 2, '.D840-859: Beroep en werk': 1, 'FAC 3': 1, 'FAC 4': 1})
# zonder Counter({'FAC 4': 3, 'type\\Implicit': 2, 'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 1': 1, '.B152: Stemming': 1, 'view\\Patient': 1, 'stm\\reaction': 1})
# steun Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 1': 1, 'FAC 0': 1, 'type\\Implicit': 1})
# Patiente Counter({'view\\Third party': 2, '.B455: Inspanningstolerantie': 1, 'type\\Implicit': 1, 'STM 1': 1, 'STM 2': 1, 'view\\Patient': 1})
# fietste Counter({'.B455: Inspanningstolerantie': 1})
# mobiliseren Counter({'type\\Implicit': 4, '.D450: Lopen en zich verplaatsen': 3})
# Kan Counter({'.D450: Lopen en zich verplaatsen': 3, 'type\\Implicit': 2, 'FAC 1': 1, 'BER 0': 1, '.D840-859: Beroep en werk': 1, '.B455: Inspanningstolerantie': 1, 'INS 1': 1, 'INS 2': 1, 'FAC 2': 1, 'FAC 4': 1})
# hierdoor Counter({'.D450: Lopen en zich verplaatsen': 1, 'FAC 1': 1, 'view\\Third party': 1})
# lopen Counter({'.D450: Lopen en zich verplaatsen': 16, 'FAC 4': 6, 'type\\Implicit': 5, '.B455: Inspanningstolerantie': 3, 'view\\Third party': 3, 'FAC 2': 3, 'INS 5': 1, 'FAC 5': 1, 'view\\Patient': 1, 'INS 2': 1, 'INS 3': 1, 'FAC 1': 1})
# te Counter({'view\\Patient': 31, 'stm\\reaction': 9, 'type\\Implicit': 8, '.D450: Lopen en zich verplaatsen': 6, 'STM 1': 3, 'view\\Third party': 2, 'FAC 4': 1, 'INS 1': 1, '.B152: Stemming': 1, 'FAC 2': 1})
# onvermogen Counter({'type\\Implicit': 1})
# Patient Counter({'view\\Patient': 4, 'STM 0': 1, 'INS 2': 1, 'stm\\reaction': 1, '.B455: Inspanningstolerantie': 1})
# geeft Counter({'view\\Patient': 9, 'STM 1': 1, 'view\\Third party': 1})
# aan Counter({'view\\Patient': 19, 'view\\Third party': 5, '.B455: Inspanningstolerantie': 4, 'type\\Implicit': 3, 'INS 5': 2, 'INS 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'STM 1': 1, 'INS 4': 1, '.B152: Stemming': 1, 'stm\\reaction': 1})
# op Counter({'type\\Implicit': 7, 'view\\Third party': 6, 'view\\Patient': 4, '.D450: Lopen en zich verplaatsen': 4, 'stm\\reaction': 3, 'FAC 4': 3, '.B152: Stemming': 2, 'STM 1': 2, 'FAC 2': 2, 'FAC 0': 1})
# linkerzij Counter({'view\\Patient': 1})
# gevallen Counter({'.D450: Lopen en zich verplaatsen': 3, 'type\\Implicit': 3, 'view\\Patient': 1, 'FAC 2': 1})
# zijn Counter({'view\\Patient': 15, 'view\\Third party': 9, 'stm\\reaction': 4, '.B152: Stemming': 3, 'type\\Implicit': 2, 'STM 1': 1, '.B455: Inspanningstolerantie': 1, 'INS 1': 1, 'INS 2': 1, '.D450: Lopen en zich verplaatsen': 1})
# , Counter({'view\\Patient': 41, 'view\\Third party': 22, 'type\\Implicit': 14, '.B152: Stemming': 10, 'FAC 4': 8, 'FAC 3': 5, 'stm\\reaction': 5, 'STM 1': 5, 'STM 2': 4, 'STM 3': 3, 'FAC 2': 2, 'FAC 5': 2, 'INS 2': 1, 'STM 0': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 0': 1, '.B455: Inspanningstolerantie': 1, 'INS 5': 1})
# vooral Counter({'view\\Patient': 1, 'view\\Third party': 1, 'stm\\reaction': 1})
# pijn Counter({'view\\Patient': 3, 'type\\Implicit': 1, 'FAC 4': 1, 'stm\\reaction': 1})
# linkerschouder Counter({'view\\Patient': 1})
# dit Counter({'view\\Patient': 6, 'view\\Third party': 3, 'type\\Implicit': 3, '.B152: Stemming': 2, 'stm\\reaction': 1, 'STM 1': 1, 'STM 0': 1})
# is Counter({'view\\Patient': 21, 'view\\Third party': 17, 'type\\Implicit': 11, 'STM 1': 7, '.B152: Stemming': 7, 'stm\\reaction': 6, 'STM 3': 4, 'STM 2': 3, 'INS 1': 2, 'STM 0': 2, '.B455: Inspanningstolerantie': 2, '.D450: Lopen en zich verplaatsen': 2, 'FAC 4': 2, 'INS 2': 1, 'INS 4': 1, 'FAC 0': 1})
# draaglijk Counter({'view\\Patient': 1})
# als Counter({'view\\Third party': 4, 'stm\\reaction': 4, 'view\\Patient': 2, '.D840-859: Beroep en werk': 1, '.B152: Stemming': 1, 'STM 1': 1})
# hij Counter({'view\\Patient': 17, 'view\\Third party': 9, 'stm\\reaction': 2, '.B152: Stemming': 1, 'INS 2': 1, 'type\\Implicit': 1, 'STM 1': 1, '.D840-859: Beroep en werk': 1, 'FAC 3': 1})
# stilzit Counter({'view\\Patient': 1})
# in Counter({'view\\Patient': 13, 'stm\\reaction': 7, 'type\\Implicit': 7, '.B152: Stemming': 5, '.D450: Lopen en zich verplaatsen': 5, 'view\\Third party': 5, 'FAC 2': 3, 'FAC 4': 3, 'STM 0': 2, 'STM 1': 2, 'FAC 0': 2, '.B455: Inspanningstolerantie': 2, 'STM 3': 2, '.D840-859: Beroep en werk': 1, 'INS 2': 1})
# linkerheup Counter({'view\\Patient': 1})
# Zijn Counter({'view\\Patient': 2, 'view\\Third party': 1, '.B152: Stemming': 1})
# vrouw Counter({'view\\Patient': 2, 'view\\Third party': 1, 'stm\\reaction': 1})
# kwaad Counter({'view\\Third party': 1, 'STM 1': 1, 'view\\Patient': 1})
# hem Counter({'view\\Patient': 2, 'view\\Third party': 1, 'stm\\reaction': 1})
# dat Counter({'view\\Patient': 46, 'view\\Third party': 21, 'stm\\reaction': 10, 'type\\Implicit': 4, 'FAC 0': 1, '.D450: Lopen en zich verplaatsen': 1, '.B152: Stemming': 1, 'STM 1': 1, 'FAC 2': 1, 'FAC 3': 1, 'FAC 1': 1})
# ze Counter({'view\\Patient': 18, 'view\\Third party': 11, 'stm\\reaction': 6, '.B152: Stemming': 4, 'STM 1': 2, 'STM 3': 2, 'STM 0': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'FAC 4': 1})
# mag Counter({'view\\Third party': 2, 'stm\\reaction': 2, 'view\\Patient': 2})
# autorijden Counter({'view\\Third party': 2, 'stm\\reaction': 2, 'view\\Patient': 1})
# Hij Counter({'view\\Third party': 5, 'view\\Patient': 4, 'stm\\reaction': 3, '.B152: Stemming': 2, 'STM 1': 1, 'FAC 0': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'STM 3': 1})
# volledig Counter({'view\\Third party': 1})
# overbelast Counter({'view\\Third party': 1})
# mantelzorger Counter({'view\\Third party': 2})
# en Counter({'view\\Patient': 24, 'view\\Third party': 12, '.B455: Inspanningstolerantie': 6, 'FAC 4': 5, '.B152: Stemming': 5, 'STM 1': 5, 'stm\\reaction': 4, 'FAC 3': 3, '.D450: Lopen en zich verplaatsen': 3, 'type\\Implicit': 3, 'INS 3': 2, 'FAC 2': 2, 'INS 5': 2, 'STM 3': 2, '.D840-859: Beroep en werk': 1, 'INS 2': 1, 'INS 1': 1, 'FAC 5': 1})
# heeft Counter({'view\\Patient': 7, 'type\\Implicit': 7, 'view\\Third party': 5, '.B152: Stemming': 5, 'stm\\reaction': 4, 'STM 1': 4, 'FAC 4': 4, '.D450: Lopen en zich verplaatsen': 3, '.D840-859: Beroep en werk': 2, 'STM 0': 1, 'FAC 0': 1, 'FAC 3': 1, 'STM 3': 1})
# weinig Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 1': 1})
# ziekte Counter({'view\\Third party': 1})
# inzicht Counter({'view\\Third party': 1})
# slaapt Counter({'view\\Third party': 1})
# al Counter({'view\\Third party': 7, 'view\\Patient': 2, 'STM 0': 1, 'FAC 4': 1})
# jaren Counter({'view\\Third party': 3, 'view\\Patient': 3})
# heel Counter({'.B152: Stemming': 3, 'STM 0': 3, 'view\\Patient': 2, 'view\\Third party': 1, 'STM 3': 1, 'STM 1': 1, 'stm\\reaction': 1, 'STM 4': 1})
# slecht Counter({'view\\Third party': 1})
# overdag Counter({'view\\Third party': 1, 'INS 2': 1, 'type\\Implicit': 1})
# vermoeid Counter({'INS 1': 4, 'type\\Implicit': 2, '.B152: Stemming': 2, 'view\\Third party': 1, '.B455: Inspanningstolerantie': 1, 'INS 2': 1, 'view\\Patient': 1, 'STM 1': 1})
# bang Counter({'STM 1': 6, '.B152: Stemming': 4, 'view\\Third party': 2, 'stm\\reaction': 2, 'view\\Patient': 2, 'STM 0': 1})
# meer Counter({'view\\Patient': 13, 'view\\Third party': 6, 'type\\Implicit': 5, 'stm\\reaction': 4, 'STM 1': 4, '.B152: Stemming': 4, '.B455: Inspanningstolerantie': 2, 'INS 2': 2, 'STM 0': 2, '.D450: Lopen en zich verplaatsen': 2, 'INS 4': 1, 'INS 5': 1, 'INS 1': 1, 'FAC 4': 1, 'FAC 3': 1, 'FAC 1': 1})
# voelt Counter({'.B152: Stemming': 4, 'view\\Patient': 3, 'STM 3': 2, '.B455: Inspanningstolerantie': 1, 'STM 1': 1, 'view\\Third party': 1, 'type\\Implicit': 1})
# zich Counter({'view\\Patient': 7, '.B152: Stemming': 5, 'STM 1': 5, '.B455: Inspanningstolerantie': 3, 'stm\\reaction': 3, 'STM 3': 2, 'view\\Third party': 2, 'type\\Implicit': 1, 'STM 0': 1})
# uitkleden Counter({'.B455: Inspanningstolerantie': 1})
# zit Counter({'view\\Patient': 5, '.B152: Stemming': 3, 'STM 1': 3, 'STM 0': 3, 'type\\Implicit': 2, 'FAC 2': 1, 'FAC 4': 1, 'FAC 0': 1, '.D450: Lopen en zich verplaatsen': 1, 'stm\\reaction': 1})
# vol Counter({'.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 1': 1, 'view\\Patient': 1})
# zorgen Counter({'.B152: Stemming': 3, 'STM 1': 3, 'type\\Implicit': 2, 'view\\Patient': 1, 'view\\Third party': 1, 'STM 0': 1})
# boos Counter({'STM 1': 5, 'view\\Patient': 4, '.B152: Stemming': 3, 'view\\Third party': 1, 'stm\\reaction': 1})
# energie Counter({'INS 1': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# verminderd Counter({'INS 1': 1, 'INS 2': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# kan Counter({'view\\Patient': 5, 'FAC 4': 5, 'view\\Third party': 4, 'type\\Implicit': 3, 'STM 3': 2, 'FAC 2': 2, '.D450: Lopen en zich verplaatsen': 2, 'FAC 3': 2, 'INS 2': 1, 'stm\\reaction': 1, 'STM 1': 1})
# minder Counter({'type\\Implicit': 2, 'STM 1': 2, 'view\\Patient': 2, 'INS 2': 1, 'view\\Third party': 1, 'FAC 4': 1})
# dan Counter({'view\\Patient': 6, '.B152: Stemming': 2, 'view\\Third party': 2, 'INS 2': 1, 'STM 0': 1, 'STM 1': 1})
# normaal Counter({'STM 2': 3, 'INS 2': 1, 'view\\Patient': 1, '.B152: Stemming': 1, 'type\\Implicit': 1, 'FAC 5': 1})
# vermogen Counter({'type\\Implicit': 1, 'STM 1': 1, 'view\\Patient': 1})
# om Counter({'view\\Patient': 8, 'stm\\reaction': 5, 'type\\Implicit': 4, 'STM 1': 2, '.D450: Lopen en zich verplaatsen': 2, 'view\\Third party': 1, 'STM 0': 1})
# genieten Counter({'view\\Patient': 2, 'STM 3': 2, 'type\\Implicit': 1, 'STM 1': 1})
# nu Counter({'view\\Patient': 5, 'type\\Implicit': 2, 'view\\Third party': 2, 'STM 1': 1, 'INS 4': 1, '.B455: Inspanningstolerantie': 1, '.B152: Stemming': 1, 'STM 2': 1, 'FAC 0': 1, '.D450: Lopen en zich verplaatsen': 1})
# ook Counter({'view\\Patient': 11, 'view\\Third party': 7, 'STM 1': 4, '.B152: Stemming': 3, 'type\\Implicit': 2, '.D450: Lopen en zich verplaatsen': 2, 'FAC 2': 2, 'stm\\reaction': 1, '.B455: Inspanningstolerantie': 1, 'INS 1': 1, 'INS 2': 1, 'FAC 3': 1, 'FAC 4': 1})
# wel Counter({'view\\Patient': 10, 'type\\Implicit': 6, 'view\\Third party': 6, 'STM 1': 4, 'FAC 4': 4, 'FAC 2': 2, '.B152: Stemming': 2, 'STM 3': 1, '.D450: Lopen en zich verplaatsen': 1, 'STM 2': 1, 'stm\\reaction': 1, 'FAC 3': 1})
# piekert Counter({'type\\Implicit': 1, 'view\\Patient': 1})
# veel Counter({'type\\Implicit': 4, 'STM 1': 4, 'view\\Patient': 3, '.B455: Inspanningstolerantie': 3, 'stm\\reaction': 2, 'STM 0': 2, 'STM 3': 2, 'INS 5': 2, 'FAC 4': 2, '.B152: Stemming': 2, 'INS 2': 2, 'INS 4': 1, '.D450: Lopen en zich verplaatsen': 1, 'view\\Third party': 1, 'INS 3': 1, 'INS 1': 1, 'STM 2': 1})
# ernstige Counter({'type\\Implicit': 1, 'STM 1': 1})
# stijf Counter({'FAC 4': 2, 'type\\Implicit': 1})
# bij Counter({'view\\Patient': 10, 'stm\\reaction': 6, 'view\\Third party': 6, 'type\\Implicit': 4, 'FAC 4': 4, '.B455: Inspanningstolerantie': 3, 'INS 2': 2, '.D840-859: Beroep en werk': 1, 'INS 1': 1, 'INS 3': 1, 'BER 0': 1, 'STM 1': 1})
# somber Counter({'STM 1': 5, 'STM 0': 2, 'view\\Patient': 2, '.B152: Stemming': 1, 'view\\Third party': 1})
# gelezen Counter({'stm\\reaction': 1})
# over Counter({'view\\Patient': 9, 'stm\\reaction': 6, 'view\\Third party': 5, 'STM 3': 2, 'type\\Implicit': 1, '.B152: Stemming': 1, 'STM 2': 1, 'STM 1': 1})
# de Counter({'view\\Patient': 21, 'stm\\reaction': 17, 'view\\Third party': 13, 'type\\Implicit': 12, '.D450: Lopen en zich verplaatsen': 5, 'FAC 4': 5, 'FAC 2': 3, '.B152: Stemming': 2, 'STM 1': 2, '.B455: Inspanningstolerantie': 2, 'FAC 0': 2, 'FAC 3': 2, 'INS 4': 1, 'INS 5': 1, 'FAC 5': 1, '.D840-859: Beroep en werk': 1, 'INS 2': 1, 'STM 0': 1})
# relatie Counter({'stm\\reaction': 1})
# slaaptekort Counter({'stm\\reaction': 1})
# Alzheimer Counter({'stm\\reaction': 1, 'view\\Third party': 1})
# verdriet Counter({'stm\\reaction': 1, 'STM 0': 1, 'STM 1': 1, 'view\\Patient': 1})
# of Counter({'view\\Patient': 8, 'stm\\reaction': 5, 'view\\Third party': 4, 'type\\Implicit': 2, '.B455: Inspanningstolerantie': 1, 'INS 2': 1, 'INS 3': 1, 'STM 1': 1})
# kanker Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# terug Counter({'view\\Patient': 2, 'stm\\reaction': 1})
# komt Counter({'view\\Patient': 3, 'view\\Third party': 3, 'type\\Implicit': 2, 'stm\\reaction': 1, '.D450: Lopen en zich verplaatsen': 1})
# haar Counter({'view\\Third party': 16, 'view\\Patient': 12, 'stm\\reaction': 9, 'type\\Implicit': 9, 'STM 1': 3, 'FAC 4': 2, 'FAC 2': 2, '.D450: Lopen en zich verplaatsen': 2, '.B152: Stemming': 1})
# Beroep Counter({'.D840-859: Beroep en werk': 5, 'BER 4': 1})
# Opleiding Counter({'.D840-859: Beroep en werk': 1})
# : Counter({'FAC 4': 4, 'type\\Implicit': 4, 'view\\Third party': 2, 'STM 2': 2, 'FAC 0': 2, '.D840-859: Beroep en werk': 1, 'BER 4': 1, 'STM 3': 1})
# hoger Counter({'.D840-859: Beroep en werk': 1})
# onderwijs Counter({'.D840-859: Beroep en werk': 1})
# antalgisch Counter({'FAC 4': 1})
# Rijdt Counter({'INS 3': 1})
# auto Counter({'INS 3': 1, 'FAC 4': 1, 'type\\Implicit': 1})
# fietst Counter({'.B455: Inspanningstolerantie': 2, 'INS 3': 1, 'INS 2': 1, 'stm\\reaction': 1})
# normaliter Counter({'INS 3': 1})
# Er Counter({'view\\Patient': 2, 'view\\Third party': 1})
# een Counter({'view\\Patient': 21, 'type\\Implicit': 9, 'FAC 4': 7, '.B152: Stemming': 7, 'stm\\reaction': 7, 'view\\Third party': 7, '.D450: Lopen en zich verplaatsen': 6, 'STM 2': 5, 'STM 0': 2, 'FAC 2': 2, 'FAC 3': 2, 'FAC 1': 2, 'STM 1': 2, 'STM 3': 1, '.D840-859: Beroep en werk': 1, 'INS 2': 1, 'FAC 0': 1})
# tijd Counter({'view\\Third party': 2, 'view\\Patient': 1, 'FAC 4': 1})
# geweest Counter({'view\\Third party': 3, 'view\\Patient': 2})
# nergens Counter({'view\\Patient': 2})
# zin Counter({'view\\Patient': 2})
# had Counter({'view\\Patient': 5, 'view\\Third party': 1})
# . Counter({'view\\Third party': 24, 'view\\Patient': 21, 'type\\Implicit': 14, 'FAC 5': 4, 'stm\\reaction': 3, '.B152: Stemming': 3, 'STM 1': 1, '.D840-859: Beroep en werk': 1, 'INS 2': 1, 'FAC 0': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'FAC 2': 1})
# schuldig Counter({'view\\Patient': 1})
# ontkent Counter({'view\\Patient': 1})
# doodsgedachten Counter({'view\\Patient': 1})
# geen Counter({'view\\Patient': 14, 'view\\Third party': 7, 'type\\Implicit': 4, '.B152: Stemming': 2, 'stm\\reaction': 2, 'STM 2': 2, 'FAC 5': 2, 'BER 0': 1, 'FAC 4': 1})
# rusteloos Counter({'view\\Patient': 1})
# gevoel Counter({'view\\Patient': 2, '.B152: Stemming': 2, 'type\\Implicit': 1})
# enigzins Counter({'view\\Patient': 1})
# bezorgd Counter({'view\\Patient': 1})
# patient Counter({'view\\Third party': 4, 'view\\Patient': 3, 'STM 1': 1, 'STM 0': 1})
# het Counter({'view\\Patient': 25, 'view\\Third party': 10, 'stm\\reaction': 8, 'type\\Implicit': 7, '.B152: Stemming': 6, 'FAC 4': 5, 'STM 1': 4, 'STM 3': 3, '.B455: Inspanningstolerantie': 3, 'INS 5': 2, '.D450: Lopen en zich verplaatsen': 2, 'FAC 5': 2, 'INS 4': 1, 'STM 2': 1})
# er Counter({'view\\Patient': 10, 'stm\\reaction': 4, 'view\\Third party': 4, '.B152: Stemming': 3, 'type\\Implicit': 2, 'STM 1': 2, 'STM 0': 1})
# mee Counter({'.B152: Stemming': 2, 'view\\Patient': 1, 'stm\\reaction': 1, 'view\\Third party': 1, 'STM 1': 1, 'type\\Implicit': 1})
# eens Counter({'view\\Patient': 2, 'view\\Third party': 1, '.B152: Stemming': 1, 'STM 1': 1})
# verzet Counter({'view\\Patient': 1})
# tegen Counter({'view\\Patient': 2, '.B152: Stemming': 1, 'STM 1': 1})
# vindt Counter({'view\\Patient': 9, 'view\\Third party': 2, 'STM 2': 1})
# goed Counter({'view\\Third party': 5, 'STM 3': 4, 'type\\Implicit': 3, 'STM 1': 3, '.B152: Stemming': 2, 'FAC 4': 2, 'view\\Patient': 1, 'STM 2': 1, 'stm\\reaction': 1})
# voor Counter({'view\\Patient': 11, 'stm\\reaction': 4, 'type\\Implicit': 3, 'FAC 4': 2, 'view\\Third party': 1, '.B455: Inspanningstolerantie': 1, 'INS 3': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 5': 1})
# verpleeghuis Counter({'view\\Patient': 1, '.D840-859: Beroep en werk': 1})
# deze Counter({'view\\Patient': 1, '.B152: Stemming': 1, 'type\\Implicit': 1})
# beslissing Counter({'view\\Patient': 1})
# accepteren Counter({'view\\Patient': 1})
# zoekt Counter({'view\\Patient': 1})
# iemand Counter({'view\\Patient': 1})
# overtuigen Counter({'view\\Patient': 1})
# ziek Counter({'view\\Patient': 1})
# Belt Counter({'view\\Patient': 1})
# dagelijks Counter({'view\\Patient': 1, '.D840-859: Beroep en werk': 1})
# zij Counter({'view\\Patient': 13, 'view\\Third party': 6, 'type\\Implicit': 2, 'stm\\reaction': 1, 'STM 1': 1, '.B152: Stemming': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1})
# wordt Counter({'view\\Patient': 4, 'view\\Third party': 4, 'stm\\reaction': 3, 'STM 2': 1, 'type\\Implicit': 1, 'STM 1': 1})
# eist Counter({'view\\Patient': 1})
# autosleutels Counter({'view\\Patient': 1})
# anderhalf Counter({'STM 0': 1})
# jaar Counter({'view\\Third party': 3, '.B152: Stemming': 2, 'STM 0': 1, 'STM 3': 1, 'type\\Implicit': 1, 'stm\\reaction': 1, 'view\\Patient': 1})
# met Counter({'FAC 4': 15, 'type\\Implicit': 15, 'view\\Third party': 11, 'FAC 2': 8, 'FAC 1': 7, '.D450: Lopen en zich verplaatsen': 6, 'FAC 0': 6, 'view\\Patient': 6, 'stm\\reaction': 4, 'FAC 3': 4, 'STM 2': 4, 'STM 3': 2, '.B152: Stemming': 2, 'STM 1': 2, 'INS 2': 2, 'INS 4': 1, '.B455: Inspanningstolerantie': 1, 'STM 0': 1})
# rollator Counter({'FAC 4': 8, 'FAC 2': 6, 'FAC 1': 5, 'type\\Implicit': 5, '.D450: Lopen en zich verplaatsen': 3, 'FAC 3': 2, 'view\\Third party': 2})
# binnen Counter({'FAC 2': 1})
# buitenshuis Counter({'FAC 2': 1})
# hulpmiddel Counter({'FAC 4': 2, 'FAC 2': 1, 'FAC 1': 1, 'type\\Implicit': 1})
# looppatroon Counter({'.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'FAC 1': 1})
# dwarslaesie Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# Overweging Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# botox Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# spieren Counter({'view\\Patient': 3, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# verslappen Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# verbeteren Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# stuntelig Counter({'FAC 4': 1, 'FAC 1': 1})
# Zij Counter({'view\\Patient': 3, 'view\\Third party': 3, 'type\\Implicit': 2, 'stm\\reaction': 1})
# daardoor Counter({'type\\Implicit': 1, 'view\\Patient': 1})
# benen Counter({'type\\Implicit': 1, 'view\\Patient': 1})
# moeilijk Counter({'type\\Implicit': 2, '.B152: Stemming': 1, 'stm\\reaction': 1, 'view\\Third party': 1, 'FAC 2': 1, 'FAC 3': 1, 'FAC 1': 1})
# sturen Counter({'type\\Implicit': 1})
# snel Counter({'STM 1': 2, '.B152: Stemming': 1, 'view\\Patient': 1, 'type\\Implicit': 1, 'STM 0': 1})
# emotioneel Counter({'.B152: Stemming': 10, 'STM 1': 3, 'STM 0': 2, 'type\\Implicit': 1, 'view\\Third party': 1, 'stm\\reaction': 1})
# Dhr Counter({'.B152: Stemming': 3, 'view\\Patient': 2, 'STM 3': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'FAC 4': 1, 'FAC 3': 1, 'STM 1': 1})
# Gaf Counter({'.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# na Counter({'stm\\reaction': 4, 'view\\Patient': 2, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'type\\Implicit': 1, 'view\\Third party': 1})
# tijdje Counter({'.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# gelopen Counter({'.D450: Lopen en zich verplaatsen': 4, 'FAC 4': 2, 'type\\Implicit': 1, 'view\\Patient': 1})
# hebben Counter({'view\\Patient': 7, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'type\\Implicit': 1, 'STM 1': 1})
# rechter Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# been Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'view\\Patient': 1, 'FAC 3': 1})
# moeilijker Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# kunnen Counter({'view\\Patient': 8, 'type\\Implicit': 2, 'FAC 2': 2, '.D450: Lopen en zich verplaatsen': 1, 'view\\Third party': 1, 'FAC 0': 1})
# optillen Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# Transfer Counter({'.D450: Lopen en zich verplaatsen': 2})
# zelf Counter({'view\\Patient': 9, 'FAC 4': 2, 'type\\Implicit': 2, 'FAC 3': 2, '.D450: Lopen en zich verplaatsen': 1, 'view\\Third party': 1, 'stm\\reaction': 1})
# beetje Counter({'view\\Patient': 1, '.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 1': 1})
# Rustig Counter({'STM 2': 1, '.B152: Stemming': 1})
# aanwezig Counter({'.B152: Stemming': 1, 'view\\Patient': 1, 'STM 2': 1})
# paniek Counter({'.B152: Stemming': 2, 'stm\\reaction': 1, 'STM 0': 1, 'STM 1': 1})
# aanvallen Counter({'stm\\reaction': 1, '.B152: Stemming': 1, 'STM 0': 1, 'STM 1': 1})
# erg Counter({'.B152: Stemming': 6, 'STM 0': 4, 'STM 1': 3, 'view\\Patient': 3, 'stm\\reaction': 2, 'STM 4': 2, 'type\\Implicit': 2, '.B455: Inspanningstolerantie': 1, 'INS 2': 1, 'INS 1': 1, 'view\\Third party': 1, 'STM 3': 1})
# benauwd Counter({'stm\\reaction': 1, '.B455: Inspanningstolerantie': 1, 'INS 2': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# van Counter({'view\\Patient': 15, 'stm\\reaction': 12, 'view\\Third party': 11, 'type\\Implicit': 7, '.B152: Stemming': 4, 'STM 1': 3, 'FAC 0': 3, 'STM 0': 2, '.B455: Inspanningstolerantie': 2, 'FAC 4': 2, 'FAC 3': 1, 'INS 2': 1, 'INS 4': 1, 'BER 1': 1, 'STM 3': 1, 'FAC 2': 1, 'FAC 1': 1})
# Mw Counter({'view\\Patient': 5, '.B152: Stemming': 2, 'STM 1': 2, '.D450: Lopen en zich verplaatsen': 2, 'FAC 4': 2, 'STM 0': 1})
# vicieuze Counter({'.B152: Stemming': 1, 'STM 0': 1, 'STM 1': 1})
# cirkel Counter({'.B152: Stemming': 1, 'STM 0': 1, 'STM 1': 1})
# angst Counter({'.B152: Stemming': 4, 'STM 1': 4, 'stm\\reaction': 3, 'STM 0': 1, 'view\\Patient': 1, 'STM 3': 1})
# + Counter({'FAC 3': 2})
# looprek Counter({'FAC 3': 2})
# veilig Counter({'FAC 3': 2})
# zelfstandig Counter({'FAC 4': 5, '.D450: Lopen en zich verplaatsen': 4, 'type\\Implicit': 4, 'FAC 3': 3, '.B152: Stemming': 1, '.B455: Inspanningstolerantie': 1, 'INS 2': 1, 'FAC 5': 1, 'INS 3': 1, 'FAC 1': 1})
# FAC Counter({'FAC 4': 3, 'FAC 3': 2, 'FAC 2': 1})
# 3 Counter({'FAC 3': 2, 'BER 1': 1, 'view\\Patient': 1})
# onder Counter({'FAC 3': 3, 'type\\Implicit': 1, 'FAC 2': 1, 'FAC 1': 1})
# toezicht Counter({'FAC 3': 1})
# 1 Counter({'type\\Implicit': 2, 'FAC 3': 1, 'FAC 4': 1, 'stm\\reaction': 1})
# persoon Counter({'FAC 3': 1})
# Adequaat Counter({'.B152: Stemming': 2})
# coöperatief Counter({'.B152: Stemming': 2})
# angstig Counter({'STM 1': 3, '.B152: Stemming': 2, 'view\\Third party': 1, 'stm\\reaction': 1})
# Transfers Counter({'.D450: Lopen en zich verplaatsen': 2})
# Partner Counter({'view\\Third party': 1})
# patiënte Counter({'view\\Third party': 2, 'type\\Implicit': 2, 'view\\Patient': 2, 'FAC 4': 2, 'STM 3': 1, 'FAC 5': 1})
# merkt Counter({'view\\Third party': 2, 'stm\\reaction': 1})
# drastisch Counter({'view\\Third party': 1})
# veranderd Counter({'view\\Third party': 2})
# hersenoperatie Counter({'view\\Third party': 1})
# Veel Counter({'view\\Third party': 1, 'stm\\reaction': 1, '.B152: Stemming': 1, 'STM 0': 1, 'STM 1': 1})
# dingen Counter({'view\\Third party': 2, 'stm\\reaction': 1, 'view\\Patient': 1})
# lukken Counter({'view\\Third party': 1, 'FAC 2': 1, 'view\\Patient': 1})
# zoals Counter({'view\\Third party': 2, 'FAC 4': 1})
# koken Counter({'view\\Third party': 1})
# administratieve Counter({'view\\Third party': 1, 'type\\Implicit': 1, '.D840-859: Beroep en werk': 1})
# zaken Counter({'view\\Third party': 1})
# cognitieve Counter({'view\\Third party': 2, 'stm\\reaction': 1, 'view\\Patient': 1})
# problemen Counter({'view\\Third party': 4, 'view\\Patient': 2, 'stm\\reaction': 1})
# maken Counter({'stm\\reaction': 3, 'type\\Implicit': 2, 'view\\Third party': 1, 'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'FAC 3': 1})
# sinds Counter({'stm\\reaction': 2, 'view\\Patient': 2, 'type\\Implicit': 1})
# ontdekken Counter({'stm\\reaction': 1})
# glioblastoma Counter({'stm\\reaction': 1})
# multiforme Counter({'stm\\reaction': 1})
# Dit Counter({'stm\\reaction': 2, 'view\\Third party': 1})
# ontstaan Counter({'stm\\reaction': 1})
# behandeling Counter({'stm\\reaction': 2, 'view\\Patient': 2, 'view\\Third party': 1})
# hersentumor Counter({'stm\\reaction': 2})
# geworden Counter({'view\\Patient': 2, 'stm\\reaction': 1})
# verkeer Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# omdat Counter({'view\\Patient': 4, 'stm\\reaction': 2, 'view\\Third party': 2})
# vreest Counter({'stm\\reaction': 1, 'STM 1': 1, 'view\\Patient': 1, 'view\\Third party': 1})
# overal Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# tegenaan Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# botsen Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# ongeluk Counter({'stm\\reaction': 2, 'view\\Patient': 1})
# veroorzaken Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# nooit Counter({'view\\Patient': 2, 'stm\\reaction': 1, 'view\\Third party': 1})
# zo Counter({'view\\Patient': 4, 'stm\\reaction': 2, 'STM 1': 2, 'STM 0': 1})
# actief Counter({'stm\\reaction': 1, 'view\\Patient': 1, 'view\\Third party': 1, 'STM 3': 1})
# zal Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# operatie Counter({'view\\Patient': 4, 'stm\\reaction': 2})
# buiten Counter({'stm\\reaction': 3, '.D450: Lopen en zich verplaatsen': 2, 'type\\Implicit': 2, 'view\\Patient': 1, 'FAC 5': 1, 'FAC 4': 1})
# werken Counter({'stm\\reaction': 3, 'view\\Patient': 3, '.D840-859: Beroep en werk': 1})
# tuin Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# Voordat Counter({'stm\\reaction': 1})
# patiënt Counter({'stm\\reaction': 1, 'type\\Implicit': 1, 'FAC 4': 1, 'FAC 1': 1})
# gediagnosticeerd Counter({'stm\\reaction': 1})
# werd Counter({'view\\Patient': 2, 'stm\\reaction': 1})
# voelde Counter({'stm\\reaction': 1, 'STM 1': 1})
# miskend Counter({'stm\\reaction': 1, 'STM 1': 1})
# door Counter({'stm\\reaction': 4, '.D450: Lopen en zich verplaatsen': 2, 'view\\Third party': 2, 'type\\Implicit': 2, '.B455: Inspanningstolerantie': 1, 'INS 5': 1, 'FAC 4': 1, 'FAC 5': 1, 'view\\Patient': 1, 'FAC 2': 1})
# huisarts Counter({'stm\\reaction': 1})
# andere Counter({'stm\\reaction': 1, 'view\\Third party': 1, 'view\\Patient': 1})
# zorgverleners Counter({'stm\\reaction': 1})
# wat Counter({'STM 1': 5, 'type\\Implicit': 4, 'view\\Patient': 3, 'stm\\reaction': 2, 'view\\Third party': 1, 'FAC 0': 1, 'FAC 4': 1, 'STM 2': 1, 'FAC 5': 1})
# versterkt Counter({'stm\\reaction': 1, 'STM 1': 1, 'STM 3': 1})
# stellen Counter({'stm\\reaction': 1})
# diagnose Counter({'stm\\reaction': 1})
# praten Counter({'stm\\reaction': 2, 'type\\Implicit': 1, 'INS 1': 1, '.B455: Inspanningstolerantie': 1, 'INS 2': 1, 'INS 3': 1, 'view\\Patient': 1})
# die Counter({'view\\Third party': 2, 'stm\\reaction': 1, 'type\\Implicit': 1})
# periode Counter({'stm\\reaction': 1, 'type\\Implicit': 1})
# spanning Counter({'stm\\reaction': 2, 'STM 1': 1, 'type\\Implicit': 1})
# meebrengt Counter({'stm\\reaction': 1, 'type\\Implicit': 1})
# status Counter({'stm\\reaction': 1})
# glioblastoom Counter({'stm\\reaction': 1})
# twijfelachtig Counter({'.B152: Stemming': 1, 'view\\Patient': 1})
# toenemende Counter({'.B152: Stemming': 1, 'STM 1': 1, 'STM 0': 1})
# angstklachten Counter({'.B152: Stemming': 3, 'STM 1': 2})
# last Counter({'view\\Patient': 5, '.B152: Stemming': 3, 'STM 1': 3, 'view\\Third party': 2, 'type\\Implicit': 1, 'FAC 4': 1})
# angststoornis Counter({'.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 0': 1})
# Ze Counter({'view\\Patient': 8, 'view\\Third party': 7, 'STM 1': 3, 'STM 3': 2, '.B152: Stemming': 2, 'type\\Implicit': 2, '.D450: Lopen en zich verplaatsen': 1, 'stm\\reaction': 1})
# lachte Counter({'STM 3': 1, 'type\\Implicit': 1})
# De Counter({'type\\Implicit': 4, 'STM 2': 3, 'STM 3': 1, '.B152: Stemming': 1, 'FAC 4': 1, '.D450: Lopen en zich verplaatsen': 1, 'view\\Patient': 1, '.B455: Inspanningstolerantie': 1})
# stemming Counter({'.B152: Stemming': 9, 'STM 2': 3, 'view\\Patient': 3, 'STM 3': 1, 'view\\Third party': 1})
# normofoor Counter({'STM 2': 5, 'STM 3': 2, '.B152: Stemming': 1})
# tijdens Counter({'STM 3': 1, 'view\\Third party': 1, 'type\\Implicit': 1, 'STM 1': 1})
# eerste Counter({'STM 3': 1})
# gesprek Counter({'STM 3': 1, 'STM 1': 1, 'view\\Patient': 1})
# vrolijk Counter({'STM 3': 1, '.B152: Stemming': 1})
# Patiënte Counter({'view\\Third party': 4, 'view\\Patient': 3, 'STM 1': 2, '.B152: Stemming': 2, 'type\\Implicit': 2, '.D840-859: Beroep en werk': 1})
# vergeetachtigheid Counter({'STM 1': 1, 'view\\Patient': 1})
# twijfel Counter({'view\\Patient': 2, 'STM 1': 1})
# In Counter({'STM 1': 1, 'view\\Third party': 1, '.B152: Stemming': 1, 'STM 3': 1, 'view\\Patient': 1})
# tweede Counter({'STM 1': 1})
# was Counter({'.B152: Stemming': 7, 'STM 1': 6, 'view\\Patient': 4, 'view\\Third party': 2, 'STM 3': 2, 'stm\\reaction': 1, 'STM 0': 1})
# echter Counter({'STM 1': 1})
# overwegend Counter({'STM 1': 1})
# leek Counter({'STM 1': 1})
# klachtenpresentatie Counter({'STM 1': 1})
# stemmingscongruent Counter({'STM 1': 1})
# maar Counter({'view\\Patient': 12, 'type\\Implicit': 4, 'view\\Third party': 4, '.B152: Stemming': 2, 'STM 1': 2, 'STM 2': 2, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'INS 4': 1, '.B455: Inspanningstolerantie': 1, 'stm\\reaction': 1})
# duidelijk Counter({'type\\Implicit': 1})
# merken Counter({'type\\Implicit': 1})
# gewerkt Counter({'.D840-859: Beroep en werk': 2})
# verzorgende Counter({'.D840-859: Beroep en werk': 1})
# gastvrouw Counter({'.D840-859: Beroep en werk': 1})
# depressief Counter({'STM 2': 1, 'view\\Patient': 1, 'STM 1': 1})
# Later Counter({'view\\Patient': 1, 'STM 1': 1})
# benoemt Counter({'view\\Patient': 2})
# afvraagt Counter({'view\\Patient': 1})
# waarom Counter({'view\\Patient': 1})
# doen Counter({'view\\Patient': 1, 'view\\Third party': 1, '.B152: Stemming': 1, 'STM 3': 1, 'INS 2': 1, 'FAC 4': 1, 'type\\Implicit': 1, '.D450: Lopen en zich verplaatsen': 1})
# toen Counter({'view\\Patient': 3, 'stm\\reaction': 1})
# volgens Counter({'view\\Patient': 3, 'view\\Third party': 1})
# zichzelf Counter({'view\\Patient': 4, '.B455: Inspanningstolerantie': 1, 'STM 2': 1, '.B152: Stemming': 1, 'STM 1': 1})
# deed Counter({'view\\Patient': 1})
# zegt Counter({'view\\Patient': 4, 'view\\Third party': 3})
# drukte Counter({'view\\Patient': 1})
# Als Counter({'view\\Patient': 2})
# belangrijkste Counter({'view\\Patient': 1})
# klacht Counter({'view\\Patient': 1})
# nemen Counter({'.B455: Inspanningstolerantie': 2, 'view\\Patient': 1})
# beslissingen Counter({'view\\Patient': 1})
# Momenteel Counter({'view\\Patient': 1})
# idee Counter({'view\\Patient': 1})
# anti-epilepticum Counter({'view\\Patient': 1})
# gebruikt Counter({'view\\Patient': 3, 'type\\Implicit': 2, 'FAC 4': 2, 'FAC 3': 1, 'FAC 1': 1, 'FAC 5': 1})
# ( Counter({'view\\Patient': 6, 'view\\Third party': 3, 'FAC 4': 2, 'type\\Implicit': 2, 'INS 2': 1, '.B455: Inspanningstolerantie': 1})
# levetiracetam Counter({'view\\Patient': 1})
# KEPPRA Counter({'view\\Patient': 1})
# ) Counter({'view\\Patient': 6, 'view\\Third party': 2, 'FAC 4': 2, 'type\\Implicit': 2, 'INS 2': 1, '.B455: Inspanningstolerantie': 1})
# 500 Counter({'view\\Patient': 1})
# mg Counter({'view\\Patient': 1})
# tablet Counter({'view\\Patient': 1})
# 2dd Counter({'view\\Patient': 1})
# mogelijk Counter({'FAC 0': 3, 'type\\Implicit': 2, 'view\\Patient': 1, '.D450: Lopen en zich verplaatsen': 1, 'INS 1': 1, 'BER 0': 1})
# rol Counter({'view\\Patient': 1})
# zou Counter({'view\\Patient': 6, 'view\\Third party': 4, 'type\\Implicit': 1})
# spelen Counter({'view\\Patient': 1})
# klachten Counter({'view\\Patient': 2, 'type\\Implicit': 2, 'view\\Third party': 1, '.B152: Stemming': 1, 'STM 1': 1, '.B455: Inspanningstolerantie': 1})
# neuroloog Counter({'view\\Patient': 1})
# gestopt Counter({'view\\Patient': 2})
# worden Counter({'view\\Patient': 5, 'stm\\reaction': 2})
# aldus Counter({'view\\Patient': 2})
# maakt Counter({'.B152: Stemming': 2, 'STM 1': 2, 'view\\Patient': 1, 'view\\Third party': 1, 'type\\Implicit': 1, 'STM 2': 1, 'STM 0': 1})
# onrust/stress Counter({'.B152: Stemming': 1, 'STM 1': 1})
# trekt Counter({'.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 1': 1})
# sonde Counter({'.B152: Stemming': 2, 'type\\Implicit': 2, 'view\\Patient': 2, 'STM 1': 1, 'view\\Third party': 1})
# eruit Counter({'.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 1': 1})
# Voelt Counter({'.B455: Inspanningstolerantie': 2, 'view\\Patient': 2, '.B152: Stemming': 1})
# moe Counter({'.B455: Inspanningstolerantie': 1, '.B152: Stemming': 1, 'INS 1': 1})
# blijft Counter({'.B152: Stemming': 1, 'STM 1': 1})
# gespannen Counter({'.B152: Stemming': 2, 'STM 1': 2, 'type\\Implicit': 1, 'STM 2': 1})
# ziet Counter({'.B152: Stemming': 1})
# rustig Counter({'.B152: Stemming': 1, 'view\\Third party': 1, 'STM 3': 1})
# uit Counter({'.B152: Stemming': 4, 'type\\Implicit': 3, 'view\\Patient': 3, 'STM 3': 1, 'view\\Third party': 1, 'stm\\reaction': 1, 'STM 1': 1})
# Rust/opluchting Counter({'.B152: Stemming': 1})
# Wast Counter({'.B455: Inspanningstolerantie': 1})
# Last Counter({'.B455: Inspanningstolerantie': 1, 'INS 2': 1, 'type\\Implicit': 1})
# vermoeidheid Counter({'.B455: Inspanningstolerantie': 3, 'type\\Implicit': 3})
# emoties Counter({'.B152: Stemming': 2, 'view\\Third party': 1, 'view\\Patient': 1})
# geïrriteerd Counter({'.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 3': 1, 'STM 1': 1})
# mn Counter({'INS 2': 1})
# beperkte Counter({'INS 2': 1})
# conditie Counter({'.B455: Inspanningstolerantie': 6, 'INS 2': 1, 'INS 1': 1})
# rolstoel Counter({'type\\Implicit': 5, '.D450: Lopen en zich verplaatsen': 4, 'FAC 0': 2, 'FAC 2': 2, 'FAC 4': 2, 'view\\Patient': 1})
# loopstoornissen Counter({'.D450: Lopen en zich verplaatsen': 1})
# Wil Counter({'view\\Patient': 2})
# liever Counter({'view\\Patient': 3})
# behandeld Counter({'view\\Patient': 2})
# alcohol Counter({'view\\Patient': 2})
# drinkt Counter({'view\\Patient': 2})
# wil Counter({'view\\Patient': 9})
# verdere Counter({'view\\Patient': 2})
# ondergaan Counter({'view\\Patient': 2})
# enkel Counter({'view\\Patient': 1})
# symptoombestrijding Counter({'view\\Patient': 1})
# willen Counter({'view\\Patient': 3, 'view\\Third party': 3, 'type\\Implicit': 1, 'STM 0': 1})
# voormalig Counter({'BER 4': 1})
# timmerman Counter({'BER 4': 1})
# Erg Counter({'.B152: Stemming': 2, 'STM 0': 2})
# geschrokken Counter({'.B152: Stemming': 1})
# gaat Counter({'view\\Patient': 5, '.D450: Lopen en zich verplaatsen': 4, 'FAC 4': 4, 'stm\\reaction': 3, 'type\\Implicit': 3, 'view\\Third party': 2, 'FAC 2': 2, 'INS 4': 1, '.B455: Inspanningstolerantie': 1, 'INS 5': 1, 'FAC 3': 1, 'FAC 1': 1, '.B152: Stemming': 1, 'STM 3': 1})
# moeizaam Counter({'FAC 4': 2, '.D450: Lopen en zich verplaatsen': 1})
# Lopen Counter({'FAC 4': 3, '.D450: Lopen en zich verplaatsen': 2, 'FAC 2': 1, 'FAC 3': 1})
# 2 Counter({'type\\Implicit': 2, 'FAC 0': 2, 'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'stm\\reaction': 1})
# supervisie Counter({'FAC 3': 1, 'type\\Implicit': 1})
# suf Counter({'.B455: Inspanningstolerantie': 1, '.B152: Stemming': 1, 'STM 1': 1, 'type\\Implicit': 1})
# slaperig Counter({'.B455: Inspanningstolerantie': 1, '.B152: Stemming': 1, 'STM 1': 1, 'type\\Implicit': 1})
# loopt Counter({'.D450: Lopen en zich verplaatsen': 4, 'FAC 4': 4, '.B152: Stemming': 1, 'FAC 5': 1, '.B455: Inspanningstolerantie': 1, 'view\\Third party': 1})
# rond Counter({'.D450: Lopen en zich verplaatsen': 2, 'FAC 4': 2, 'FAC 5': 2, '.B152: Stemming': 1, 'type\\Implicit': 1})
# kamer Counter({'.B152: Stemming': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1})
# war Counter({'.B152: Stemming': 1, 'STM 1': 1})
# Loopt Counter({'FAC 4': 1, '.D450: Lopen en zich verplaatsen': 1})
# 4 Counter({'FAC 4': 3, 'BER 1': 1, 'stm\\reaction': 1})
# loophulpmiddel Counter({'FAC 4': 1})
# kracht Counter({'type\\Implicit': 1, 'FAC 3': 1})
# Bed-stoel Counter({'type\\Implicit': 1})
# sporten Counter({'.B455: Inspanningstolerantie': 2, 'INS 5': 2, 'INS 4': 1})
# moet Counter({'INS 4': 1, '.B455: Inspanningstolerantie': 1, 'view\\Third party': 1, '.D450: Lopen en zich verplaatsen': 1, 'view\\Patient': 1, '.B152: Stemming': 1})
# nog Counter({'view\\Third party': 2, 'INS 4': 1, '.B455: Inspanningstolerantie': 1, '.B152: Stemming': 1, 'stm\\reaction': 1, 'BER 1': 1, 'view\\Patient': 1})
# oppassen Counter({'INS 4': 1, '.B455: Inspanningstolerantie': 1})
# belasten Counter({'INS 4': 1, '.B455: Inspanningstolerantie': 1})
# borstspieren Counter({'INS 4': 1, '.B455: Inspanningstolerantie': 1})
# Pt Counter({'view\\Patient': 2, '.B455: Inspanningstolerantie': 1, '.B152: Stemming': 1, 'stm\\reaction': 1, '.D450: Lopen en zich verplaatsen': 1, 'INS 5': 1, 'FAC 4': 1})
# fietsen Counter({'.B455: Inspanningstolerantie': 2, '.D450: Lopen en zich verplaatsen': 1, 'INS 5': 1, 'FAC 4': 1})
# stad Counter({'.B455: Inspanningstolerantie': 1, '.D450: Lopen en zich verplaatsen': 1, 'INS 5': 1, 'FAC 4': 1, 'FAC 5': 1})
# onrustig Counter({'.B152: Stemming': 3, 'STM 1': 3})
# rustiger Counter({'.B152: Stemming': 1, 'STM 2': 1})
# soms Counter({'.B152: Stemming': 1, 'stm\\reaction': 1})
# overlijden Counter({'stm\\reaction': 1})
# Gadget Counter({'stm\\reaction': 1})
# pt Counter({'view\\Patient': 2, '.D450: Lopen en zich verplaatsen': 1, 'FAC 5': 1})
# niks Counter({'view\\Patient': 2, 'view\\Third party': 1})
# naar Counter({'view\\Patient': 5, 'view\\Third party': 4, 'stm\\reaction': 4, '.D450: Lopen en zich verplaatsen': 3, 'FAC 4': 3, 'type\\Implicit': 3, '.B152: Stemming': 1, 'STM 3': 1, 'INS 1': 1, 'BER 1': 1, 'FAC 5': 1, 'FAC 2': 1, 'FAC 0': 1, 'FAC 1': 1})
# voorlichting Counter({'view\\Patient': 1})
# zorgboerderij Counter({'.D840-859: Beroep en werk': 1})
# af Counter({'.B152: Stemming': 1, 'STM 1': 1, 'view\\Third party': 1, 'view\\Patient': 1, '.B455: Inspanningstolerantie': 1})
# toe Counter({'.B152: Stemming': 1, 'STM 1': 1, '.B455: Inspanningstolerantie': 1})
# zat Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'FAC 0': 1})
# uur Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'FAC 0': 1, 'view\\Third party': 1, 'stm\\reaction': 1})
# Ergo Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# aangemeten Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# gestaan Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'FAC 0': 1})
# fysio Counter({'type\\Implicit': 2, '.D450: Lopen en zich verplaatsen': 1, 'FAC 0': 1, 'FAC 3': 1, 'FAC 4': 1})
# passieve Counter({'type\\Implicit': 1, 'FAC 0': 1})
# lift Counter({'type\\Implicit': 1, 'FAC 0': 1})
# Bij Counter({'view\\Third party': 2, 'stm\\reaction': 2, 'view\\Patient': 1, '.B152: Stemming': 1, 'STM 1': 1})
# staat Counter({'view\\Third party': 1})
# geloof Counter({'view\\Third party': 1})
# centraal Counter({'view\\Third party': 1})
# goede Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'STM 3': 1, 'view\\Patient': 1})
# tevreden Counter({'STM 3': 3, 'view\\Third party': 1, '.B152: Stemming': 1})
# Bijbel Counter({'view\\Third party': 1, 'type\\Implicit': 1})
# Altijd Counter({'view\\Third party': 1})
# selectief Counter({'view\\Third party': 2})
# wie Counter({'view\\Third party': 1})
# antwoord Counter({'view\\Third party': 1})
# gaf Counter({'view\\Patient': 2, 'view\\Third party': 1})
# sprak Counter({'view\\Third party': 1})
# Laatste Counter({'view\\Third party': 2})
# half Counter({'view\\Third party': 1})
# verslechtering Counter({'view\\Third party': 1})
# verwardheid Counter({'view\\Third party': 1})
# ingestuurd Counter({'view\\Third party': 1})
# VU Counter({'view\\Third party': 1})
# maanden Counter({'view\\Patient': 2, 'view\\Third party': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# wisselend Counter({'view\\Third party': 1, 'FAC 4': 1})
# logopedist Counter({'view\\Third party': 1})
# onvoldoende Counter({'view\\Third party': 1})
# speeksel Counter({'view\\Third party': 1})
# wegslikte Counter({'view\\Third party': 1})
# reden Counter({'view\\Third party': 1, '.B152: Stemming': 1})
# verminderde Counter({'view\\Third party': 1})
# slikfunctie Counter({'view\\Third party': 1})
# bekend Counter({'view\\Third party': 1})
# Bedlegerig Counter({'view\\Third party': 1})
# laatste Counter({'view\\Third party': 1})
# Na Counter({'view\\Third party': 1})
# val Counter({'view\\Third party': 1})
# grond Counter({'view\\Third party': 1})
# piepende Counter({'view\\Third party': 1})
# ademhaling Counter({'view\\Third party': 1})
# begonnen Counter({'view\\Third party': 1, '.B152: Stemming': 1})
# begeleider Counter({'view\\Third party': 1})
# tracheostoma Counter({'view\\Third party': 1, 'view\\Patient': 1})
# vanaf Counter({'view\\Third party': 1})
# jong Counter({'view\\Third party': 1})
# belaagd Counter({'view\\Third party': 1})
# geesten Counter({'view\\Third party': 2})
# Op Counter({'view\\Third party': 1})
# 13e Counter({'view\\Third party': 1})
# bezocht Counter({'view\\Third party': 1})
# moeder Counter({'view\\Third party': 2})
# helderziende Counter({'view\\Third party': 1})
# Af Counter({'view\\Third party': 1})
# Buitenhof Counter({'view\\Third party': 1})
# opgenomen Counter({'view\\Third party': 1})
# Valeriuskliniek Counter({'view\\Third party': 1})
# Vlaamsche Counter({'view\\Third party': 1})
# Pasage Counter({'view\\Third party': 1})
# grote Counter({'view\\Third party': 1})
# prater Counter({'view\\Third party': 1})
# Een Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'STM 3': 1})
# geleden Counter({'.B152: Stemming': 2, 'view\\Third party': 1, 'STM 3': 1})
# vrolijker Counter({'.B152: Stemming': 2, 'STM 3': 2, 'view\\Third party': 1})
# kon Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'STM 1': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'type\\Implicit': 1})
# ergens Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'STM 1': 1, 'view\\Patient': 1})
# wilde Counter({'view\\Patient': 3, 'view\\Third party': 2, '.B152: Stemming': 1, 'type\\Implicit': 1})
# spreken Counter({'view\\Third party': 2})
# rondom Counter({'view\\Third party': 1})
# ziekenhuisopname Counter({'view\\Third party': 1})
# levenseinde Counter({'view\\Third party': 1})
# herhaalde Counter({'view\\Third party': 1})
# vriendin Counter({'view\\Third party': 1, 'view\\Patient': 1})
# Vriendin Counter({'view\\Third party': 2})
# acht Counter({'view\\Third party': 1})
# polonaise Counter({'view\\Third party': 1})
# lijf Counter({'view\\Third party': 1, 'stm\\reaction': 1})
# Wel Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'STM 1': 1})
# behandelzaken Counter({'view\\Third party': 1})
# kwaliteit Counter({'view\\Third party': 1})
# leven Counter({'view\\Third party': 1, 'type\\Implicit': 1, 'STM 0': 1})
# bieden Counter({'view\\Third party': 1})
# meldt Counter({'view\\Patient': 3, 'view\\Third party': 1})
# pte Counter({'view\\Third party': 1})
# contact Counter({'view\\Third party': 2, 'STM 3': 2, 'stm\\reaction': 1})
# zus Counter({'view\\Third party': 2})
# trok Counter({'.B152: Stemming': 1, 'type\\Implicit': 1})
# meermalen Counter({'.B152: Stemming': 1, 'type\\Implicit': 1})
# 2012 Counter({'view\\Patient': 1})
# ziekenhuis Counter({'view\\Patient': 2, 'stm\\reaction': 1})
# opname Counter({'view\\Patient': 1, '.B455: Inspanningstolerantie': 1, 'INS 3': 1})
# Het Counter({'view\\Third party': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, '.B152: Stemming': 1, 'STM 3': 1})
# lijkt Counter({'view\\Third party': 1, 'type\\Implicit': 1, 'STM 1': 1, 'STM 2': 1})
# verslechterd Counter({'view\\Third party': 1})
# afgelopen Counter({'view\\Patient': 2, 'view\\Third party': 1, 'FAC 3': 1})
# Vindt Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'view\\Patient': 1})
# eng Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'STM 1': 1})
# twee Counter({'view\\Patient': 3, 'view\\Third party': 1, 'stm\\reaction': 1})
# alleen Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# thuis Counter({'view\\Third party': 5, 'stm\\reaction': 1, 'FAC 4': 1, 'FAC 2': 1})
# laten Counter({'view\\Third party': 1, 'stm\\reaction': 1})
# Zit Counter({'FAC 2': 1, 'FAC 4': 1})
# traag Counter({'FAC 2': 1, 'type\\Implicit': 1, 'FAC 4': 1})
# kleine Counter({'FAC 4': 2, 'FAC 2': 1, 'type\\Implicit': 1, 'INS 2': 1})
# pasjes Counter({'FAC 2': 1, 'type\\Implicit': 1, 'FAC 4': 1})
# per Counter({'stm\\reaction': 1, 'FAC 4': 1})
# verkeerde Counter({'view\\Third party': 2, 'stm\\reaction': 1})
# deur Counter({'stm\\reaction': 1})
# pakken Counter({'stm\\reaction': 1, 'view\\Third party': 1})
# imponeert Counter({'STM 2': 2, '.B152: Stemming': 1, 'STM 3': 1})
# modulerend Counter({'STM 2': 4, '.B152: Stemming': 1, 'STM 1': 1, 'STM 3': 1})
# affect Counter({'STM 2': 4, '.B152: Stemming': 1, 'STM 3': 1})
# Heeft Counter({'view\\Patient': 1})
# gemerkt Counter({'view\\Patient': 1})
# geheugen Counter({'view\\Patient': 1})
# trager Counter({'view\\Patient': 1})
# verdrietig Counter({'view\\Patient': 1, 'STM 1': 1})
# overtuigd Counter({'view\\Patient': 1})
# ' Counter({'view\\Patient': 2, 'view\\Third party': 1})
# echtgenoot Counter({'view\\Patient': 1})
# spullen Counter({'view\\Patient': 1})
# verplaatst Counter({'view\\Patient': 1})
# huis Counter({'view\\Patient': 5, 'view\\Third party': 1, 'INS 2': 1})
# taken Counter({'view\\Third party': 1, 'type\\Implicit': 1, 'BER 0': 1, 'INS 3': 1, '.D840-859: Beroep en werk': 1})
# overgenomen Counter({'view\\Third party': 1})
# echtgenote Counter({'view\\Third party': 7, 'stm\\reaction': 1})
# name Counter({'view\\Third party': 1, 'STM 1': 1})
# ongerust Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'STM 1': 1})
# Echtgenote Counter({'view\\Third party': 2})
# ervaart Counter({'view\\Third party': 1})
# duidelijke Counter({'view\\Third party': 1})
# Ook Counter({'view\\Third party': 1})
# degelijk Counter({'view\\Third party': 1})
# orientatieproblemen Counter({'view\\Third party': 1})
# neemt Counter({'view\\Third party': 1, 'type\\Implicit': 1})
# rijden Counter({'view\\Third party': 1})
# vaak Counter({'view\\Third party': 1, 'view\\Patient': 1})
# afslag Counter({'view\\Third party': 1})
# uiteindelijk Counter({'view\\Third party': 1})
# noemt Counter({'view\\Third party': 2})
# daarvan Counter({'view\\Third party': 1})
# voorbeeld Counter({'view\\Third party': 1})
# bijv Counter({'view\\Third party': 1})
# 5 Counter({'view\\Third party': 1})
# truien Counter({'view\\Third party': 1})
# aanzetten Counter({'view\\Third party': 1})
# aangeeft Counter({'view\\Third party': 1})
# juist Counter({'view\\Third party': 1})
# trui Counter({'view\\Third party': 1})
# boordje Counter({'view\\Third party': 1})
# beaamt Counter({'view\\Third party': 1})
# alle Counter({'view\\Third party': 1})
# regelen Counter({'view\\Third party': 1})
# nodig Counter({'view\\Patient': 2, 'view\\Third party': 1})
# genoemde Counter({'view\\Third party': 1})
# wonen Counter({'view\\Third party': 1, '.B455: Inspanningstolerantie': 1, 'INS 2': 1, 'INS 3': 1})
# bandrukt Counter({'view\\Third party': 1})
# daarom Counter({'view\\Third party': 1})
# zo'n Counter({'view\\Third party': 1})
# hoge Counter({'view\\Third party': 1, 'view\\Patient': 1})
# bloeddruk Counter({'view\\Third party': 1})
# gekregen Counter({'view\\Third party': 2, 'FAC 4': 1})
# benadrukt Counter({'view\\Third party': 1, 'view\\Patient': 1})
# belangrijk Counter({'view\\Third party': 1})
# genoteerd Counter({'view\\Third party': 1, 'view\\Patient': 1})
# altijd Counter({'view\\Third party': 2})
# laat Counter({'view\\Third party': 1})
# bed Counter({'view\\Third party': 2, 'type\\Implicit': 2, '.D450: Lopen en zich verplaatsen': 2, 'FAC 2': 2, '.B455: Inspanningstolerantie': 1, 'FAC 0': 1, 'FAC 1': 1})
# doorvraag Counter({'view\\Third party': 1, 'view\\Patient': 1})
# tientallen Counter({'view\\Third party': 1})
# geval Counter({'view\\Third party': 1})
# wandelstok Counter({'FAC 3': 2, 'FAC 4': 2, 'FAC 1': 2, 'type\\Implicit': 1})
# vlot Counter({'FAC 4': 2, 'FAC 3': 1, 'FAC 1': 1, 'type\\Implicit': 1, 'FAC 5': 1})
# normale Counter({'FAC 3': 1, '.B455: Inspanningstolerantie': 1, 'INS 1': 1, 'INS 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# pasgrootte Counter({'FAC 3': 1, 'type\\Implicit': 1, 'FAC 5': 1})
# armswing Counter({'FAC 3': 1, 'type\\Implicit': 1, 'FAC 5': 1})
# onenigheid Counter({'.B152: Stemming': 1, 'STM 1': 1, 'view\\Patient': 1})
# bestaat Counter({'.B152: Stemming': 1, 'STM 1': 1, 'view\\Patient': 1, 'type\\Implicit': 1})
# Stemming Counter({'.B152: Stemming': 5, 'STM 3': 2, 'STM 2': 1, 'STM 1': 1})
# aankleden Counter({'.B455: Inspanningstolerantie': 2})
# inspanning Counter({'.B455: Inspanningstolerantie': 3})
# ...
# Huishoudelijke Counter({'INS 3': 1})
# langere Counter({'FAC 4': 1})
# kortademigheid Counter({'.B455: Inspanningstolerantie': 1})
# rondje Counter({'.D450: Lopen en zich verplaatsen': 2, '.B455: Inspanningstolerantie': 1, 'INS 1': 1, 'INS 2': 1, 'type\\Implicit': 1})
# somatische Counter({'stm\\reaction': 1, '.B152: Stemming': 1})
# aandoening Counter({'stm\\reaction': 1})
# tekeningen Counter({'stm\\reaction': 1})
# depressieve Counter({'.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 0': 1, 'STM 1': 1})
# stoornis Counter({'.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 0': 1})
# omschrijft Counter({'.B152: Stemming': 1, 'view\\Patient': 1})
# depressie Counter({'.B152: Stemming': 1, 'view\\Patient': 1})
# verleden Counter({'.B152: Stemming': 1, 'view\\Patient': 1})
# bestond Counter({'.B152: Stemming': 1, 'view\\Patient': 1})
# prikkelbare Counter({'.B152: Stemming': 1, 'STM 1': 1, 'view\\Patient': 1})
# suïcidale Counter({'.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 0': 1})
# gedachten Counter({'.B152: Stemming': 1, 'type\\Implicit': 1, 'STM 0': 1})
# stemmingsklachten Counter({'.B152: Stemming': 1})
# parallel Counter({'.B152: Stemming': 1})
# optreden Counter({'.B152: Stemming': 1})
# ongeveer Counter({'.B152: Stemming': 1})
# risico Counter({'type\\Implicit': 1})
# suïcide Counter({'type\\Implicit': 1})
# stabiel Counter({'view\\Patient': 2, 'type\\Implicit': 1, 'STM 2': 1})
# plezier Counter({'STM 3': 1})
# normofreen Counter({'STM 2': 1})
# adequaat Counter({'STM 2': 1})
# verhoogd Counter({'STM 2': 1})
# ingeschat Counter({'STM 2': 1})
# genormaliseerd Counter({'STM 2': 1, 'view\\Patient': 1})
# vertelt Counter({'view\\Patient': 2, 'STM 2': 1})
# Patiënt Counter({'view\\Patient': 2})
# gebleven Counter({'view\\Patient': 1})
# persisterende Counter({'view\\Patient': 1})
# wens Counter({'view\\Patient': 1})
# stoppen Counter({'view\\Patient': 1})
# gebruik Counter({'view\\Patient': 1})
# antidepressiva Counter({'view\\Patient': 2})
# vermoedt Counter({'view\\Patient': 1})
# bijdragen Counter({'view\\Patient': 1})
# visusklachten Counter({'view\\Patient': 1})
# nystagmus Counter({'view\\Patient': 1})
# ? Counter({'view\\Patient': 3})
# Nicht Counter({'view\\Third party': 1})
# herkent Counter({'view\\Third party': 1})
# verschijnselen Counter({'view\\Third party': 1})
# tante Counter({'view\\Third party': 1})
# vader Counter({'view\\Third party': 1})
# administratie Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'type\\Implicit': 1})
# orde Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'type\\Implicit': 1})
# aanmaningen Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'type\\Implicit': 1})
# onzeker Counter({'view\\Third party': 2, 'STM 1': 2, 'stm\\reaction': 1, 'type\\Implicit': 1})
# toenemend Counter({'view\\Third party': 1, 'STM 1': 1})
# belt Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'type\\Implicit': 1, 'STM 1': 1})
# nicht Counter({'view\\Third party': 2, 'stm\\reaction': 2, 'type\\Implicit': 1, 'STM 1': 1})
# vaker Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'type\\Implicit': 1, 'STM 1': 1})
# ongerustheid Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'type\\Implicit': 1, 'STM 1': 1})
# momenten Counter({'view\\Third party': 1, 'STM 1': 1})
# geniet Counter({'view\\Third party': 1, 'STM 4': 1, 'stm\\reaction': 1, '.B152: Stemming': 1, 'STM 3': 1})
# kinderen Counter({'view\\Third party': 1, 'stm\\reaction': 1})
# linker Counter({'FAC 4': 2, 'view\\Third party': 1, 'type\\Implicit': 1})
# heup Counter({'view\\Third party': 1, 'FAC 4': 1})
# zorgelijk Counter({'stm\\reaction': 1, 'STM 1': 1})
# bijvoorbeeld Counter({'stm\\reaction': 1})
# koffie Counter({'stm\\reaction': 1})
# drinken Counter({'stm\\reaction': 1})
# regelmatig Counter({'stm\\reaction': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# wegens Counter({'stm\\reaction': 1, 'STM 1': 1})
# nervositeit Counter({'STM 1': 2, '.B152: Stemming': 1, 'type\\Implicit': 1})
# lies Counter({'type\\Implicit': 1, 'FAC 4': 1})
# Looppatroon Counter({'type\\Implicit': 1})
# iets Counter({'view\\Patient': 2, 'type\\Implicit': 1, 'FAC 5': 1})
# beenlengteverschil Counter({'type\\Implicit': 1, 'FAC 5': 1})
# hangt Counter({'type\\Implicit': 1, 'FAC 5': 1})
# rechts Counter({'type\\Implicit': 1, 'FAC 5': 1})
# verbreed Counter({'type\\Implicit': 1, 'FAC 5': 1})
# gangspoor Counter({'type\\Implicit': 1, 'FAC 5': 1})
# onderliggend Counter({'type\\Implicit': 1, 'STM 1': 1, 'STM 2': 1})
# geagiteerd Counter({'type\\Implicit': 1, 'STM 1': 1, 'STM 2': 1})
# lacherig Counter({'STM 3': 1, 'STM 2': 1})
# verbloemend Counter({'STM 2': 1})
# levendig Counter({'STM 2': 1})
# vlak Counter({'STM 2': 1})
# Pte Counter({'view\\Patient': 1})
# gehoord Counter({'view\\Patient': 2})
# kant Counter({'view\\Patient': 1})
# onwaarschijnlijk Counter({'view\\Patient': 1})
# gezien Counter({'view\\Patient': 1})
# toestand Counter({'view\\Patient': 1})
# heb Counter({'view\\Patient': 3, 'STM 1': 1})
# allergie Counter({'view\\Patient': 1})
# witte Counter({'view\\Patient': 1})
# jassen Counter({'view\\Patient': 1})
# vd Counter({'FAC 4': 1, 'type\\Implicit': 1})
# Boechorststr Counter({'FAC 4': 1, 'type\\Implicit': 1})
# Vandaag Counter({'type\\Implicit': 1})
# nieuwe Counter({'view\\Patient': 1})
# medicatie Counter({'view\\Patient': 2})
# starten Counter({'view\\Patient': 1})
# weken Counter({'view\\Patient': 3})
# opnieuw Counter({'view\\Patient': 1})
# aanval Counter({'view\\Patient': 1})
# spierrheuma Counter({'view\\Patient': 1})
# wederom Counter({'view\\Patient': 1})
# dosis Counter({'view\\Patient': 1})
# prednisolon Counter({'view\\Patient': 2})
# waarna Counter({'view\\Patient': 1})
# langzaam Counter({'view\\Patient': 1})
# Eerst Counter({'view\\Patient': 1})
# afbouwen Counter({'view\\Patient': 1})
# oogoperaties Counter({'view\\Patient': 1})
# achter Counter({'view\\Patient': 1})
# rug Counter({'view\\Patient': 2})
# rust Counter({'.B455: Inspanningstolerantie': 1})
# gerustgesteld Counter({'.B152: Stemming': 1})
# Met Counter({'FAC 0': 1, 'view\\Patient': 1})
# Staan Counter({'FAC 0': 1, '.B455: Inspanningstolerantie': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# personen Counter({'FAC 0': 1, 'type\\Implicit': 1})
# Actieve Counter({'FAC 0': 1})
# stalift Counter({'FAC 0': 1})
# Loopvaardigheid Counter({'FAC 0': 1})
# liep Counter({'FAC 0': 1})
# rollator/stok Counter({'FAC 0': 1, 'FAC 4': 1})
# Traplopen Counter({'FAC 0': 1, '.B455: Inspanningstolerantie': 1})
# Verplaatsen Counter({'.B455: Inspanningstolerantie': 1, '.D450: Lopen en zich verplaatsen': 1})
# transfers Counter({'.D450: Lopen en zich verplaatsen': 4, 'FAC 2': 1, 'FAC 3': 1, 'type\\Implicit': 1, 'view\\Patient': 1})
# Mr Counter({'type\\Implicit': 1})
# adequate Counter({'type\\Implicit': 1})
# Dat Counter({'view\\Patient': 2, 'stm\\reaction': 1})
# mij Counter({'view\\Patient': 4, 'stm\\reaction': 2, 'STM 1': 2, '.B152: Stemming': 1, 'STM 0': 1})
# sneller Counter({'stm\\reaction': 1, 'view\\Patient': 1, 'STM 1': 1})
# koorts Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# aankomst Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# lig Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# daar Counter({'view\\Patient': 3, 'stm\\reaction': 1})
# malen Counter({'stm\\reaction': 1, 'view\\Patient': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# vooruit Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# geschoven Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# Ik Counter({'view\\Patient': 5, 'stm\\reaction': 1, '.B152: Stemming': 1, 'STM 0': 1})
# voel Counter({'stm\\reaction': 1, '.B152: Stemming': 1, 'STM 1': 1, 'view\\Patient': 1, 'STM 0': 1})
# klote Counter({'stm\\reaction': 1, 'STM 1': 1, 'view\\Patient': 1, 'STM 0': 1})
# probleem Counter({'.B152: Stemming': 1, 'view\\Patient': 1, 'STM 0': 1})
# ben Counter({'view\\Patient': 3, '.B152: Stemming': 1, 'STM 1': 1})
# best Counter({'.B152: Stemming': 1, 'STM 1': 1, 'view\\Patient': 1, 'STM 0': 1})
# trek Counter({'.B152: Stemming': 1, 'STM 1': 1, 'view\\Patient': 1, 'STM 0': 1})
# zeker Counter({'STM 1': 1, 'view\\Patient': 1})
# ervan Counter({'STM 1': 1, 'view\\Patient': 1})
# Beste Counter({'view\\Patient': 1})
# Arjan Counter({'view\\Patient': 1})
# roep Counter({'view\\Patient': 1})
# mijn Counter({'view\\Patient': 4})
# huid Counter({'view\\Patient': 2})
# jij Counter({'view\\Patient': 1})
# afgeschoven Counter({'view\\Patient': 1})
# Ons Counter({'view\\Patient': 1})
# waar Counter({'view\\Patient': 1})
# partner Counter({'view\\Patient': 1, 'view\\Third party': 1})
# alsof Counter({'view\\Patient': 1})
# aanstel Counter({'view\\Patient': 1})
# Haren Counter({'view\\Patient': 1})
# uitvallen Counter({'view\\Patient': 1})
# bijna Counter({'view\\Patient': 2})
# kaal Counter({'view\\Patient': 2})
# voorkomen Counter({'view\\Patient': 1})
# geluisterd Counter({'view\\Patient': 1})
# aangaf Counter({'view\\Patient': 1})
# Vorige Counter({'view\\Patient': 1})
# keer Counter({'view\\Patient': 2, 'stm\\reaction': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# daarvoor Counter({'view\\Patient': 1})
# mtx Counter({'view\\Patient': 2})
# Nu Counter({'view\\Patient': 1})
# verder Counter({'view\\Patient': 1})
# woensdag Counter({'view\\Patient': 1})
# wachten Counter({'view\\Patient': 1})
# elke Counter({'view\\Patient': 1})
# valt Counter({'view\\Patient': 1})
# zoveel Counter({'view\\Patient': 1})
# begrepen Counter({'view\\Patient': 1})
# aanstellen Counter({'view\\Patient': 1})
# doe Counter({'view\\Patient': 1})
# En Counter({'view\\Patient': 2, 'view\\Third party': 1})
# benauwde Counter({'view\\Patient': 1})
# hoop Counter({'view\\Patient': 1})
# maandag Counter({'view\\Patient': 1})
# horen Counter({'view\\Patient': 1})
# recept Counter({'view\\Patient': 1})
# haren Counter({'view\\Patient': 1})
# aangevallen Counter({'view\\Patient': 1})
# strammer Counter({'view\\Patient': 1})
# Want Counter({'view\\Patient': 1})
# stram Counter({'view\\Patient': 1})
# kom Counter({'view\\Patient': 1})
# Kaal Counter({'view\\Patient': 1})
# vraag Counter({'view\\Patient': 1})
# vriendelijke Counter({'view\\Patient': 1})
# groet Counter({'view\\Patient': 1})
# José Counter({'view\\Patient': 1})
# den Counter({'view\\Patient': 1})
# Boer Counter({'view\\Patient': 1})
# nachtelijke Counter({'stm\\reaction': 1})
# onrust Counter({'stm\\reaction': 1, '.B152: Stemming': 1, 'STM 2': 1})
# wezen Counter({'stm\\reaction': 1})
# roken Counter({'stm\\reaction': 1, 'view\\Patient': 1})
# stukje Counter({'.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1})
# Onrust Counter({'.B152: Stemming': 2, 'STM 2': 1})
# Vroeg Counter({'view\\Patient': 1})
# kon. Counter({'view\\Patient': 1})
# ervaring Counter({'view\\Patient': 1})
# gehad Counter({'view\\Patient': 1})
# wending Counter({'view\\Patient': 1})
# afkick Counter({'view\\Patient': 1})
# centrum Counter({'view\\Patient': 1})
# leger Counter({'view\\Patient': 1})
# des Counter({'view\\Patient': 1})
# heils Counter({'view\\Patient': 1})
# je Counter({'view\\Patient': 1})
# actieve Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'type\\Implicit': 1})
# transfer Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'type\\Implicit': 1})
# via Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'type\\Implicit': 1, 'view\\Third party': 1})
# stand Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'FAC 4': 1, 'type\\Implicit': 1})
# afdeling Counter({'FAC 2': 1, 'FAC 4': 1, 'type\\Implicit': 1})
# beoordelen Counter({'type\\Implicit': 1})
# wisselt Counter({'STM 2': 1})
# beroert Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'type\\Implicit': 1})
# diarree Counter({'view\\Third party': 1})
# middag Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# naast Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# probeerde Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# po-stoel Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# zakte Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# knieën Counter({'FAC 2': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# tijdsafspraak Counter({'stm\\reaction': 1})
# kwam Counter({'stm\\reaction': 1, 'STM 1': 1})
# wondzorg Counter({'stm\\reaction': 1})
# gestemd Counter({'.B152: Stemming': 1})
# dus Counter({'STM 1': 1})
# stilletjes Counter({'STM 1': 1})
# bozig Counter({'STM 1': 1})
# achterdochtig Counter({'STM 1': 1})
# vragen Counter({'stm\\reaction': 1})
# gesteld Counter({'stm\\reaction': 1})
# schoonzoon Counter({'stm\\reaction': 1})
# hoort Counter({'stm\\reaction': 1})
# uitslag Counter({'stm\\reaction': 1})
# aantal Counter({'stm\\reaction': 1, '.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# onderzoeken Counter({'stm\\reaction': 1})
# Verteld Counter({'view\\Patient': 1})
# productief Counter({'view\\Patient': 1})
# Wilde Counter({'view\\Patient': 1})
# bellen Counter({'view\\Patient': 1})
# Samen Counter({'FAC 3': 1, '.D450: Lopen en zich verplaatsen': 1})
# oogt Counter({'.B152: Stemming': 1})
# drugs Counter({'view\\Patient': 2})
# lichamelijk Counter({'.B455: Inspanningstolerantie': 1})
# algeheel Counter({'stm\\reaction': 1})
# rugpijn Counter({'stm\\reaction': 1})
# J Counter({'view\\Third party': 1})
# weet Counter({'view\\Third party': 1, 'view\\Patient': 1})
# verbazing Counter({'view\\Third party': 1})
# A Counter({'view\\Third party': 1})
# blij Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'STM 3': 1, 'view\\Patient': 1})
# informeerde Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'view\\Patient': 1})
# J. Counter({'view\\Third party': 1})
# Begint Counter({'view\\Third party': 1, 'view\\Patient': 1})
# piekeren Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'STM 1': 1, 'view\\Patient': 1})
# 's Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'view\\Patient': 1})
# nachts Counter({'view\\Third party': 1, 'stm\\reaction': 1, 'view\\Patient': 1})
# zoons Counter({'view\\Patient': 2, 'view\\Third party': 1, 'stm\\reaction': 1})
# Weer Counter({'view\\Third party': 1})
# beschikbaar Counter({'view\\Third party': 1})
# uitleg Counter({'view\\Third party': 1})
# want Counter({'view\\Third party': 1, 'view\\Patient': 1})
# begrijpt Counter({'view\\Third party': 1, 'view\\Patient': 1})
# verkeerd Counter({'view\\Third party': 1, 'view\\Patient': 1})
# zicht Counter({'view\\Third party': 1, 'view\\Patient': 1})
# terugkomen Counter({'view\\Third party': 1})
# ! Counter({'view\\Third party': 1})
# geëmotioneerd Counter({'.B152: Stemming': 1, 'STM 1': 1})
# fucking Counter({'view\\Patient': 1})
# soep Counter({'view\\Patient': 1})
# Wat Counter({'view\\Patient': 1})
# heftige Counter({'view\\Patient': 1})
# irritaties Counter({'view\\Patient': 1})
# Gebruiken Counter({'view\\Patient': 1})
# Volwassen Counter({'view\\Patient': 1})
# straks Counter({'view\\Patient': 1})
# gemist Counter({'view\\Patient': 1})
# sombere Counter({'.B152: Stemming': 1, 'STM 1': 1})
# gedrag Counter({'view\\Third party': 1})
# boosheid Counter({'view\\Third party': 1, '.B152: Stemming': 1, 'STM 1': 1})
# apathie Counter({'view\\Third party': 1})
# redt Counter({'view\\Third party': 1})
# trap Counter({'view\\Third party': 1, '.D450: Lopen en zich verplaatsen': 1})
# moeizamer Counter({'FAC 2': 1, 'FAC 3': 1, 'type\\Implicit': 1})
# begeleiding Counter({'FAC 2': 1, 'FAC 3': 1, 'FAC 1': 1})
# Linker Counter({'FAC 3': 1})
# Conditie Counter({'.B455: Inspanningstolerantie': 1})
# Afgelopen Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1})
# ADL Counter({'.D450: Lopen en zich verplaatsen': 1, 'type\\Implicit': 1, 'FAC 1': 1})
# redden Counter({'type\\Implicit': 1})
# ivm Counter({'stm\\reaction': 1})
# Was Counter({'.B455: Inspanningstolerantie': 1, 'INS 5': 1})
# boksen Counter({'.B455: Inspanningstolerantie': 1, 'INS 5': 1})
# survaivelrun Counter({'.B455: Inspanningstolerantie': 1, 'INS 5': 1})
# taining Counter({'.B455: Inspanningstolerantie': 1, 'INS 5': 1})
# gedemotiveerd Counter({'.B152: Stemming': 1, 'stm\\reaction': 1, 'STM 1': 1})
# Ziet Counter({'.B152: Stemming': 1, 'STM 1': 1})
# zorg Counter({'stm\\reaction': 1})
# toekomst Counter({'stm\\reaction': 1})
# man Counter({'stm\\reaction': 1})
# wachtlijsten Counter({'stm\\reaction': 1})
# gemakkelijk Counter({'STM 3': 1, 'view\\Patient': 1})
# leuk Counter({'view\\Patient': 1})
