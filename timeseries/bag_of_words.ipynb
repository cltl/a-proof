# %% [markdown]
# # Bag-of-Words (BoW) baseline for sentence annotation
#
# This was an experimental notebook. I made a naive bag-of-words model using the annotated sentences, then used this to evaluate predictive performance on an unseen dataset. This matches was the NLP team worked on, but avoids BERTje altogether. The purpose was to provide a baseline to verify that the BERTje method was performing at least as well as the most naive alternative.

# %%
import pickle
from pathlib import Path

import numpy as np
import pandas as pd
import scipy
import seaborn as sns
import sklearn
import statsmodels
import torch
from matplotlib import pyplot as plt
from tqdm import tqdm as tqdm

# Make graphics nice
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# Set sensible defaults
sns.set()
sns.set_style("ticks")
sns.set_context('paper')

# %%
df_train = pd.read_csv('//data2/Documents/a-proof/bow_data/covid_traindata.tsv', sep='\t')
df_train.head()

# %%
df_test = pd.read_csv('//data2/Documents/a-proof/bow_data/covid_testdata.tsv', sep='\t')
df_test.shape
# Out:
# (17365, 6)

# %%
# extract all annotated sentences
df_train = df_train[~df_train.annotations.isna()]
df_test = df_test[~df_test.annotations.isna()]

# Make initial corpus from train data
corpus = df_train.sentence.values
len(corpus)
# Out:
# 14718

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

stop_words = stopwords.words('dutch')

vectorizer = CountVectorizer(
    lowercase=True,
    stop_words=stop_words,
    strip_accents='ascii',
    min_df=0.002,
    max_df=0.9,
)
X_train = vectorizer.fit_transform(corpus)
print('Vocabulary size:', len(vectorizer.vocabulary_))
print('Train:', X_train.shape)

X_test = vectorizer.transform(df_test.sentence.values)
print('Test:', X_test.shape)
# Out:
# Vocabulary size: 479
# Train: (14718, 479)
# Test: (2983, 479)

# %%
train_vocab = vectorizer.vocabulary_
train_vocab
# Out:
# {'passieve': 333,
#  'lift': 259,
#  'lopen': 271,
#  'mogelijk': 292,
#  'beweegadvies': 102,
#  'starten': 389,
#  'stoel': 392,
#  'unit': 419,
#  '30': 38,
#  '25': 32,
#  'min': 288,
#  'doel': 159,
#  'ft': 180,
#  'plan': 342,
#  'bed': 85,
#  'week': 460,
#  'respiratoire': 363,
#  'insufficientie': 232,
#  'covid': 134,
#  'voorgeschiedenis': 445,
#  'medicatie': 279,
#  'beloop': 96,
#  'opname': 322,
#  'overname': 327,
#  'aldaar': 65,
#  '27': 34,
#  '03': 3,
#  'opgenomen': 320,
#  'bekend': 94,
#  'obesitas': 306,
#  'hypertensie': 224,
#  'hypercholesterolemie': 223,
#  'depressie': 148,
#  'gecompliceerd': 185,
#  'hit': 217,
#  'toename': 407,
#  'adequaat': 54,
#  'wv': 470,
#  'icc': 226,
#  'herstart': 211,
#  '22': 29,
#  '05': 5,
#  'verdere': 432,
#  'afname': 62,
#  'consolidaties': 129,
#  'icu': 227,
#  'dd': 146,
#  '19': 19,
#  'pneumonie': 344,
#  'behandeling': 91,
#  'gedurende': 189,
#  'dagen': 145,
#  'waarna': 454,
#  'langzaam': 255,
#  'waarbij': 452,
#  'patient': 334,
#  'klinisch': 244,
#  'heel': 207,
#  'herstel': 212,
#  'zien': 475,
#  'verpleegafdeling': 434,
#  'o2': 305,
#  'extra': 173,
#  'pre': 348,
#  'goede': 204,
#  'conditie': 128,
#  'dagelijks': 144,
#  'pulmonale': 354,
#  'klachten': 242,
#  'beademing': 83,
#  'overleg': 326,
#  'gezien': 200,
#  'weken': 464,
#  'weinig': 463,
#  'hierop': 216,
#  'verbetering': 429,
#  'beleid': 95,
#  'opnieuw': 323,
#  'besproken': 100,
#  'morgen': 293,
#  'komt': 248,
#  'dhr': 153,
#  'tijdens': 405,
#  'keer': 240,
#  'hoog': 220,
#  '60': 43,
#  'jarige': 239,
#  'man': 275,
#  'verband': 427,
#  'sprake': 384,
#  'behandeldoel': 89,
#  'waardoor': 453,
#  'welke': 466,
#  'zelfstandig': 473,
#  'klinische': 245,
#  'arm': 73,
#  'actieve': 51,
#  'therapie': 402,
#  'per': 338,
#  'erg': 171,
#  'situatie': 378,
#  '10': 8,
#  'jaar': 238,
#  'geleden': 193,
#  'gestaakt': 197,
#  '23': 30,
#  'via': 439,
#  'seh': 375,
#  '24': 31,
#  'geintubeerd': 192,
#  'buikligging': 118,
#  'rug': 367,
#  'gedraaid': 187,
#  'hierna': 215,
#  'stabiel': 386,
#  'afgebouwd': 60,
#  'sinds': 377,
#  'hulp': 222,
#  'vanaf': 422,
#  'goed': 203,
#  'inspanning': 231,
#  'fors': 178,
#  'vpk': 448,
#  'actief': 50,
#  'zeer': 472,
#  'wel': 465,
#  'saturatie': 370,
#  '80': 44,
#  'obv': 307,
#  'mri': 294,
#  'waarschijnlijk': 456,
#  'intubatie': 235,
#  'detubatie': 152,
#  're': 357,
#  'ivm': 237,
#  'cmv': 126,
#  'aspergillus': 76,
#  'afdeling': 59,
#  'gestart': 198,
#  '11': 10,
#  'sonde': 382,
#  'sociaal': 381,
#  'vrouw': 449,
#  'hierbij': 214,
#  'hoge': 219,
#  'af': 57,
#  'graag': 205,
#  'diabetes': 154,
#  'mellitus': 282,
#  'type': 414,
#  'pijn': 340,
#  'roken': 364,
#  '15': 14,
#  'gestopt': 199,
#  '2018': 25,
#  'amc': 68,
#  'verdenking': 430,
#  'bdz': 81,
#  'intensive': 233,
#  'care': 119,
#  'volwassenen': 444,
#  'pcr': 336,
#  '2019': 26,
#  'ct': 136,
#  'bilaterale': 105,
#  'interstitiele': 234,
#  'co': 127,
#  'severity': 376,
#  'score': 372,
#  '20': 22,
#  'ab': 47,
#  'ceftriaxon': 122,
#  '31': 39,
#  '40': 41,
#  'ging': 201,
#  'tube': 413,
#  'cm': 125,
#  'aki': 64,
#  'duodenumsonde': 161,
#  'blijven': 111,
#  'lage': 254,
#  'beademingsvoorwaarden': 84,
#  'voorwaarden': 447,
#  'volgt': 443,
#  'gedetubeerd': 186,
#  'afbouwen': 58,
#  'stop': 393,
#  'desaturatie': 150,
#  'echter': 165,
#  'onvoldoende': 318,
#  'effect': 168,
#  'coronavirus': 133,
#  'pulmonaal': 353,
#  'ondersteuning': 311,
#  'nierfunctie': 301,
#  'dochter': 158,
#  'gaat': 183,
#  'alleen': 67,
#  'nodig': 304,
#  'hoesten': 218,
#  'dyspnoe': 163,
#  'negatief': 298,
#  'respiratoir': 362,
#  'cta': 137,
#  'ter': 398,
#  'longembolieen': 268,
#  'ondanks': 310,
#  '15l': 15,
#  '50': 42,
#  'ic': 225,
#  '13': 12,
#  'pressure': 350,
#  'hersenen': 210,
#  'bloeding': 113,
#  '14': 13,
#  'verslechtering': 436,
#  'drukken': 160,
#  'fio2': 177,
#  'kweken': 253,
#  'daarnaast': 142,
#  'cvvh': 139,
#  'dvt': 162,
#  'rechts': 359,
#  'start': 388,
#  'heparine': 208,
#  'desaturaties': 151,
#  '16': 16,
#  '17': 17,
#  'meropenem': 283,
#  'sdd': 373,
#  'vancomycine': 424,
#  'continueren': 131,
#  'oxygenatie': 329,
#  '18': 18,
#  'status': 390,
#  'quo': 356,
#  'waarvoor': 457,
#  'terug': 399,
#  'sedatie': 374,
#  '21': 28,
#  'thorax': 403,
#  'beiderzijds': 93,
#  'besloten': 99,
#  'verhoogd': 433,
#  'later': 257,
#  'bal': 80,
#  '04': 4,
#  'bewustzijn': 104,
#  'volgens': 442,
#  'protocol': 352,
#  'streef': 394,
#  'positief': 346,
#  'peep': 337,
#  'onrustig': 314,
#  '00': 0,
#  'uur': 421,
#  'arts': 75,
#  'mw': 295,
#  'weer': 461,
#  'geeft': 190,
#  'alle': 66,
#  'contact': 130,
#  'eerder': 167,
#  'passief': 332,
#  'tillift': 406,
#  'rolstoel': 366,
#  '1x': 21,
#  'aanwezig': 45,
#  'linker': 264,
#  'bedrand': 86,
#  'ochtend': 308,
#  'dag': 143,
#  'familie': 176,
#  'blij': 109,
#  'thuismedicatie': 404,
#  '2020': 27,
#  'ziekenhuis': 474,
#  '26': 33,
#  'beademd': 82,
#  'liet': 258,
#  'atriumfibrilleren': 78,
#  'tevens': 400,
#  'acute': 52,
#  'nierinsufficientie': 302,
#  'eigen': 169,
#  'behandeld': 88,
#  'chloroquine': 124,
#  'nacht': 296,
#  'overgeplaatst': 325,
#  'vumc': 450,
#  'gesedeerd': 196,
#  'ontwateren': 316,
#  'metoprolol': 284,
#  'koorts': 250,
#  'lijn': 262,
#  'uitgebreide': 417,
#  'afwijkingen': 63,
#  'verricht': 435,
#  'groei': 206,
#  'werden': 467,
#  'konden': 249,
#  'bleef': 107,
#  'rugligging': 368,
#  'support': 397,
#  'daags': 140,
#  'hervat': 213,
#  '12': 11,
#  'verbeterde': 428,
#  'volgende': 441,
#  'neurologisch': 300,
#  'geduid': 188,
#  'overplaatsing': 328,
#  'argatroban': 72,
#  'wegens': 462,
#  '29': 36,
#  'vanwege': 426,
#  'ontslag': 315,
#  'behoefte': 92,
#  'aanwijzingen': 46,
#  'echo': 164,
#  'mobiliseren': 291,
#  'vg': 438,
#  'bloed': 112,
#  'controle': 132,
#  'uitbreiden': 415,
#  'bouwen': 116,
#  'gehad': 191,
#  'indien': 228,
#  'komen': 247,
#  'loopt': 270,
#  'toenemend': 408,
#  'sputum': 385,
#  '2015': 23,
#  'cataract': 120,
#  'wisselend': 469,
#  'therapeutische': 401,
#  'antistolling': 70,
#  'bleek': 108,
#  'waarop': 455,
#  'middels': 287,
#  'onderzoek': 312,
#  'steeds': 391,
#  '28': 35,
#  'furosemide': 181,
#  'verder': 431,
#  'tracheostoma': 411,
#  'geplaatst': 195,
#  'rectaal': 360,
#  'bloedverlies': 115,
#  'abdomen': 48,
#  'beeld': 87,
#  'meest': 280,
#  'passend': 331,
#  'uitzuigen': 418,
#  'trach': 410,
#  'herhaald': 209,
#  'prednison': 349,
#  'positieve': 347,
#  'snel': 380,
#  'mg': 285,
#  'mei': 281,
#  'arterielijn': 74,
#  'toonde': 409,
#  'nieuwe': 303,
#  'delier': 147,
#  'achteruitgang': 49,
#  'reintubatie': 361,
#  'matglasafwijkingen': 276,
#  'oplopende': 321,
#  'waar': 451,
#  'lijkt': 261,
#  'longbeeld': 267,
#  'kleine': 243,
#  'lijnwissel': 263,
#  'derhalve': 149,
#  'slechte': 379,
#  'wakker': 458,
#  '01': 1,
#  'pancreatitis': 330,
#  'maandag': 272,
#  'daarna': 141,
#  '3x': 40,
#  'plaatsing': 341,
#  'infectie': 230,
#  'virale': 440,
#  'buik': 117,
#  'matig': 277,
#  'negatieve': 299,
#  'afgenomen': 61,
#  'rechter': 358,
#  'forse': 179,
#  'echtgenote': 166,
#  'adl': 55,
#  'bewezen': 103,
#  'scan': 371,
#  'longen': 269,
#  'astma': 77,
#  '07': 6,
#  '08': 7,
#  'diamox': 156,
#  'blijft': 110,
#  'onrust': 313,
#  '2x': 37,
#  'voorkomen': 446,
#  'advies': 56,
#  'beter': 101,
#  'rollator': 365,
#  'fac': 174,
#  'benen': 97,
#  'transfer': 412,
#  '02': 2,
#  'olvg': 309,
#  'enkele': 170,
#  'ligt': 260,
#  'liter': 266,
#  'kracht': 251,
#  'weanen': 459,
#  'optimaliseren': 324,
#  'problemen': 351,
#  'gemaakt': 194,
#  'zoon': 478,
#  'gebeld': 184,
#  'diagnostiek': 155,
#  'huisarts': 221,
#  'cvl': 138,
#  'gaan': 182,
#  'streven': 395,
#  'vandaag': 425,
#  'nb': 297,
#  'zitten': 477,
#  'angst': 69,
#  '2016': 24,
#  'poging': 345,
#  '1dd': 20,
#  'maart': 273,
#  'april': 71,
#  'behandelen': 90,
#  'persisterende': 339,
#  'bk': 106,
#  'faecium': 175,
#  'gisteren': 202,
#  'bloedkweek': 114,
#  'onveranderd': 317,
#  'uitgebreid': 416,
#  'sars': 369,
#  'esbl': 172,
#  'subfebriel': 396,
#  'vanco': 423,
#  'patiente': 335,
#  'kno': 246,
#  'links': 265,
#  'iv': 236,
#  'laten': 256,
#  'staken': 387,
#  'mdo': 278,
#  'ureum': 420,
#  'wissel': 468,
#  'maken': 274,
#  'zit': 476,
#  'verwijderd': 437,
#  'chirurgische': 123,
#  'dienst': 157,
#  'midazolam': 286,
#  'ad': 53,
#  'quetiapine': 355,
#  'zat': 471,
#  'crp': 135,
#  'infarct': 229,
#  'beoordeling': 98,
#  'opgehoogd': 319,
#  'cefta': 121,
#  'augmentin': 79,
#  'pleuravocht': 343,
#  'mmol': 290,
#  'ml': 289,
#  'sondevoeding': 383,
#  'kg': 241,
#  'kreat': 252,
#  '10e9': 9}

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.80)
pca = pca.fit(X_train.toarray())
_X_train = pca.transform(X_train.toarray())
_X_test = pca.transform(X_test.toarray())
_X_train.shape, _X_test.shape
# Out:
# ((14718, 219), (2983, 219))

# %%
DOMAINS = ['STM', 'INS', 'BER', 'FAC']

def indicate_domain(s, d):
    assert d in DOMAINS
    if not isinstance(s, str):
        return 0
    if d in s:
        return 1
    return 0

for df in [df_train, df_test]:
    for d in DOMAINS:
        df[f"ind_{d}"] = df['annotations'].apply(indicate_domain, d=d)

df_train.sample(5)

# %%
from collections import defaultdict

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support as prfs
from sklearn.svm import SVC

results = defaultdict(list)

for target in ['ind_STM', 'ind_INS', 'ind_FAC', 'ind_BER']:
    print(target)
    y_train = df_train[target].values
    y_test = df_test[target].values
    for model in [LogisticRegression, SVC]:
        for pca_flag in [True, False]:
            
            traindata = _X_train if pca_flag else X_train
            testdata = _X_test if pca_flag else X_test
            mod = model().fit(traindata, y_train)
            preds = mod.predict(testdata)
            acc = accuracy_score(y_test, preds)
            prec, rec, f1, sup = prfs(y_test, preds, average='binary', pos_label=1)
            results['model'].append(type(mod).__name__)
            results['pca'].append(pca_flag)
            results['class'].append(target)
            results['accuracy'].append(acc)
            results['precision'].append(prec)
            results['recall'].append(rec)
            results['f1_score'].append(f1)

df_results = pd.DataFrame(results)
df_results
# Out:
# ind_STM
# ind_INS
# ind_FAC
# ind_BER
# /data/homedirs/gianluca/.local/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /data/homedirs/gianluca/.local/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /data/homedirs/gianluca/.local/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                  model    pca    class  accuracy  precision    recall  \
# 0   LogisticRegression   True  ind_STM  0.971840   0.633333  0.206522
# 1   LogisticRegression  False  ind_STM  0.971170   0.578947  0.239130
# 2                  SVC   True  ind_STM  0.971170   0.607143  0.184783
# 3                  SVC  False  ind_STM  0.970164   0.555556  0.163043
# 4   LogisticRegression   True  ind_INS  0.987261   0.666667  0.232558
# 5   LogisticRegression  False  ind_INS  0.987261   0.631579  0.279070
# 6                  SVC   True  ind_INS  0.987596   0.875000  0.162791
# 7                  SVC  False  ind_INS  0.987596   0.875000  0.162791
# 8   LogisticRegression   True  ind_FAC  0.984579   0.833333  0.185185
# 9   LogisticRegression  False  ind_FAC  0.984244   0.684211  0.240741
# 10                 SVC   True  ind_FAC  0.985250   0.812500  0.240741
# 11                 SVC  False  ind_FAC  0.987261   0.766667  0.425926
# 12  LogisticRegression   True  ind_BER  0.999330   0.000000  0.000000
# 13  LogisticRegression  False  ind_BER  0.999330   0.000000  0.000000
# 14                 SVC   True  ind_BER  0.999330   0.000000  0.000000
# 15                 SVC  False  ind_BER  0.999330   0.000000  0.000000
#
#     f1_score
# 0   0.311475
# 1   0.338462
# 2   0.283333
# 3   0.252101
# 4   0.344828
# 5   0.387097
# 6   0.274510
# 7   0.274510
# 8   0.303030
# 9   0.356164
# 10  0.371429
# 11  0.547619
# 12  0.000000
# 13  0.000000
# 14  0.000000
# 15  0.000000

# %%
df_results.set_index(['class', 'model', 'pca']).round(4)
# Out:
#                                   accuracy  precision  recall  f1_score
# class   model              pca
# ind_STM LogisticRegression True     0.9718     0.6333  0.2065    0.3115
#                            False    0.9712     0.5789  0.2391    0.3385
#         SVC                True     0.9712     0.6071  0.1848    0.2833
#                            False    0.9702     0.5556  0.1630    0.2521
# ind_INS LogisticRegression True     0.9873     0.6667  0.2326    0.3448
#                            False    0.9873     0.6316  0.2791    0.3871
#         SVC                True     0.9876     0.8750  0.1628    0.2745
#                            False    0.9876     0.8750  0.1628    0.2745
# ind_FAC LogisticRegression True     0.9846     0.8333  0.1852    0.3030
#                            False    0.9842     0.6842  0.2407    0.3562
#         SVC                True     0.9852     0.8125  0.2407    0.3714
#                            False    0.9873     0.7667  0.4259    0.5476
# ind_BER LogisticRegression True     0.9993     0.0000  0.0000    0.0000
#                            False    0.9993     0.0000  0.0000    0.0000
#         SVC                True     0.9993     0.0000  0.0000    0.0000
#                            False    0.9993     0.0000  0.0000    0.0000
